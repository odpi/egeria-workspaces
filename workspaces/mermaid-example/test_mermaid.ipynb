# %%
# SPDX-License-Identifier: Apache-2.0
# Copyright Contributors to the ODPi Egeria project.

import os
view_server = os.environ.get("VIEW_SERVER","view-server")
url = os.environ.get("EGERIA_VIEW_SERVER_URL","https://host.docker.internal:9443")
user_id = os.environ.get("EGERIA_USER", "peterprofile")
user_pwd = os.environ.get("EGERIA_USER_PASSWORD")

from pyegeria import AutomatedCuration, ServerOps
import asyncio
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# Notebook provides a simple example of using the pyegeria mermaid_utilities functions.
#
# A running Egeria environment is needed to run these functions.
#
# * mermaid_graph(process_guid, view_server, url, user_id, password) - generates Mermaid markdown for the Egeria process.
# * load_mermaid() - must be executed once per session to inject mermaid javascript code into the Jupyter environment.
# * render_mermaid(mermaid_code) - renders and displays the Mermaid markdown code specified.

# %%
from pyegeria import load_mermaid, render_mermaid, generate_process_graph

mermaid_graph = generate_process_graph()
load_mermaid()
render_mermaid(mermaid_graph)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /opt/conda/lib/python3.11/site-packages/pyegeria/mermaid_utilities.py:112 in                     │
# │ generate_process_graph                                                                           │
# │                                                                                                  │
# │   109 │   │   token = a_client.create_egeria_bearer_token()                                      │
# │   110 │   │                                                                                      │
# │   111 │   │   start_time = time.perf_counter()                                                   │
# │ ❱ 112 │   │   response = a_client.get_gov_action_process_graph(process_guid)                     │
# │   113 │   │   duration = time.perf_counter() - start_time                                        │
# │   114 │   │                                                                                      │
# │   115 │   │   if type(response) is dict:                                                         │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │     a_client = <pyegeria.automated_curation_omvs.AutomatedCuration object at 0xffff8e75d290> │ │
# │ │      console = <console width=115 ColorSystem.TRUECOLOR>                                     │ │
# │ │            e = InvalidParameterException('{"class":"GovernanceActionProcessGraphResponse","… │ │
# │ │                The GovernanceActionProcess entity with unique identifier                     │ │
# │ │                508d3878-8eae-47e5-8507-ee936f33b418 is not found for method                  │ │
# │ │                getGovernanceActionProcessGraph of access service Governance Action Framework │ │
# │ │                Services in open metadata server active-metadata-store, error message was:    │ │
# │ │                OMRS-REPOSITORY-404-002 The entity identified with guid                       │ │
# │ │                508d3878-8eae-47e5-8507-ee936f33b418 passed on the getEntityDetail call is    │ │
# │ │                not known to the open metadata repository                                     │ │
# │ │                Enterprise","exceptionErrorMessageId":"OMAG-REPOSITORY-HANDLER-404-007","exc… │ │
# │ │                Action Framework Services","active-metadata-store","OMRS-REPOSITORY-404-002   │ │
# │ │                The entity identified with guid 508d3878-8eae-47e5-8507-ee936f33b418 passed   │ │
# │ │                on the getEntityDetail call is not known to the open metadata repository      │ │
# │ │                Enterprise"],"exceptionSystemAction":"The system is unable to update          │ │
# │ │                information associated with the entity because none of the connected open     │ │
# │ │                metadata repositories recognize the entity\'s unique                          │ │
# │ │                identifier.","exceptionUserAction":"The unique identifier of the entity is    │ │
# │ │                supplied by the caller.  Verify that the caller\'s logic is correct, and that │ │
# │ │                there are no errors being reported by the open metadata repository. Once all  │ │
# │ │                errors have been resolved, retry the                                          │ │
# │ │                request.","exceptionProperties":{"parameterName":"processGUID"}}')            │ │
# │ │ process_guid = '508d3878-8eae-47e5-8507-ee936f33b418'                                        │ │
# │ │   start_time = 1952.195548384                                                                │ │
# │ │        token = 'eyJraWQiOiI0NzhkMjhlZS1lMzdlLTQzN2QtODY5NS1jMTQ2NzQ4ODU4NjgiLCJhbGciOiJSUzI… │ │
# │ │          url = 'https://host.docker.internal:9443'                                           │ │
# │ │      user_id = 'erinoverview'                                                                │ │
# │ │    user_pass = 'secret'                                                                      │ │
# │ │  view_server = 'view-server'                                                                 │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /opt/conda/lib/python3.11/site-packages/pyegeria/automated_curation_omvs.py:1729 in              │
# │ get_gov_action_process_graph                                                                     │
# │                                                                                                  │
# │   1726 │   │                                                                                     │
# │   1727 │   │   """                                                                               │
# │   1728 │   │   loop = asyncio.get_event_loop()                                                   │
# │ ❱ 1729 │   │   response = loop.run_until_complete(                                               │
# │   1730 │   │   │   self._async_get_gov_action_process_graph(process_guid, server)                │
# │   1731 │   │   )                                                                                 │
# │   1732 │   │   return response                                                                   │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │         loop = <_UnixSelectorEventLoop running=True closed=False debug=False>                │ │
# │ │ process_guid = '508d3878-8eae-47e5-8507-ee936f33b418'                                        │ │
# │ │         self = <pyegeria.automated_curation_omvs.AutomatedCuration object at 0xffff8e75d290> │ │
# │ │       server = None                                                                          │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /opt/conda/lib/python3.11/site-packages/nest_asyncio.py:98 in run_until_complete                 │
# │                                                                                                  │
# │    95 │   │   │   if not f.done():                                                               │
# │    96 │   │   │   │   raise RuntimeError(                                                        │
# │    97 │   │   │   │   │   'Event loop stopped before Future completed.')                         │
# │ ❱  98 │   │   │   return f.result()                                                              │
# │    99 │                                                                                          │
# │   100 │   def _run_once(self):                                                                   │
# │   101 │   │   """                                                                                │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │          f = <Task finished name='Task-4'                                                    │ │
# │ │              coro=<AutomatedCuration._async_get_gov_action_process_graph() done, defined at  │ │
# │ │              /opt/conda/lib/python3.11/site-packages/pyegeria/automated_curation_omvs.py:16… │ │
# │ │              exception=InvalidParameterException('{"class":"GovernanceActionProcessGraphRes… │ │
# │ │              The GovernanceActionProcess entity with unique identifier                       │ │
# │ │              508d3878-8eae-47e5-8507-ee936f33b418 is not found for method                    │ │
# │ │              getGovernanceActionProcessGraph of access service Governance Action Framework   │ │
# │ │              Services in open metadata server active-metadata-store, error message was:      │ │
# │ │              OMRS-REPOSITORY-404-002 The entity identified with guid                         │ │
# │ │              508d3878-8eae-47e5-8507-ee936f33b418 passed on the getEntityDetail call is not  │ │
# │ │              known to the open metadata repository                                           │ │
# │ │              Enterprise","exceptionErrorMessageId":"OMAG-REPOSITORY-HANDLER-404-007","excep… │ │
# │ │              Action Framework Services","active-metadata-store","OMRS-REPOSITORY-404-002 The │ │
# │ │              entity identified with guid 508d3878-8eae-47e5-8507-ee936f33b418 passed on the  │ │
# │ │              getEntityDetail call is not known to the open metadata repository               │ │
# │ │              Enterprise"],"exceptionSystemAction":"The system is unable to update            │ │
# │ │              information associated with the entity because none of the connected open       │ │
# │ │              metadata repositories recognize the entity\'s unique                            │ │
# │ │              identifier.","exceptionUserAction":"The unique identifier of the entity is      │ │
# │ │              supplied by the caller.  Verify that the caller\'s logic is correct, and that   │ │
# │ │              there are no errors being reported by the open metadata repository. Once all    │ │
# │ │              errors have been resolved, retry the                                            │ │
# │ │              request.","exceptionProperties":{"parameterName":"processGUID"}}')>             │ │
# │ │     future = <coroutine object AutomatedCuration._async_get_gov_action_process_graph at      │ │
# │ │              0xffff8e730d40>                                                                 │ │
# │ │ manage_run = <function _patch_loop.<locals>.manage_run at 0xffff8e77ba60>                    │ │
# │ │       self = <_UnixSelectorEventLoop running=True closed=False debug=False>                  │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /opt/conda/lib/python3.11/asyncio/futures.py:203 in result                                       │
# │                                                                                                  │
# │   200 │   │   │   raise exceptions.InvalidStateError('Result is not ready.')                     │
# │   201 │   │   self.__log_traceback = False                                                       │
# │   202 │   │   if self._exception is not None:                                                    │
# │ ❱ 203 │   │   │   raise self._exception.with_traceback(self._exception_tb)                       │
# │   204 │   │   return self._result                                                                │
# │   205 │                                                                                          │
# │   206 │   def exception(self):                                                                   │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ self = <Task finished name='Task-4'                                                          │ │
# │ │        coro=<AutomatedCuration._async_get_gov_action_process_graph() done, defined at        │ │
# │ │        /opt/conda/lib/python3.11/site-packages/pyegeria/automated_curation_omvs.py:1667>     │ │
# │ │        exception=InvalidParameterException('{"class":"GovernanceActionProcessGraphResponse"… │ │
# │ │        The GovernanceActionProcess entity with unique identifier                             │ │
# │ │        508d3878-8eae-47e5-8507-ee936f33b418 is not found for method                          │ │
# │ │        getGovernanceActionProcessGraph of access service Governance Action Framework         │ │
# │ │        Services in open metadata server active-metadata-store, error message was:            │ │
# │ │        OMRS-REPOSITORY-404-002 The entity identified with guid                               │ │
# │ │        508d3878-8eae-47e5-8507-ee936f33b418 passed on the getEntityDetail call is not known  │ │
# │ │        to the open metadata repository                                                       │ │
# │ │        Enterprise","exceptionErrorMessageId":"OMAG-REPOSITORY-HANDLER-404-007","exceptionEr… │ │
# │ │        Action Framework Services","active-metadata-store","OMRS-REPOSITORY-404-002 The       │ │
# │ │        entity identified with guid 508d3878-8eae-47e5-8507-ee936f33b418 passed on the        │ │
# │ │        getEntityDetail call is not known to the open metadata repository                     │ │
# │ │        Enterprise"],"exceptionSystemAction":"The system is unable to update information      │ │
# │ │        associated with the entity because none of the connected open metadata repositories   │ │
# │ │        recognize the entity\'s unique identifier.","exceptionUserAction":"The unique         │ │
# │ │        identifier of the entity is supplied by the caller.  Verify that the caller\'s logic  │ │
# │ │        is correct, and that there are no errors being reported by the open metadata          │ │
# │ │        repository. Once all errors have been resolved, retry the                             │ │
# │ │        request.","exceptionProperties":{"parameterName":"processGUID"}}')>                   │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /opt/conda/lib/python3.11/asyncio/tasks.py:277 in __step                                         │
# │                                                                                                  │
# │   274 │   │   │   if exc is None:                                                                │
# │   275 │   │   │   │   # We use the `send` method directly, because coroutines                    │
# │   276 │   │   │   │   # don't have `__iter__` and `__next__` methods.                            │
# │ ❱ 277 │   │   │   │   result = coro.send(None)                                                   │
# │   278 │   │   │   else:                                                                          │
# │   279 │   │   │   │   result = coro.throw(exc)                                                   │
# │   280 │   │   except StopIteration as exc:                                                       │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ coro = <coroutine object AutomatedCuration._async_get_gov_action_process_graph at            │ │
# │ │        0xffff8e730d40>                                                                       │ │
# │ │ self = None                                                                                  │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /opt/conda/lib/python3.11/site-packages/pyegeria/automated_curation_omvs.py:1700 in              │
# │ _async_get_gov_action_process_graph                                                              │
# │                                                                                                  │
# │   1697 │   │   │   f"governance-action-processes/{process_guid}/graph"                           │
# │   1698 │   │   )                                                                                 │
# │   1699 │   │                                                                                     │
# │ ❱ 1700 │   │   response = await self._async_make_request("POST", url)                            │
# │   1701 │   │   return response.json().get("element", "no actions")                               │
# │   1702 │                                                                                         │
# │   1703 │   def get_gov_action_process_graph(                                                     │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ process_guid = '508d3878-8eae-47e5-8507-ee936f33b418'                                        │ │
# │ │         self = <pyegeria.automated_curation_omvs.AutomatedCuration object at 0xffff8e75d290> │ │
# │ │       server = 'view-server'                                                                 │ │
# │ │          url = 'https://host.docker.internal:9443/servers/view-server/api/open-metadata/aut… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /opt/conda/lib/python3.11/site-packages/pyegeria/_client.py:398 in _async_make_request           │
# │                                                                                                  │
# │   395 │   │   │   │   │   │   return response                                                    │
# │   396 │   │   │   │   │   else:                                                                  │
# │   397 │   │   │   │   │   │   exc_message = response.text                                        │
# │ ❱ 398 │   │   │   │   │   │   raise InvalidParameterException(exc_message)                       │
# │   399 │   │   │   │   else:                                                                      │
# │   400 │   │   │   │   │   msg = OMAGCommonErrorCode.CLIENT_SIDE_REST_API_ERROR.value[            │
# │   401 │   │   │   │   │   │   "message_template"                                                 │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ caller_method = '_async_get_gov_action_process_graph'                                        │ │
# │ │ calling_frame = <frame at 0xffff8e759e00, file                                               │ │
# │ │                 '/opt/conda/lib/python3.11/site-packages/pyegeria/automated_curation_omvs.p… │ │
# │ │                 line 1700, code _async_get_gov_action_process_graph>                         │ │
# │ │    class_name = 'Client'                                                                     │ │
# │ │      endpoint = 'https://host.docker.internal:9443/servers/view-server/api/open-metadata/au… │ │
# │ │   exc_message = '{"class":"GovernanceActionProcessGraphResponse","relatedHTTPCode":404,"exc… │ │
# │ │       payload = None                                                                         │ │
# │ │  related_code = 404                                                                          │ │
# │ │  request_type = 'POST'                                                                       │ │
# │ │      response = <Response [200 ]>                                                            │ │
# │ │          self = <pyegeria.automated_curation_omvs.AutomatedCuration object at                │ │
# │ │                 0xffff8e75d290>                                                              │ │
# │ │   status_code = 200                                                                          │ │
# │ │      time_out = 30                                                                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# InvalidParameterException: OMAG-REPOSITORY-HANDLER-404-007 The GovernanceActionProcess entity with unique
# identifier 508d3878-8eae-47e5-8507-ee936f33b418 is not found for method getGovernanceActionProcessGraph of access
# service Governance Action Framework Services in open metadata server active-metadata-store, error message was:
# OMRS-REPOSITORY-404-002 The entity identified with guid 508d3878-8eae-47e5-8507-ee936f33b418 passed on the
# getEntityDetail call is not known to the open metadata repository Enterprise
# ---------------------------------------------------------------------------
# InvalidParameterException                 Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/pyegeria/mermaid_utilities.py:112, in generate_process_graph(process_guid, view_server, url, user_id, user_pass)
#     111 start_time = time.perf_counter()
# --> 112 response = a_client.get_gov_action_process_graph(process_guid)
#     113 duration = time.perf_counter() - start_time
#
# File /opt/conda/lib/python3.11/site-packages/pyegeria/automated_curation_omvs.py:1729, in AutomatedCuration.get_gov_action_process_graph(self, process_guid, server)
#    1728 loop = asyncio.get_event_loop()
# -> 1729 response = loop.run_until_complete(
#    1730     self._async_get_gov_action_process_graph(process_guid, server)
#    1731 )
#    1732 return response
#
# File /opt/conda/lib/python3.11/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /opt/conda/lib/python3.11/asyncio/futures.py:203, in Future.result(self)
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /opt/conda/lib/python3.11/asyncio/tasks.py:277, in Task.__step(***failed resolving arguments***)
#     274 if exc is None:
#     275     # We use the `send` method directly, because coroutines
#     276     # don't have `__iter__` and `__next__` methods.
# --> 277     result = coro.send(None)
#     278 else:
#
# File /opt/conda/lib/python3.11/site-packages/pyegeria/automated_curation_omvs.py:1700, in AutomatedCuration._async_get_gov_action_process_graph(self, process_guid, server)
#    1695 url = (
#    1696     f"{self.platform_url}/servers/{server}/api/open-metadata/automated-curation/"
#    1697     f"governance-action-processes/{process_guid}/graph"
#    1698 )
# -> 1700 response = await self._async_make_request("POST", url)
#    1701 return response.json().get("element", "no actions")
#
# File /opt/conda/lib/python3.11/site-packages/pyegeria/_client.py:398, in Client._async_make_request(self, request_type, endpoint, payload, time_out)
#     397         exc_message = response.text
# --> 398         raise InvalidParameterException(exc_message)
#     399 else:
#
# InvalidParameterException: OMAG-REPOSITORY-HANDLER-404-007 The GovernanceActionProcess entity with unique identifier 508d3878-8eae-47e5-8507-ee936f33b418 is not found for method getGovernanceActionProcessGraph of access service Governance Action Framework Services in open metadata server active-metadata-store, error message was: OMRS-REPOSITORY-404-002 The entity identified with guid 508d3878-8eae-47e5-8507-ee936f33b418 passed on the getEntityDetail call is not known to the open metadata repository Enterprise
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pyegeria import load_mermaid, render_mermaid, generate_process_graph
# ----> 3 mermaid_graph = generate_process_graph()
#       4 load_mermaid()
#       5 render_mermaid(mermaid_graph)
#
# File /opt/conda/lib/python3.11/site-packages/pyegeria/mermaid_utilities.py:214, in generate_process_graph(process_guid, view_server, url, user_id, user_pass)
#     208 except (
#     209     InvalidParameterException,
#     210     PropertyServerException,
#     211     UserNotAuthorizedException,
#     212 ) as e:
#     213     console.print_exception(show_locals=True)
# --> 214     assert False, "Invalid request"
#     216 finally:
#     217     a_client.close_session()
#
# AssertionError: Invalid request
