# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Egeria Workbook
#
# # Querying solutions
#
# ## Introduction

# %%
# Initialize pyegeria

# %run ../pyegeria/initialize-pyegeria.ipynb
# Out:
#     <script src="https://unpkg.com/mermaid@11.6.0/dist/mermaid.min.js"></script>
#     <script>
#         document.addEventListener('DOMContentLoaded', function() {
#             mermaid.initialize({startOnLoad: true},
#             {maxTextSize: 300000});
#         });
#     </script>

# %%
egeria_tech = EgeriaTech(view_server, url, user_id, user_pwd)
token = egeria_tech.create_egeria_bearer_token()

# %%
egeria_tech.add_archive_file("content-packs/CocoComboArchive.omarchive", None, "qs-metadata-store")

print("Archive loaded!")
# Out:
# Archive loaded!

# %%
egeria_cat = EgeriaCat(view_server, url, user_id, user_pwd)
egeria_cat.set_bearer_token(token)

# %%
print_information_supply_chains(egeria_tech, "Treatment Validation", add_implementation=True)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-63e0c0d3-7870-4d31-9763-72d9d0dd36b6-510a-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Information Supply Chain - Clinical Trial Treatment Validation::PROJ-CT-TBDF
#                 </h3>
#                 <p id="mermaid-graph-63e0c0d3-7870-4d31-9763-72d9d0dd36b6-510a-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 63e0c0d3-7870-4d31-9763-72d9d0dd36b6
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# subgraph 1 [Details]
# subgraph 2 [Segments]
# 3@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Data Lake to Sandbox**&quot;}
# 3==&gt;|&quot;assemble,
# [Information Supply Chain Link]&quot;|4
# 5@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Deliver Treatment Assessment Report**&quot;}
# 6@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Weekly Measurements Onboarding**&quot;}
# 6==&gt;|&quot;capture and catalog,
# [Information Supply Chain Link]&quot;|3
# 4@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Assess Treatment under Trial**&quot;}
# 4==&gt;|&quot;publish results,
# [Information Supply Chain Link]&quot;|5
# 7@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Hospital Delivers Patient Weekly Readings**&quot;}
# 7==&gt;|&quot;publish,
# [Information Supply Chain Link]&quot;|6
# end
# subgraph 8 [Design]
# 9@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Weekly Measurements Data Lake Folder::V1.0**&quot;}
# 10@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Populate Sandbox::V1.0**&quot;}
# 11@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Treatment Validation Sandbox::V1.0**&quot;}
# 12@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Assemble Treatment Assessment Report::V1.0**&quot;}
# 13@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Treatment Efficacy Evidence::V1.0**&quot;}
# 14@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Treatment Assessment Report Validation and Delivery::V1.0**&quot;}
# 15@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Hospital Landing Area Folder::V1.0**&quot;}
# 16@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Weekly Measurements Onboarding Pipeline::V1.0**&quot;}
# 17@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Landing Folder Cataloguer::V1.0**&quot;}
# 18@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Analyse Patient Data::V1.0**&quot;}
# 19@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Hospital Processes::V1.0**&quot;}
# 3--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|9
# 3--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|10
# 3--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|11
# 16==&gt;|&quot;save new files,
# [Solution Linking Wire]&quot;|9
# 9==&gt;|&quot;read certified files,
# [Solution Linking Wire]&quot;|10
# 10==&gt;|&quot;write patient measurements,
# [Solution Linking Wire]&quot;|11
# 11==&gt;|&quot;retrieve patient data,
# [Solution Linking Wire]&quot;|18
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|12
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|13
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|14
# 13==&gt;|&quot;retrieve evidence,
# [Solution Linking Wire]&quot;|12
# 12==&gt;|&quot;publish results,
# [Solution Linking Wire]&quot;|14
# 18==&gt;|&quot;publish results,
# [Solution Linking Wire]&quot;|13
# 6--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|15
# 6--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|16
# 6--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|17
# 6--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|9
# 15==&gt;|&quot;detect new files,
# [Solution Linking Wire]&quot;|17
# 19==&gt;|&quot;publish,
# [Solution Linking Wire]&quot;|15
# 17==&gt;|&quot;request onboarding,
# [Solution Linking Wire]&quot;|16
# 4--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|13
# 4--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|18
# 4--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|11
# 7--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|15
# 7--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|19
# end
# subgraph 20 [Implementation]
# 21@{ shape: notch-pent, label: &quot;*Tabular Column*
# **LandingArea::Hampton Hospital::PROJ-CT-TBDF::CSVFile::/Users/amandachessell/Code/ODPi/egeria-oak/egeria/open-metadata-distribution/omag-server-platform/build/unpacked/egeria-platform-5.3-SNAPSHOT-distribution.tar.gz/assembly/platform/landing-area/hospitals/hampton/clinical-trials/drop-foot/week3.csv_angleLeft_column_archivedOn_Mon May 12 13:20:38 BST 2025**&quot;}
# 22@{ shape: rounded, label: &quot;*Tabular Column*
# **DataLake::PROJ-CT-TBDF::CSVFile::/Users/amandachessell/Code/ODPi/egeria-oak/egeria/open-metadata-distribution/omag-server-platform/build/unpacked/egeria-platform-5.3-SNAPSHOT-distribution.tar.gz/assembly/platform/coco-data-lake/research/clinical-trials/teddy-bear-drop-foot/weekly-measurements/PROJ-CT-TBDF_000005.csv_angleLeft_column**&quot;}
# 21==&gt;|&quot;copy [Data Mapping]&quot;|22
# 23@{ shape: notch-pent, label: &quot;*Tabular Column*
# **LandingArea::Oak Dene Hospital::PROJ-CT-TBDF::CSVFile::/Users/amandachessell/Code/ODPi/egeria-oak/egeria/open-metadata-distribution/omag-server-platform/build/unpacked/egeria-platform-5.3-SNAPSHOT-distribution.tar.gz/assembly/platform/landing-area/hospitals/oak-dene/clinical-trials/drop-foot/week3.csv_angleLeft_column_archivedOn_Mon May 12 13:18:07 BST 2025**&quot;}
# 24@{ shape: rounded, label: &quot;*Tabular Column*
# **DataLake::PROJ-CT-TBDF::CSVFile::/Users/amandachessell/Code/ODPi/egeria-oak/egeria/open-metadata-distribution/omag-server-platform/build/unpacked/egeria-platform-5.3-SNAPSHOT-distribution.tar.gz/assembly/platform/coco-data-lake/research/clinical-trials/teddy-bear-drop-foot/weekly-measurements/PROJ-CT-TBDF_000004.csv_angleLeft_column**&quot;}
# 23==&gt;|&quot;copy [Data Mapping]&quot;|24
# 25@{ shape: notch-pent, label: &quot;*Tabular Column*
# **LandingArea::Oak Dene Hospital::PROJ-CT-TBDF::CSVFile::/Users/amandachessell/Code/ODPi/egeria-oak/egeria/open-metadata-distribution/omag-server-platform/build/unpacked/egeria-platform-5.3-SNAPSHOT-distribution.tar.gz/assembly/platform/landing-area/hospitals/oak-dene/clinical-trials/drop-foot/week1.csv_angleLeft_column_archivedOn_Mon May 12 13:15:04 BST 2025**&quot;}
# 26@{ shape: rounded, label: &quot;*Tabular Column*
# **DataLake::PROJ-CT-TBDF::CSVFile::/Users/amandachessell/Code/ODPi/egeria-oak/egeria/open-metadata-distribution/omag-server-platform/build/unpacked/egeria-platform-5.3-SNAPSHOT-distribution.tar.gz/assembly/platform/coco-data-lake/research/clinical-trials/teddy-bear-drop-foot/weekly-measurements/PROJ-CT-TBDF_000000.csv_angleLeft_column**&quot;}
# 25==&gt;|&quot;copy [Data Mapping]&quot;|26
# 27@{ shape: notch-pent, label: &quot;*Tabular Column*
# **LandingArea::Oak Dene Hospital::PROJ-CT-TBDF::CSVFile::/Users/amandachessell/Code/ODPi/egeria-oak/egeria/open-metadata-distribution/omag-server-platform/build/unpacked/egeria-platform-5.3-SNAPSHOT-distribution.tar.gz/assembly/platform/landing-area/hospitals/oak-dene/clinical-trials/drop-foot/week1.csv_angleRight_column_archivedOn_Mon May 12 13:15:05 BST 2025**&quot;}
# 28@{ shape: rounded, label: &quot;*Tabular Column*
# **DataLake::PROJ-CT-TBDF::CSVFile::/Users/amandachessell/Code/ODPi/egeria-oak/egeria/open-metadata-distribution/omag-server-platform/build/unpacked/egeria-platform-5.3-SNAPSHOT-distribution.tar.gz/assembly/platform/coco-data-lake/research/clinical-trials/teddy-bear-drop-foot/weekly-measurements/PROJ-CT-TBDF_000000.csv_angleRight_column**&quot;}
# 27==&gt;|&quot;copy [Data Mapping
#     <div>
#                 <h3 id="mermaid-graph-1f71e403-1187-4f03-a1dd-ae7dc105f06f-69b5-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Information Supply Chain - Clinical Trial Treatment Validation::{{clinicalTrialId}}
#                 </h3>
#                 <p id="mermaid-graph-1f71e403-1187-4f03-a1dd-ae7dc105f06f-69b5-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 1f71e403-1187-4f03-a1dd-ae7dc105f06f
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# subgraph 1 [Details]
# subgraph 2 [Segments]
# 3@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Weekly Measurements Onboarding**&quot;}
# 3==&gt;|&quot;capture and catalog,
# [Information Supply Chain Link]&quot;|4
# 5@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Assess Treatment under Trial**&quot;}
# 5==&gt;|&quot;publish results,
# [Information Supply Chain Link]&quot;|6
# 7@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Hospital Delivers Patient Weekly Readings**&quot;}
# 7==&gt;|&quot;publish,
# [Information Supply Chain Link]&quot;|3
# 6@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Deliver Treatment Assessment Report**&quot;}
# 4@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Data Lake to Sandbox**&quot;}
# 4==&gt;|&quot;assemble,
# [Information Supply Chain Link]&quot;|5
# end
# subgraph 8 [Design]
# 9@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Hospital Landing Area Folder::V1.0**&quot;}
# 10@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Weekly Measurements Onboarding Pipeline::V1.0**&quot;}
# 11@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Landing Folder Cataloguer::V1.0**&quot;}
# 12@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Weekly Measurements Data Lake Folder::V1.0**&quot;}
# 13@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Treatment Efficacy Evidence::V1.0**&quot;}
# 14@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Analyse Patient Data::V1.0**&quot;}
# 15@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Treatment Validation Sandbox::V1.0**&quot;}
# 16@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Hospital Processes::V1.0**&quot;}
# 17@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Assemble Treatment Assessment Report::V1.0**&quot;}
# 18@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Treatment Assessment Report Validation and Delivery::V1.0**&quot;}
# 19@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Populate Sandbox::V1.0**&quot;}
# 3--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|9
# 3--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|10
# 3--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|11
# 3--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|12
# 9==&gt;|&quot;detect new files,
# [Solution Linking Wire]&quot;|11
# 16==&gt;|&quot;publish,
# [Solution Linking Wire]&quot;|9
# 11==&gt;|&quot;request onboarding,
# [Solution Linking Wire]&quot;|10
# 10==&gt;|&quot;save new files,
# [Solution Linking Wire]&quot;|12
# 12==&gt;|&quot;read certified files,
# [Solution Linking Wire]&quot;|19
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|13
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|14
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|15
# 13==&gt;|&quot;retrieve evidence,
# [Solution Linking Wire]&quot;|17
# 14==&gt;|&quot;publish results,
# [Solution Linking Wire]&quot;|13
# 15==&gt;|&quot;retrieve patient data,
# [Solution Linking Wire]&quot;|14
# 19==&gt;|&quot;write patient measurements,
# [Solution Linking Wire]&quot;|15
# 7--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|9
# 7--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|16
# 6--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|17
# 6--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|13
# 6--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|18
# 17==&gt;|&quot;publish results,
# [Solution Linking Wire]&quot;|18
# 4--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|12
# 4--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|19
# 4--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|15
# end
# end
# subgraph 20 [Overview]
# 21@{ shape: card, label: &quot;*Information Supply Chain*
# **Clinical Trial Treatment Validation::{{clinicalTrialId}}**&quot;}
# 22@{ shape: text, label: &quot;*Description*
# **Delivering data relating to the {{clinicalTrialName}} clinical trial from the hospitals to the Coco Researchers so that they can then determine the efficacy of the treatment to report to the regulators.**&quot;}
# 23@{ shape: text, label: &quot;*Purpose*
# **Deliver patient measurement data from hospitals to data scientists in research.**&quot;}
# 24@{ shape: text, label: &quot;*Purpose*
# **Ensure incoming data is only from certified hospitals.**&quot;}
# 25@{ shape: text, label: &quot;*Purpose*
# **Ensure incoming data is validated and catalogued.**&quot;}
# 26@{ shape: text, label: &quot;*Purpose*
# **Ensure data and process owners are informed of key milestones and issues requiring attention.**&quot;}
# 27@{ shape: text, label: &quot;*Purpose*
# **Ensure the process of data capture and treatment validation is transparent and auditable.**&quot;}
# 28@{ shape: text, label: &quot;*Purpose*
# **Ensure the treatment validation report is complete and regulatory compliant.**&quot;}
# end
# 20~~~1
# style 22 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 23 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 24 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 25 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 26 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 27 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 28 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 10 color:#000000, fill:#dda0dd, stroke:#000000
# style 11 color:#000000, fill:#dda0dd, stroke:#000000
# style 12 color:#000000, fill:#dda0dd, stroke:#000000
# style 13 color:#000000, fill:#dda0dd, stroke:#000000
# style 14 color:#000000, fill:#dda0dd, stroke:#000000
# style 15 color:#000000, fill:#dda0dd, stroke:#000000
# style 16 color:#000000, fill:#dda0dd, stroke:#000000
# style 17 color:#000000, fill:#dda0dd, stroke:#000000
# style 18 color:#000000, fill:#dda0dd, stroke:#000000
# style 19 color:#000000, fill:#dda0dd, stroke:#000000
# style 1 color:#FFFFFF, fill:#FFFFFF, stroke:#FFFFFF
# style 2 color:#004563, fill:#FFFFFF, stroke:#004563
# style 3 color:#004563, fill:#b7c0c7, stroke:#004563
# style 4 color:#004563, fill:#b7c0c7, stroke:#004563
# style 5 color:#004563, fill:#b7c0c7, stroke:#004563
# style 6 color:#004563, fill:#b7c0c7, stroke:#004563
# style 7 color:#004563, fill:#b7c0c7, stroke:#004563
# style 8 color:#000000, fill:#b0c4de, stroke:#000000
# style 9 color:#000000, fill:#dda0dd, stroke:#000000
# style 20 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 21 color:#004563, fill:#b0e0e6, stroke:#004563
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_information_supply_chains(egeria_tech, "Sustainability Reporting", add_implementation=False)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-dd15b286-a38d-4f03-8625-aaded8596048-b280-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Information Supply Chain - Sustainability Reporting
#                 </h3>
#                 <p id="mermaid-graph-dd15b286-a38d-4f03-8625-aaded8596048-b280-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: dd15b286-a38d-4f03-8625-aaded8596048
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# subgraph 1 [Details]
# subgraph 2 [Segments]
# 3@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Sustainability Report Delivery**&quot;}
# 4@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Sustainability Assessment**&quot;}
# 4==&gt;|&quot;publish report,
# [Information Supply Chain Link]&quot;|3
# 5@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Sustainability Data Gathering**&quot;}
# 5==&gt;|&quot;deliver data,
# [Information Supply Chain Link]&quot;|4
# end
# subgraph 6 [Design]
# 7@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Sustainability Dashboards::V1.0**&quot;}
# 8@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Sustainability Calculators::V1.0**&quot;}
# 9@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Sustainability Operational Data Store (ODS)::V1.0**&quot;}
# 10@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Goods Inventory::V1.0**&quot;}
# 11@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Accounting ledgers::V1.0**&quot;}
# 12@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Employee Expense Tool::V1.0**&quot;}
# 13@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Hazardous Materials (HazMat) Inventory::V1.0**&quot;}
# 3--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|7
# 9==&gt;|&quot;report request,
# [Solution Linking Wire]&quot;|7
# 4--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|8
# 4--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|9
# 8==&gt;|&quot;results publishing,
# [Solution Linking Wire]&quot;|9
# 9==&gt;|&quot;raw data request,
# [Solution Linking Wire]&quot;|8
# 11==&gt;|&quot;spending types,
# [Solution Linking Wire]&quot;|9
# 13==&gt;|&quot;publish hazmat levels,
# [Solution Linking Wire]&quot;|9
# 10==&gt;|&quot;goods movement,
# [Solution Linking Wire]&quot;|9
# 12==&gt;|&quot;travel inventory,
# [Solution Linking Wire]&quot;|9
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|10
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|9
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|11
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|12
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|13
# end
# end
# subgraph 14 [Overview]
# 15@{ shape: flip-tri, label: &quot;*Information Supply Chain*
# **Sustainability Reporting**&quot;}
# 16@{ shape: text, label: &quot;*Description*
# **Delivering information to the sustainability reporting tools.**&quot;}
# 17@{ shape: text, label: &quot;*Purpose*
# **Ensuring sustainability reporting is accurate.**&quot;}
# end
# 14~~~1
# style 11 color:#000000, fill:#dda0dd, stroke:#000000
# style 12 color:#000000, fill:#dda0dd, stroke:#000000
# style 13 color:#000000, fill:#dda0dd, stroke:#000000
# style 14 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 15 color:#FFFFFF, fill:#004563, stroke:#b7c0c7
# style 16 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 17 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 1 color:#FFFFFF, fill:#FFFFFF, stroke:#FFFFFF
# style 2 color:#004563, fill:#FFFFFF, stroke:#004563
# style 3 color:#004563, fill:#b7c0c7, stroke:#004563
# style 4 color:#004563, fill:#b7c0c7, stroke:#004563
# style 5 color:#004563, fill:#b7c0c7, stroke:#004563
# style 6 color:#000000, fill:#b0c4de, stroke:#000000
# style 7 color:#000000, fill:#dda0dd, stroke:#000000
# style 8 color:#000000, fill:#dda0dd, stroke:#000000
# style 9 color:#000000, fill:#dda0dd, stroke:#000000
# style 10 color:#000000, fill:#dda0dd, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_information_supply_chains(egeria_tech, "Sustainability Reporting", add_implementation=True)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-dd15b286-a38d-4f03-8625-aaded8596048-62fe-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Information Supply Chain - Sustainability Reporting
#                 </h3>
#                 <p id="mermaid-graph-dd15b286-a38d-4f03-8625-aaded8596048-62fe-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: dd15b286-a38d-4f03-8625-aaded8596048
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# subgraph 1 [Details]
# subgraph 2 [Segments]
# 3@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Sustainability Report Delivery**&quot;}
# 4@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Sustainability Assessment**&quot;}
# 4==&gt;|&quot;publish report,
# [Information Supply Chain Link]&quot;|3
# 5@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Sustainability Data Gathering**&quot;}
# 5==&gt;|&quot;deliver data,
# [Information Supply Chain Link]&quot;|4
# end
# subgraph 6 [Design]
# 7@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Sustainability Dashboards::V1.0**&quot;}
# 8@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Sustainability Calculators::V1.0**&quot;}
# 9@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Sustainability Operational Data Store (ODS)::V1.0**&quot;}
# 10@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Goods Inventory::V1.0**&quot;}
# 11@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Accounting ledgers::V1.0**&quot;}
# 12@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Employee Expense Tool::V1.0**&quot;}
# 13@{ shape: rect, label: &quot;*Solution Component*
# **SolutionComponent::Hazardous Materials (HazMat) Inventory::V1.0**&quot;}
# 3--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|7
# 9==&gt;|&quot;report request,
# [Solution Linking Wire]&quot;|7
# 4--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|8
# 4--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|9
# 8==&gt;|&quot;results publishing,
# [Solution Linking Wire]&quot;|9
# 9==&gt;|&quot;raw data request,
# [Solution Linking Wire]&quot;|8
# 11==&gt;|&quot;spending types,
# [Solution Linking Wire]&quot;|9
# 13==&gt;|&quot;publish hazmat levels,
# [Solution Linking Wire]&quot;|9
# 10==&gt;|&quot;goods movement,
# [Solution Linking Wire]&quot;|9
# 12==&gt;|&quot;travel inventory,
# [Solution Linking Wire]&quot;|9
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|10
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|9
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|11
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|12
# 5--&gt;|&quot;Supporting Supply Chain,
# [Implemented By]&quot;|13
# end
# subgraph 14 [Implementation]
# 15@{ shape: rounded, label: &quot;*Software Server*
# **System::coco-haz-mat**&quot;}
# 16@{ shape: rounded, label: &quot;*Software Server*
# **System::coco-sus**&quot;}
# 15==&gt;|&quot;publish hazmat levels [Data Flow]&quot;|16
# 17@{ shape: rounded, label: &quot;*Software Server*
# **System::coco-ledgers**&quot;}
# 17==&gt;|&quot;spending types [Data Flow]&quot;|16
# 18@{ shape: rounded, label: &quot;*Software Server*
# **System::coco-sus-dashboards**&quot;}
# 16==&gt;|&quot;report request [Data Flow]&quot;|18
# 19@{ shape: rounded, label: &quot;*Software Server*
# **System::coco-expenses**&quot;}
# 19==&gt;|&quot;travel inventory [Data Flow]&quot;|16
# 20@{ shape: rounded, label: &quot;*Software Server*
# **System::coco-sus-calculators**&quot;}
# 16==&gt;|&quot;raw data request [Data Flow]&quot;|20
# 20==&gt;|&quot;results publishing [Data Flow]&quot;|16
# 21@{ shape: rounded, label: &quot;*Software Server*
# **System::austin-haz-mat**&quot;}
# 21==&gt;|&quot;publish hazmat levels [Data Flow]&quot;|16
# 22@{ shape: rounded, label: &quot;*Software Server*
# **System::aus-inventory**&quot;}
# 22==&gt;|&quot;goods movement [Data Flow]&quot;|16
# 23@{ shape: rounded, label: &quot;*Software Server*
# **System::coco-inventory**&quot;}
# 23==&gt;|&quot;goods movement [Data Flow]&quot;|16
# end
# end
# subgraph 24 [Overview]
# 25@{ shape: flip-tri, label: &quot;*Information Supply Chain*
# **Sustainability Reporting**&quot;}
# 26@{ shape: text, label: &quot;*Description*
# **Delivering information to the sustainability reporting tools.**&quot;}
# 27@{ shape: text, label: &quot;*Purpose*
# **Ensuring sustainability reporting is accurate.**&quot;}
# end
# 24~~~1
# style 22 color:#000000, fill:#e0ab18, stroke:#004563
# style 23 color:#000000, fill:#e0ab18, stroke:#004563
# style 24 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 25 color:#FFFFFF, fill:#004563, stroke:#b7c0c7
# style 26 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 27 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 10 color:#000000, fill:#dda0dd, stroke:#000000
# style 11 color:#000000, fill:#dda0dd, stroke:#000000
# style 12 color:#000000, fill:#dda0dd, stroke:#000000
# style 13 color:#000000, fill:#dda0dd, stroke:#000000
# style 14 color:#004563, fill:#b7c0c7, stroke:#004563
# style 15 color:#000000, fill:#e0ab18, stroke:#004563
# style 16 color:#000000, fill:#e0ab18, stroke:#004563
# style 17 color:#000000, fill:#e0ab18, stroke:#004563
# style 18 color:#000000, fill:#e0ab18, stroke:#004563
# style 19 color:#000000, fill:#e0ab18, stroke:#004563
# style 1 color:#FFFFFF, fill:#FFFFFF, stroke:#FFFFFF
# style 2 color:#004563, fill:#FFFFFF, stroke:#004563
# style 3 color:#004563, fill:#b7c0c7, stroke:#004563
# style 4 color:#004563, fill:#b7c0c7, stroke:#004563
# style 5 color:#004563, fill:#b7c0c7, stroke:#004563
# style 6 color:#000000, fill:#b0c4de, stroke:#000000
# style 7 color:#000000, fill:#dda0dd, stroke:#000000
# style 8 color:#000000, fill:#dda0dd, stroke:#000000
# style 9 color:#000000, fill:#dda0dd, stroke:#000000
# style 20 color:#000000, fill:#e0ab18, stroke:#004563
# style 21 color:#000000, fill:#e0ab18, stroke:#004563
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_information_supply_chains(egeria_tech, "New Employee Onboarding", add_implementation=True)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-022009d9-53cb-4469-afeb-16ee81d8f9bc-e7b2-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Information Supply Chain - New Employee Onboarding
#                 </h3>
#                 <p id="mermaid-graph-022009d9-53cb-4469-afeb-16ee81d8f9bc-e7b2-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 022009d9-53cb-4469-afeb-16ee81d8f9bc
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# subgraph 1 [Details]
# subgraph 2 [Implementation]
# 3@{ shape: rounded, label: &quot;*Software Server*
# **System::coco-hrim**&quot;}
# 4@{ shape: rounded, label: &quot;*Software Server*
# **System::Netherlands payroll**&quot;}
# 3==&gt;|&quot;payment authorization [Data Flow]&quot;|4
# 5@{ shape: rounded, label: &quot;*Software Server*
# **System::cocopages**&quot;}
# 3==&gt;|&quot;employee directory [Data Flow]&quot;|5
# 6@{ shape: rounded, label: &quot;*Software Server*
# **System::Canadian payroll**&quot;}
# 3==&gt;|&quot;payment authorization [Data Flow]&quot;|6
# 7@{ shape: rounded, label: &quot;*Software Server*
# **System::UK payroll**&quot;}
# 3==&gt;|&quot;payment authorization [Data Flow]&quot;|7
# end
# end
# subgraph 8 [Overview]
# 9@{ shape: flip-tri, label: &quot;*Information Supply Chain*
# **New Employee Onboarding**&quot;}
# 10@{ shape: text, label: &quot;*Description*
# **Adding information about a new employee to all appropriate systems and directories.**&quot;}
# 11@{ shape: text, label: &quot;*Purpose*
# **Ensure a new employee is productive and engaged in a timely manner.**&quot;}
# end
# 8~~~1
# style 11 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 1 color:#FFFFFF, fill:#FFFFFF, stroke:#FFFFFF
# style 2 color:#004563, fill:#b7c0c7, stroke:#004563
# style 3 color:#000000, fill:#e0ab18, stroke:#004563
# style 4 color:#000000, fill:#e0ab18, stroke:#004563
# style 5 color:#000000, fill:#e0ab18, stroke:#004563
# style 6 color:#000000, fill:#e0ab18, stroke:#004563
# style 7 color:#000000, fill:#e0ab18, stroke:#004563
# style 8 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 9 color:#FFFFFF, fill:#004563, stroke:#b7c0c7
# style 10 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_solution_blueprints(egeria_tech, "Sustainability Reporting Solution Blueprint")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-aed5c289-6e81-4cf8-8852-752005eee0c4-dac4-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Components and Roles for Solution Blueprint - Sustainability Reporting Solution Blueprint
#                 </h3>
#                 <p id="mermaid-graph-aed5c289-6e81-4cf8-8852-752005eee0c4-dac4-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: aed5c289-6e81-4cf8-8852-752005eee0c4
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# subgraph 1 [Components and Actors]
# 2@{ shape: text, label: &quot;*Description*
# **A description of how data is gathered to support sustainability reporting in Coco Pharmaceuticals.**&quot;}
# 3@{ shape: subproc, label: &quot;*Solution Component*
# **Sustainability Operational Data Store (ODS)**&quot;}
# 4@{ shape: rect, label: &quot;*Solution Component*
# **Accounting ledgers**&quot;}
# 4==&gt;|&quot;spending types,
# [Solution Linking Wire]&quot;|3
# 5@{ shape: rect, label: &quot;*Solution Component*
# **Sustainability Calculators**&quot;}
# 5==&gt;|&quot;results publishing,
# [Solution Linking Wire]&quot;|3
# 6@{ shape: rect, label: &quot;*Solution Component*
# **Hazardous Materials (HazMat) Inventory**&quot;}
# 6==&gt;|&quot;publish hazmat levels,
# [Solution Linking Wire]&quot;|3
# 7@{ shape: rect, label: &quot;*Solution Component*
# **Goods Inventory**&quot;}
# 7==&gt;|&quot;goods movement,
# [Solution Linking Wire]&quot;|3
# 8@{ shape: rect, label: &quot;*Solution Component*
# **Employee Expense Tool**&quot;}
# 8==&gt;|&quot;travel inventory,
# [Solution Linking Wire]&quot;|3
# 9@{ shape: rect, label: &quot;*Solution Component*
# **Sustainability Dashboards**&quot;}
# 3==&gt;|&quot;report request,
# [Solution Linking Wire]&quot;|9
# 3==&gt;|&quot;raw data request,
# [Solution Linking Wire]&quot;|5
# 10@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Sustainability Champion**&quot;}
# 10==&gt;|&quot;Review Status&quot;|9
# 11@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Sustainability Executive**&quot;}
# 11==&gt;|&quot;Review Status&quot;|9
# 12@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Sustainability Leader**&quot;}
# 12==&gt;|&quot;Review Status&quot;|9
# end
# style 11 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 1 color:#FFFFFF, fill:#3079ab, stroke:#000000
# style 12 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#dda0dd, stroke:#000000
# style 4 color:#000000, fill:#dda0dd, stroke:#000000
# style 5 color:#000000, fill:#dda0dd, stroke:#000000
# style 6 color:#000000, fill:#dda0dd, stroke:#000000
# style 7 color:#000000, fill:#dda0dd, stroke:#000000
# style 8 color:#000000, fill:#dda0dd, stroke:#000000
# style 9 color:#000000, fill:#dda0dd, stroke:#000000
# style 10 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_solution_blueprints(egeria_tech, "Clinical Trial Management Solution Blueprint")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-c4f8d707-7c85-4125-b5fd-c3257a2ef2ef-836c-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Components and Roles for Solution Blueprint - Clinical Trial Management Solution Blueprint
#                 </h3>
#                 <p id="mermaid-graph-c4f8d707-7c85-4125-b5fd-c3257a2ef2ef-836c-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: c4f8d707-7c85-4125-b5fd-c3257a2ef2ef
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# subgraph 1 [Components and Actors]
# 2@{ shape: text, label: &quot;*Description*
# **A description of how a clinical trial is managed in Coco Pharmaceuticals.**&quot;}
# 3@{ shape: subproc, label: &quot;*Solution Component*
# **Certify Hospital**&quot;}
# 4@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Clinical Trial Manager**&quot;}
# 4==&gt;|&quot;Certifier&quot;|3
# 5@{ shape: docs, label: &quot;*Solution Component*
# **Assemble Treatment Assessment Report**&quot;}
# 6@{ shape: rect, label: &quot;*Solution Component*
# **Treatment Efficacy Evidence**&quot;}
# 6==&gt;|&quot;retrieve evidence,
# [Solution Linking Wire]&quot;|5
# 7@{ shape: rect, label: &quot;*Solution Component*
# **Treatment Assessment Report Validation and Delivery**&quot;}
# 5==&gt;|&quot;publish results,
# [Solution Linking Wire]&quot;|7
# 8@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **New Treatment Researcher**&quot;}
# 8==&gt;|&quot;Author&quot;|5
# 4==&gt;|&quot;Reviewer&quot;|5
# 9@{ shape: rect, label: &quot;*Solution Component*
# **Analyse Patient Data**&quot;}
# 9==&gt;|&quot;publish results,
# [Solution Linking Wire]&quot;|6
# 10@{ shape: subproc, label: &quot;*Solution Component*
# **Weekly Measurements Onboarding Pipeline**&quot;}
# 11@{ shape: rect, label: &quot;*Solution Component*
# **Landing Folder Cataloguer**&quot;}
# 11==&gt;|&quot;request onboarding,
# [Solution Linking Wire]&quot;|10
# 12@{ shape: rect, label: &quot;*Solution Component*
# **Weekly Measurements Data Lake Folder**&quot;}
# 10==&gt;|&quot;save new files,
# [Solution Linking Wire]&quot;|12
# 4==&gt;|&quot;Steward&quot;|10
# 13@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Certified Data Engineer**&quot;}
# 13==&gt;|&quot;Steward&quot;|10
# 14@{ shape: lin-cyl, label: &quot;*Solution Component*
# **Treatment Validation Sandbox**&quot;}
# 15@{ shape: rect, label: &quot;*Solution Component*
# **Populate Sandbox**&quot;}
# 15==&gt;|&quot;write patient measurements,
# [Solution Linking Wire]&quot;|14
# 14==&gt;|&quot;retrieve patient data,
# [Solution Linking Wire]&quot;|9
# 16@{ shape: processes, label: &quot;*Solution Component*
# **Hospital Processes**&quot;}
# 17@{ shape: rect, label: &quot;*Solution Component*
# **Hospital Landing Area Folder**&quot;}
# 16==&gt;|&quot;publish,
# [Solution Linking Wire]&quot;|17
# 18@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Clinical Trial Participating Hospital Coordinator**&quot;}
# 18==&gt;|&quot;Coordinator on behalf of hospital&quot;|16
# 19@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Clinical Trial Participating Hospital**&quot;}
# 19==&gt;|&quot;Owner&quot;|16
# 20@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **New Treatment Data Scientist**&quot;}
# 20==&gt;|&quot;Data Analyser&quot;|9
# 8==&gt;|&quot;Results Interpreter&quot;|9
# 21@{ shape: subproc, label: &quot;*Solution Component*
# **Onboard Hospital**&quot;}
# 13==&gt;|&quot;Initiator&quot;|21
# 22@{ shape: subproc, label: &quot;*Solution Component*
# **Set up clinical trial**&quot;}
# 23@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Clinical Trial Sponsor**&quot;}
# 23==&gt;|&quot;Initiator&quot;|22
# 12==&gt;|&quot;read certified files,
# [Solution Linking Wire]&quot;|15
# 23==&gt;|&quot;Reviewer&quot;|7
# 24@{ shape: subproc, label: &quot;*Solution Component*
# **Set up Data Lake**&quot;}
# 13==&gt;|&quot;Initiator&quot;|24
# 17==&gt;|&quot;detect new files,
# [Solution Linking Wire]&quot;|11
# 25@{ shape: subproc, label: &quot;*Solution Component*
# **Nominate Hospital**&quot;}
# 4==&gt;|&quot;Initiator&quot;|25
# end
# style 22 color:#000000, fill:#dda0dd, stroke:#000000
# style 23 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 24 color:#000000, fill:#dda0dd, stroke:#000000
# style 25 color:#000000, fill:#dda0dd, stroke:#000000
# style 10 color:#000000, fill:#dda0dd, stroke:#000000
# style 11 color:#000000, fill:#dda0dd, stroke:#000000
# style 12 color:#000000, fill:#dda0dd, stroke:#000000
# style 13 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 14 color:#000000, fill:#dda0dd, stroke:#000000
# style 15 color:#000000, fill:#dda0dd, stroke:#000000
# style 16 color:#000000, fill:#dda0dd, stroke:#000000
# style 17 color:#000000, fill:#dda0dd, stroke:#000000
# style 18 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 19 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 1 color:#FFFFFF, fill:#3079ab, stroke:#000000
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#dda0dd, stroke:#000000
# style 4 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 5 color:#000000, fill:#dda0dd, stroke:#000000
# style 6 color:#000000, fill:#dda0dd, stroke:#000000
# style 7 color:#000000, fill:#dda0dd, stroke:#000000
# style 8 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 9 color:#000000, fill:#dda0dd, stroke:#000000
# style 20 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 21 color:#000000, fill:#dda0dd, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_solution_roles(egeria_tech, "Clinical Trial Manager")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-f37f3735-28a1-4e03-9ff5-3fe2f137f661-f4e1-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Solution Components for Solution Role - Clinical Trial Manager
#                 </h3>
#                 <p id="mermaid-graph-f37f3735-28a1-4e03-9ff5-3fe2f137f661-f4e1-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: f37f3735-28a1-4e03-9ff5-3fe2f137f661
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Clinical Trial Manager**&quot;}
# 2@{ shape: rect, label: &quot;*Solution Component*
# **Nominate Hospital**&quot;}
# 1==&gt;|&quot;Initiator&quot;|2
# 3@{ shape: rect, label: &quot;*Solution Component*
# **Weekly Measurements Onboarding Pipeline**&quot;}
# 1==&gt;|&quot;Steward&quot;|3
# 4@{ shape: rect, label: &quot;*Solution Component*
# **Certify Hospital**&quot;}
# 1==&gt;|&quot;Certifier&quot;|4
# 5@{ shape: rect, label: &quot;*Solution Component*
# **Assemble Treatment Assessment Report**&quot;}
# 1==&gt;|&quot;Reviewer&quot;|5
# style 1 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 2 color:#000000, fill:#dda0dd, stroke:#000000
# style 3 color:#000000, fill:#dda0dd, stroke:#000000
# style 4 color:#000000, fill:#dda0dd, stroke:#000000
# style 5 color:#000000, fill:#dda0dd, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_solution_roles(egeria_tech, "Clinical Trial Sponsor")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-f6bc847b-868d-43cc-b767-41f5fe3e47d1-a8ce-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Solution Components for Solution Role - Clinical Trial Sponsor
#                 </h3>
#                 <p id="mermaid-graph-f6bc847b-868d-43cc-b767-41f5fe3e47d1-a8ce-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: f6bc847b-868d-43cc-b767-41f5fe3e47d1
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Clinical Trial Sponsor**&quot;}
# 2@{ shape: rect, label: &quot;*Solution Component*
# **Set up clinical trial**&quot;}
# 1==&gt;|&quot;Initiator&quot;|2
# 3@{ shape: rect, label: &quot;*Solution Component*
# **Treatment Assessment Report Validation and Delivery**&quot;}
# 1==&gt;|&quot;Reviewer&quot;|3
# style 1 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 2 color:#000000, fill:#dda0dd, stroke:#000000
# style 3 color:#000000, fill:#dda0dd, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_solution_components(egeria_tech, "Set up clinical trial")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-849b0b42-f465-452b-813c-477d6398e082-0b28-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Solution Component - Set up clinical trial
#                 </h3>
#                 <p id="mermaid-graph-849b0b42-f465-452b-813c-477d6398e082-0b28-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 849b0b42-f465-452b-813c-477d6398e082
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: text, label: &quot;*Description*
# **Generates the project, and governance action processes needed to drive a clinical trial.**&quot;}
# 2@{ shape: subproc, label: &quot;*Solution Component*
# **Set up clinical trial**&quot;}
# 3@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Clinical Trial Sponsor**&quot;}
# 3==&gt;|&quot;Initiator&quot;|2
# 4@{ shape: lin-doc, label: &quot;*Solution Blueprint*
# **Clinical Trial Management Solution Blueprint**&quot;}
# 4==&gt;|&quot;Solution Blueprint&quot;|2
# 5@{ shape: rounded, label: &quot;*Governance  Action  Type*
# **set-up-clinical-trial (ClinicalTrials@CocoPharmaceuticals)**&quot;}
# 2==&gt;|&quot;Implemented By&quot;|5
# style 1 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 2 color:#000000, fill:#dda0dd, stroke:#000000
# style 3 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 4 color:#FFFFFF, fill:#3079ab, stroke:#000000
# style 5 color:#000000, fill:#e0ab18, stroke:#004563
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_solution_components(egeria_tech, "Pipeline")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-7f5dca65-50b4-4103-9ac7-3a406a09047a-7eec-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Solution Component - Weekly Measurements Onboarding Pipeline
#                 </h3>
#                 <p id="mermaid-graph-7f5dca65-50b4-4103-9ac7-3a406a09047a-7eec-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 7f5dca65-50b4-4103-9ac7-3a406a09047a
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# c8ee5fa5-7780-4fbf-8247-9a32c255427e@{ shape: text, label: &quot;*Description*
# **Move landing area files to data lake, catalog files in data lake with lineage from the landing area and validate/certify that the data contains valid values.  The cataloguing includes lineage, retention, origin, governance zones.  The quality validation survey will add a certification to the file asset if the data contains valid values.**&quot;}
# 7f5dca65-50b4-4103-9ac7-3a406a09047a@{ shape: subproc, label: &quot;*Solution Component*
# **Weekly Measurements Onboarding Pipeline**&quot;}
# 07705e15-efff-4f80-8992-f04ac85e0ef1@{ shape: rect, label: &quot;*Solution Component*
# **Landing Folder Cataloguer**&quot;}
# 07705e15-efff-4f80-8992-f04ac85e0ef1==&gt;|&quot;request onboarding,
# [Solution Linking Wire]&quot;|7f5dca65-50b4-4103-9ac7-3a406a09047a
# a5d4d638-6836-47e5-99d0-fdcde637e13f@{ shape: rect, label: &quot;*Solution Component*
# **Weekly Measurements Data Lake Folder**&quot;}
# 7f5dca65-50b4-4103-9ac7-3a406a09047a==&gt;|&quot;save new files,
# [Solution Linking Wire]&quot;|a5d4d638-6836-47e5-99d0-fdcde637e13f
# f37f3735-28a1-4e03-9ff5-3fe2f137f661@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Clinical Trial Manager**&quot;}
# f37f3735-28a1-4e03-9ff5-3fe2f137f661==&gt;|&quot;Steward&quot;|7f5dca65-50b4-4103-9ac7-3a406a09047a
# b0290339-c96c-4b05-904f-12fc98e54e14@{ shape: trap-t, label: &quot;*Solution Actor Role*
# **Certified Data Engineer**&quot;}
# b0290339-c96c-4b05-904f-12fc98e54e14==&gt;|&quot;Steward&quot;|7f5dca65-50b4-4103-9ac7-3a406a09047a
# c4f8d707-7c85-4125-b5fd-c3257a2ef2ef@{ shape: notch-rect, label: &quot;*Solution Blueprint*
# **Clinical Trial Management Solution Blueprint**&quot;}
# c4f8d707-7c85-4125-b5fd-c3257a2ef2ef==&gt;|&quot;Solution Blueprint&quot;|7f5dca65-50b4-4103-9ac7-3a406a09047a
# 38635d38-f728-400d-a8ec-7c26e68b7c0f@{ shape: hex, label: &quot;*Information Supply Chain Segment*
# **Weekly Measurements Onboarding**&quot;}
# 38635d38-f728-400d-a8ec-7c26e68b7c0f==&gt;|&quot;Implemented By&quot;|7f5dca65-50b4-4103-9ac7-3a406a09047a
# 1f71e403-1187-4f03-a1dd-ae7dc105f06f@{ shape: flip-tri, label: &quot;*Information Supply Chain*
# **Clinical Trial Treatment Validation:{{clinicalTrialId}}**&quot;}
# 1f71e403-1187-4f03-a1dd-ae7dc105f06f==&gt;|&quot;InformationSupplyChainComposition&quot;|38635d38-f728-400d-a8ec-7c26e68b7c0f
# subgraph Subcomponents
# b1fd8336-45ca-4e2e-bd79-ce6601c0b68f@{ shape: subproc, label: &quot;*Solution Component*
# **Report Quality Issues**&quot;}
# 2a5763d0-c540-4a59-8268-db7c88342269@{ shape: rect, label: &quot;*Solution Component*
# **Check Quality of Data**&quot;}
# 2a5763d0-c540-4a59-8268-db7c88342269==&gt;|&quot;quality analysis complete,
# [Solution Linking Wire]&quot;|b1fd8336-45ca-4e2e-bd79-ce6601c0b68f
# 22e35eff-fcc8-4baa-804e-8363989cf6f1@{ shape: rect, label: &quot;*Solution Component*
# **Publish Asset**&quot;}
# b1fd8336-45ca-4e2e-bd79-ce6601c0b68f==&gt;|&quot;quality assessment complete,
# [Solution Linking Wire]&quot;|22e35eff-fcc8-4baa-804e-8363989cf6f1
# 7bcf573b-0ad8-4ca8-82c0-8d8f50fac4cd@{ shape: subproc, label: &quot;*Solution Component*
# **Determine Origin of Data**&quot;}
# 18931474-d170-4394-97a9-0e627e2212ac@{ shape: rect, label: &quot;*Solution Component*
# **Move File To Data Lake**&quot;}
# 18931474-d170-4394-97a9-0e627e2212ac==&gt;|&quot;provisioning complete,
# [Solution Linking Wire]&quot;|7bcf573b-0ad8-4ca8-82c0-8d8f50fac4cd
# bed0ec86-45ce-4350-8c68-9596299c843a@{ shape: rect, label: &quot;*Solution Component*
# **Set Retention Period**&quot;}
# 7bcf573b-0ad8-4ca8-82c0-8d8f50fac4cd==&gt;|&quot;origin determined,
# [Solution Linking Wire]&quot;|bed0ec86-45ce-4350-8c68-9596299c843a
# 18931474-d170-4394-97a9-0e627e2212ac==&gt;|&quot;provisioning complete,
# [Solution Linking Wire]&quot;|2a5763d0-c540-4a59-8268-db7c88342269
# bed0ec86-45ce-4350-8c68-9596299c843a==&gt;|&quot;classifications assigned,
# [Solution Linking Wire]&quot;|22e35eff-fcc8-4baa-804e-8363989cf6f1
# end
# 7f5dca65-50b4-4103-9ac7-3a406a09047a ===&gt; Subcomponents
# style c4f8d707-7c85-4125-b5fd-c3257a2ef2ef color:#FFFFFF, fill:#3079ab, stroke:#000000
# style c8ee5fa5-7780-4fbf-8247-9a32c255427e color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 22e35eff-fcc8-4baa-804e-8363989cf6f1 color:#FFFFFF, fill:#838cc7, stroke:#E1D5E7
# style 2a5763d0-c540-4a59-8268-db7c88342269 color:#FFFFFF, fill:#838cc7, stroke:#E1D5E7
# style 7f5dca65-50b4-4103-9ac7-3a406a09047a color:#FFFFFF, fill:#838cc7, stroke:#E1D5E7
# style a5d4d638-6836-47e5-99d0-fdcde637e13f color:#FFFFFF, fill:#838cc7, stroke:#E1D5E7
# style b1fd8336-45ca-4e2e-bd79-ce6601c0b68f color:#FFFFFF, fill:#838cc7, stroke:#E1D5E7
# style bed0ec86-45ce-4350-8c68-9596299c843a color:#FFFFFF, fill:#838cc7, stroke:#E1D5E7
# style 38635d38-f728-400d-a8ec-7c26e68b7c0f color:#004563, fill:#b7c0c7, stroke:#004563
# style 18931474-d170-4394-97a9-0e627e2212ac color:#FFFFFF, fill:#838cc7, stroke:#E1D5E7
# style f37f3735-28a1-4e03-9ff5-3fe2f137f661 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style b0290339-c96c-4b05-904f-12fc98e54e14 color:#FFFFFF, fill:#AA00FF, stroke:#E1D5E7
# style 1f71e403-1187-4f03-a1dd-ae7dc105f06f color:#FFFFFF, fill:#004563, stroke:#b7c0c7
# style 7bcf573b-0ad8-4ca8-82c0-8d8f50fac4cd color:#FFFFFF, fill:#838cc7, stroke:#E1D5E7
# style Subcomponents color:#000000, fill:#E1D5E7, stroke:#000000
# style 07705e15-efff-4f80-8992-f04ac85e0ef1 color:#FFFFFF, fill:#838cc7, stroke:#E1D5E7
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>
