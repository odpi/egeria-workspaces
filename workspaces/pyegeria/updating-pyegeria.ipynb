# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Egeria Workbook
#
# # Updating pyegeria
#
# ## Introduction
#
# The `pyegeria` python library provides a wide-ranging set of python functions for interacting with the Egeria runtime.  In addition there is a command level interface (CLI) for issuing commands to Egeria and widgets to display information held by Egeria. The CLI and pyegeria commands are normally called from a terminal window. However, many of the functions can also be called within a Jupyter Notebook.
#
# This notebook ensures you have the latest level of pyegeria
#
# ## Updating JupyterLab
#
# Pyegeria is installed in this JupyterLab environment.  However, it is advancing rapidly and it is worthwhile checking that you have the latest level.  Firstly, to upgrade the base python functions, run the following command:
#
# -----

# %%
pip install pyegeria --upgrade
# Out:
# Requirement already satisfied: pyegeria in /opt/conda/lib/python3.13/site-packages (5.4.0.26)
# Collecting pyegeria
#   Downloading pyegeria-5.4.4.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.13/site-packages (from pyegeria) (8.2.1)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.13/site-packages (from pyegeria) (0.28.1)
# Requirement already satisfied: inflect<8.0.0,>=7.5.0 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (7.5.0)
# Requirement already satisfied: jupyter in /opt/conda/lib/python3.13/site-packages (from pyegeria) (1.1.1)
# Requirement already satisfied: jupyter-notebook-parser<0.2.0,>=0.1.4 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (0.1.4)
# Requirement already satisfied: loguru<0.8.0,>=0.7.3 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (0.7.3)
# Requirement already satisfied: mermaid-py in /opt/conda/lib/python3.13/site-packages (from pyegeria) (0.8.0)
# Requirement already satisfied: poetry-core<3.0.0,>=2.1.3 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (2.1.3)
# Requirement already satisfied: psycopg2-binary<3.0.0,>=2.9.9 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (2.9.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.7 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (2.11.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (2.10.1)
# Requirement already satisfied: pydevd-pycharm<253.0.0,>=252.23892.364 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (252.25557.70)
# Requirement already satisfied: pytest<9.0.0,>=8.3.5 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (8.4.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.13/site-packages (from pyegeria) (2.32.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.13/site-packages (from pyegeria) (14.1.0)
# Requirement already satisfied: textual in /opt/conda/lib/python3.13/site-packages (from pyegeria) (5.3.0)
# Requirement already satisfied: trogon<0.7.0,>=0.6.0 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (0.6.0)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (2.5.0)
# Requirement already satisfied: validators in /opt/conda/lib/python3.13/site-packages (from pyegeria) (0.35.0)
# Requirement already satisfied: wcwidth==0.2.13 in /opt/conda/lib/python3.13/site-packages (from pyegeria) (0.2.13)
# Requirement already satisfied: more_itertools>=8.5.0 in /opt/conda/lib/python3.13/site-packages (from inflect<8.0.0,>=7.5.0->pyegeria) (10.7.0)
# Requirement already satisfied: typeguard>=4.0.1 in /opt/conda/lib/python3.13/site-packages (from inflect<8.0.0,>=7.5.0->pyegeria) (4.4.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.11.7->pyegeria) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.11.7->pyegeria) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.11.7->pyegeria) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.11.7->pyegeria) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.10.1->pyegeria) (1.1.1)
# Requirement already satisfied: iniconfig>=1 in /opt/conda/lib/python3.13/site-packages (from pytest<9.0.0,>=8.3.5->pyegeria) (2.1.0)
# Requirement already satisfied: packaging>=20 in /opt/conda/lib/python3.13/site-packages (from pytest<9.0.0,>=8.3.5->pyegeria) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/conda/lib/python3.13/site-packages (from pytest<9.0.0,>=8.3.5->pyegeria) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /opt/conda/lib/python3.13/site-packages (from pytest<9.0.0,>=8.3.5->pyegeria) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.1.0 in /opt/conda/lib/python3.13/site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual->pyegeria) (4.0.0)
# Requirement already satisfied: platformdirs<5,>=3.6.0 in /opt/conda/lib/python3.13/site-packages (from textual->pyegeria) (4.3.8)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.13/site-packages (from markdown-it-py>=2.1.0->markdown-it-py[linkify,plugins]>=2.1.0->textual->pyegeria) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /opt/conda/lib/python3.13/site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual->pyegeria) (2.0.3)
# Requirement already satisfied: mdit-py-plugins>=0.5.0 in /opt/conda/lib/python3.13/site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual->pyegeria) (0.5.0)
# Requirement already satisfied: uc-micro-py in /opt/conda/lib/python3.13/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual->pyegeria) (1.0.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.13/site-packages (from httpx->pyegeria) (4.10.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.13/site-packages (from httpx->pyegeria) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.13/site-packages (from httpx->pyegeria) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.13/site-packages (from httpx->pyegeria) (3.10)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.13/site-packages (from httpcore==1.*->httpx->pyegeria) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.13/site-packages (from anyio->httpx->pyegeria) (1.3.1)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.13/site-packages (from jupyter->pyegeria) (7.4.5)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.13/site-packages (from jupyter->pyegeria) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.13/site-packages (from jupyter->pyegeria) (7.16.6)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.13/site-packages (from jupyter->pyegeria) (6.30.1)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.13/site-packages (from jupyter->pyegeria) (8.1.7)
# Requirement already satisfied: jupyterlab in /opt/conda/lib/python3.13/site-packages (from jupyter->pyegeria) (4.4.6)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (9.4.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (27.0.1)
# Requirement already satisfied: tornado>=6.2 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.13/site-packages (from ipykernel->jupyter->pyegeria) (5.14.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyegeria) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/conda/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyegeria) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyegeria) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyegeria) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyegeria) (3.0.51)
# Requirement already satisfied: stack_data in /opt/conda/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyegeria) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->pyegeria) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.13/site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter->pyegeria) (2.9.0.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->pyegeria) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel->jupyter->pyegeria) (1.17.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/conda/lib/python3.13/site-packages (from ipywidgets->jupyter->pyegeria) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/conda/lib/python3.13/site-packages (from ipywidgets->jupyter->pyegeria) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/conda/lib/python3.13/site-packages (from jupyterlab->jupyter->pyegeria) (2.0.5)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/conda/lib/python3.13/site-packages (from jupyterlab->jupyter->pyegeria) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/conda/lib/python3.13/site-packages (from jupyterlab->jupyter->pyegeria) (2.2.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/conda/lib/python3.13/site-packages (from jupyterlab->jupyter->pyegeria) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/conda/lib/python3.13/site-packages (from jupyterlab->jupyter->pyegeria) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/conda/lib/python3.13/site-packages (from jupyterlab->jupyter->pyegeria) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /opt/conda/lib/python3.13/site-packages (from jupyterlab->jupyter->pyegeria) (80.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/conda/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/conda/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/conda/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/conda/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/conda/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/conda/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/conda/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/conda/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/conda/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyegeria) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/conda/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyegeria) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/conda/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyegeria) (4.25.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.13/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->pyegeria) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyegeria) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyegeria) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyegeria) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->pyegeria) (0.27.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /opt/conda/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (1.1.0)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/conda/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.13/site-packages (from nbconvert->jupyter->pyegeria) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->pyegeria) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.13/site-packages (from nbconvert->jupyter->pyegeria) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.13/site-packages (from nbconvert->jupyter->pyegeria) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/lib/python3.13/site-packages (from nbconvert->jupyter->pyegeria) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.13/site-packages (from nbconvert->jupyter->pyegeria) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.13/site-packages (from nbconvert->jupyter->pyegeria) (1.5.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->pyegeria) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/conda/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->pyegeria) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.13/site-packages (from requests->pyegeria) (3.4.3)
# Requirement already satisfied: lark>=1.2.2 in /opt/conda/lib/python3.13/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (1.17.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.13/site-packages (from beautifulsoup4->nbconvert->jupyter->pyegeria) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->pyegeria) (2.9.0.20250809)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->pyegeria) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->pyegeria) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->pyegeria) (0.2.3)
# Downloading pyegeria-5.4.4.1-py3-none-any.whl (71.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 MB 6.9 MB/s  0:00:10m0:00:0100:01
# Installing collected packages: pyegeria
#   Attempting uninstall: pyegeria
#     Found existing installation: pyegeria 5.4.0.26
#     Uninstalling pyegeria-5.4.0.26:
#       Successfully uninstalled pyegeria-5.4.0.26
# Successfully installed pyegeria-5.4.4.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ----
# If the libraries are upgraded, you will need to restart the python kernel.  From the JupyterLab menubar select `Kernel->Restart Kernel...` and then confirm that you want the kernel to restart.
#
# ## Updating the command environment
#
# The next step is to check that the widgets and CLI are up-to-date.  For this you need a Terminal window.  Click on the plus (+) to open an new tab.  This displays the launcher page.  Then click on *Terminal* to open up the Terminal window.
#
# ----
#
# ![Launcher](images/launcher.png)
#
# ----
#
# From the Terminal window enter the command `pipx upgrade pyegeria` command.   This will upgrade the CLI if required.
#
# ```
# $ pipx upgrade pyegeria
# Upgraded package pyegeria from 0.7.45 to 0.8.4.1 (location: /home/jovyan/.local/share/venvs/pipx/pyegeria)
# $
#
# ```
#
# As a quick check to ensure the CLI is correctly installed, enter `pipx list` in the terminal window.  This will show all of the commands currently available.
#
# As pyegeria is being actively enhanced, the list of commands continues to grow and evolve.
#
#
#
# ----
