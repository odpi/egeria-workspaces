# %%
import asyncio
import nest_asyncio
nest_asyncio.apply()

# %%
# %run uc_catalog_viewer --url http://egeria.pdr-associates.com:8070
# Out:
#                                                                                UC OSS Catalog @ Thu Sep 19 07:11:32 2024
# ╭───────────────────────┬───────────────────────┬─────────────────────────────────┬────────────────────────────────┬────────────────────────────────────────────────────────────┬──────────────────────╮
# │ Catalog Name          │ Catalog Comment       │ Schema Name                     │ Schema Comment                 │ Vol/Tab                                                    │ Details              │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ clinical_trials       │ Clinical trials data  │ werewolf_transformation         │ New treatment for accelerating │ Volumes                                                    │                      │
# │                       │ for personalized      │                                 │ the recovery of a werewolf     │                                                            │                      │
# │                       │ medicine research.    │                                 │ after transformation.          │ * name: weekly_measurements                                │                      │
# │                       │                       │                                 │                                │         * comment: Weekly measurements for patients on     │                      │
# │                       │                       │                                 │                                │ clinical trial.  This data may only be used for this       │                      │
# │                       │                       │                                 │                                │ clinical trial.                                            │                      │
# │                       │                       │                                 │                                │         * created_at: 1726148414666                        │                      │
# │                       │                       │                                 │                                │         * updated_at: 1726148414666                        │                      │
# │                       │                       │                                 │                                │         * volume_id: d98918e7-068a-451c-8234-a0710a710f6a  │                      │
# │                       │                       │                                 │                                │         * volume_type: EXTERNAL                            │                      │
# │                       │                       │                                 │                                │         * storage_location:                                │                      │
# │                       │                       │                                 │                                │ file:///Users/amandachessell/coco_data_lake/clinical_tria… │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ clinical_trials       │ Clinical trials data  │ werewolf_transformation         │ New treatment for accelerating │ Tables                                                     │                      │
# │                       │ for personalized      │                                 │ the recovery of a werewolf     │                                                            │                      │
# │                       │ medicine research.    │                                 │ after transformation.          │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ data_office           │ Data management       │ project_purposes                │ Data from existing projects    │ Tables                                                     │                      │
# │                       │ history for Coco      │                                 │ that manage sensitive data.    │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │                                │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ finance               │ Historical financial  │ payroll                         │ Data from payroll for          │ Tables                                                     │                      │
# │                       │ data for Coco         │                                 │ analysis.                      │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │                                │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ haz_mat               │ History of hazardous  │ risk_analysis                   │ Historical haz mat data with   │ Tables                                                     │                      │
# │                       │ materials for Coco    │                                 │ risk analysis.                 │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │                                │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ hospital_delivery     │ Product delivery data │ patient_shipments               │ Details of the treatment       │ Tables                                                     │                      │
# │                       │ to hospitals for Coco │                                 │ packages sent to hospitals for │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │ individual patients.           │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ human_resources       │ Employee hiring,      │ payroll                         │ Data from payroll for analysis │ Tables                                                     │                      │
# │                       │ retention and         │                                 │ of cost, equity and assurance. │                                                            │                      │
# │                       │ termination for Coco  │                                 │                                │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │                                │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ inventory             │ Inventory levels from │ stock_shrinkage                 │ Data relating to the loss of   │ Tables                                                     │                      │
# │                       │ warehouses and        │                                 │ stock in the distribution      │                                                            │                      │
# │                       │ distribution points   │                                 │ network.  Includes pilfering   │                                                            │                      │
# │                       │ for Coco              │                                 │ of part shipments and theft of │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │ whole shipments.               │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ manufacturing         │ Manufacturing run     │ production_run_timings          │ Details of the production runs │ Tables                                                     │                      │
# │                       │ data from all         │                                 │ for each factory.              │                                                            │                      │
# │                       │ factories for Coco    │                                 │                                │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │                                │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ patient_treatment     │ Patient treatment     │ patient_recipes                 │ Details of the approved        │ Tables                                                     │                      │
# │                       │ data for Coco         │                                 │ recipes, their costs,          │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │ popularity and value.          │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ procurement           │ Supplier and          │ supplier_history                │ Details of  business partners  │ Tables                                                     │                      │
# │                       │ purchasing history    │                                 │ supplying goods and services.  │                                                            │                      │
# │                       │ for Coco              │                                 │                                │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │                                │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ security              │ Security's historical │ user_identities                 │ Historical inventories of user │ Tables                                                     │                      │
# │                       │ data for Coco         │                                 │ identities for Coco            │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │ Pharmaceuticals.               │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ sustainability_repor… │ Sustainability        │ sustainability_metrics          │ Sustainability metrics and     │ Tables                                                     │                      │
# │                       │ reporting for Coco    │                                 │ measures used in reporting.    │                                                            │                      │
# │                       │ Pharmaceuticals.      │                                 │                                │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ unity                 │ Main catalog          │ default                         │ Default schema                 │ Functions                                                  │                      │
# │                       │                       │                                 │                                │ * name: lowercase                                          │                      │
# │                       │                       │                                 │                                │         * comment: Converts a string to lowercase.         │                      │
# │                       │                       │                                 │                                │         * function_id:                                     │                      │
# │                       │                       │                                 │                                │ ebb706d6-7ba0-4b2e-8d9c-716d13fd57f8                       │                      │
# │                       │                       │                                 │                                │         * function_type: STRING                            │                      │
# │                       │                       │                                 │                                │         * sql_access: NO_SQL                               │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# │                       │                       │                                 │                                │ * name: sum                                                │                      │
# │                       │                       │                                 │                                │         * comment: Adds two numbers.                       │                      │
# │                       │                       │                                 │                                │         * function_id:                                     │                      │
# │                       │                       │                                 │                                │ 7ad91857-fc34-4417-9694-1738642f874c                       │                      │
# │                       │                       │                                 │                                │         * function_type: INT                               │                      │
# │                       │                       │                                 │                                │         * sql_access: NO_SQL                               │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ unity                 │ Main catalog          │ default                         │ Default schema                 │ Volumes                                                    │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# │                       │                       │                                 │                                │ * name: txt_files                                          │                      │
# │                       │                       │                                 │                                │         * comment: None                                    │                      │
# │                       │                       │                                 │                                │         * created_at: 1721259605627                        │                      │
# │                       │                       │                                 │                                │         * updated_at: 1721259605627                        │                      │
# │                       │                       │                                 │                                │         * volume_id: 74695d77-d48b-4f8e-9894-54a3e110b1ae  │                      │
# │                       │                       │                                 │                                │         * volume_type: MANAGED                             │                      │
# │                       │                       │                                 │                                │         * storage_location:                                │                      │
# │                       │                       │                                 │                                │ file:///home/dan/localGit/databricks/unitycatalog/etc/dat… │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# │                       │                       │                                 │                                │ * name: json_files                                         │                      │
# │                       │                       │                                 │                                │         * comment: None                                    │                      │
# │                       │                       │                                 │                                │         * created_at: 1721259605627                        │                      │
# │                       │                       │                                 │                                │         * updated_at: 1721259605627                        │                      │
# │                       │                       │                                 │                                │         * volume_id: d3f18882-eb1f-4cbb-bbc4-0347091224e8  │                      │
# │                       │                       │                                 │                                │         * volume_type: EXTERNAL                            │                      │
# │                       │                       │                                 │                                │         * storage_location:                                │                      │
# │                       │                       │                                 │                                │ file:///home/dan/localGit/databricks/unitycatalog/etc/dat… │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# ├───────────────────────┼───────────────────────┼─────────────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────┼──────────────────────┤
# │ unity                 │ Main catalog          │ default                         │ Default schema                 │ Tables                                                     │ ┏━━━━┳━━━━┳━━━━┳━━━┓ │
# │                       │                       │                                 │                                │                                                            │ ┃ n… ┃ t… ┃ n… ┃ … ┃ │
# │                       │                       │                                 │                                │ * name: marksheet                                          │ ┡━━━━╇━━━━╇━━━━╇━━━┩ │
# │                       │                       │                                 │                                │         * comment: Managed table                           │ │ f… │ s… │ f… │ … │ │
# │                       │                       │                                 │                                │         * created_at: 1721259605595                        │ │    │    │    │ … │ │
# │                       │                       │                                 │                                │         * updated_at: 1721259605595                        │ │ a… │ b… │ f… │ … │ │
# │                       │                       │                                 │                                │         * table_id: c389adfa-5c8f-497b-8f70-26c2cca4976d   │ │    │    │    │ … │ │
# │                       │                       │                                 │                                │         * table_type: MANAGED                              │ │ c… │ s… │ f… │ … │ │
# │                       │                       │                                 │                                │         * src_format: DELTA                                │ │    │    │    │ … │ │
# │                       │                       │                                 │                                │                                                            │ └────┴────┴────┴───┘ │
# │                       │                       │                                 │                                │                                                            │                      │
# │                       │                       │                                 │                                │ * name: marksheet_uniform                                  │                      │
# │                       │                       │                                 │                                │         * comment: Uniform table                           │                      │
# │                       │                       │                                 │                                │         * created_at: 1721259605611                        │                      │
# │                       │                       │                                 │                                │         * updated_at: 1721259605611                        │                      │
# │                       │                       │                                 │                                │         * table_id: 9a73eb46-adf0-4457-9bd8-9ab491865e0d   │                      │
# │                       │                       │                                 │                                │         * table_type: EXTERNAL                             │                      │
# │                       │                       │                                 │                                │         * src_format: DELTA                                │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# │                       │                       │                                 │                                │ * name: numbers                                            │                      │
# │                       │                       │                                 │                                │         * comment: External table                          │                      │
# │                       │                       │                                 │                                │         * created_at: 1721259605617                        │                      │
# │                       │                       │                                 │                                │         * updated_at: 1721259605617                        │                      │
# │                       │                       │                                 │                                │         * table_id: 32025924-be53-4d67-ac39-501a86046c01   │                      │
# │                       │                       │                                 │                                │         * table_type: EXTERNAL                             │                      │
# │                       │                       │                                 │                                │         * src_format: DELTA                                │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# │                       │                       │                                 │                                │ * name: user_countries                                     │                      │
# │                       │                       │                                 │                                │         * comment: Partitioned table                       │                      │
# │                       │                       │                                 │                                │         * created_at: 1721259605622                        │                      │
# │                       │                       │                                 │                                │         * updated_at: 1721259605622                        │                      │
# │                       │                       │                                 │                                │         * table_id: 26ed93b5-9a18-4726-8ae8-c89dfcfea069   │                      │
# │                       │                       │                                 │                                │         * table_type: EXTERNAL                             │                      │
# │                       │                       │                                 │                                │         * src_format: DELTA                                │                      │
# │                       │                       │                                 │                                │                                                            │                      │
# ╰───────────────────────┴───────────────────────┴─────────────────────────────────┴────────────────────────────────┴────────────────────────────────────────────────────────────┴──────────────────────╯
#                                                                             Running on http://egeria.pdr-associates.com:8070
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# %run uc_catalog_viewer --url http://host.docker.internal:8081
# Out:
#                                                                                UC OSS Catalog @ Thu Sep 19 07:11:55 2024
# ╭────────────────────────┬────────────────────────┬──────────────────────────┬────────────────────────────────┬────────────────────────────────────────────────────────────────┬───────────────────────╮
# │ Catalog Name           │ Catalog Comment        │ Schema Name              │ Schema Comment                 │ Vol/Tab                                                        │ Details               │
# ├────────────────────────┼────────────────────────┼──────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────────┼───────────────────────┤
# │ unity                  │ Main catalog           │ default                  │ Default schema                 │ Functions                                                      │                       │
# │                        │                        │                          │                                │ * name: lowercase                                              │                       │
# │                        │                        │                          │                                │         * comment: Converts a string to lowercase.             │                       │
# │                        │                        │                          │                                │         * function_id: ebb706d6-7ba0-4b2e-8d9c-716d13fd57f8    │                       │
# │                        │                        │                          │                                │         * function_type: STRING                                │                       │
# │                        │                        │                          │                                │         * sql_access: NO_SQL                                   │                       │
# │                        │                        │                          │                                │                                                                │                       │
# │                        │                        │                          │                                │ * name: sum                                                    │                       │
# │                        │                        │                          │                                │         * comment: Adds two numbers.                           │                       │
# │                        │                        │                          │                                │         * function_id: 7ad91857-fc34-4417-9694-1738642f874c    │                       │
# │                        │                        │                          │                                │         * function_type: INT                                   │                       │
# │                        │                        │                          │                                │         * sql_access: NO_SQL                                   │                       │
# │                        │                        │                          │                                │                                                                │                       │
# ├────────────────────────┼────────────────────────┼──────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────────┼───────────────────────┤
# │ unity                  │ Main catalog           │ default                  │ Default schema                 │ Volumes                                                        │                       │
# │                        │                        │                          │                                │                                                                │                       │
# │                        │                        │                          │                                │ * name: txt_files                                              │                       │
# │                        │                        │                          │                                │         * comment: None                                        │                       │
# │                        │                        │                          │                                │         * created_at: 1721241605627                            │                       │
# │                        │                        │                          │                                │         * updated_at: 1721241605627                            │                       │
# │                        │                        │                          │                                │         * volume_id: 74695d77-d48b-4f8e-9894-54a3e110b1ae      │                       │
# │                        │                        │                          │                                │         * volume_type: MANAGED                                 │                       │
# │                        │                        │                          │                                │         * storage_location:                                    │                       │
# │                        │                        │                          │                                │ file:///opt/unitycatalog/etc/data/managed/unity/default/volum… │                       │
# │                        │                        │                          │                                │                                                                │                       │
# │                        │                        │                          │                                │ * name: json_files                                             │                       │
# │                        │                        │                          │                                │         * comment: None                                        │                       │
# │                        │                        │                          │                                │         * created_at: 1721241605627                            │                       │
# │                        │                        │                          │                                │         * updated_at: 1721241605627                            │                       │
# │                        │                        │                          │                                │         * volume_id: d3f18882-eb1f-4cbb-bbc4-0347091224e8      │                       │
# │                        │                        │                          │                                │         * volume_type: EXTERNAL                                │                       │
# │                        │                        │                          │                                │         * storage_location:                                    │                       │
# │                        │                        │                          │                                │ file:///opt/unitycatalog/etc/data/external/unity/default/volu… │                       │
# │                        │                        │                          │                                │                                                                │                       │
# ├────────────────────────┼────────────────────────┼──────────────────────────┼────────────────────────────────┼────────────────────────────────────────────────────────────────┼───────────────────────┤
# │ unity                  │ Main catalog           │ default                  │ Default schema                 │ Tables                                                         │ ┏━━━━┳━━━━┳━━━━┳━━━━┓ │
# │                        │                        │                          │                                │                                                                │ ┃ n… ┃ t… ┃ n… ┃ c… ┃ │
# │                        │                        │                          │                                │ * name: marksheet                                              │ ┡━━━━╇━━━━╇━━━━╇━━━━┩ │
# │                        │                        │                          │                                │         * comment: Managed table                               │ │ f… │ s… │ f… │ s… │ │
# │                        │                        │                          │                                │         * created_at: 1721241605595                            │ │    │    │    │ c… │ │
# │                        │                        │                          │                                │         * updated_at: 1721241605595                            │ │ a… │ b… │ f… │ l… │ │
# │                        │                        │                          │                                │         * table_id: c389adfa-5c8f-497b-8f70-26c2cca4976d       │ │    │    │    │ c… │ │
# │                        │                        │                          │                                │         * table_type: MANAGED                                  │ │ c… │ s… │ f… │ p… │ │
# │                        │                        │                          │                                │         * src_format: DELTA                                    │ │    │    │    │ c… │ │
# │                        │                        │                          │                                │                                                                │ └────┴────┴────┴────┘ │
# │                        │                        │                          │                                │                                                                │                       │
# │                        │                        │                          │                                │ * name: marksheet_uniform                                      │                       │
# │                        │                        │                          │                                │         * comment: Uniform table                               │                       │
# │                        │                        │                          │                                │         * created_at: 1721241605611                            │                       │
# │                        │                        │                          │                                │         * updated_at: 1721241605611                            │                       │
# │                        │                        │                          │                                │         * table_id: 9a73eb46-adf0-4457-9bd8-9ab491865e0d       │                       │
# │                        │                        │                          │                                │         * table_type: EXTERNAL                                 │                       │
# │                        │                        │                          │                                │         * src_format: DELTA                                    │                       │
# │                        │                        │                          │                                │                                                                │                       │
# │                        │                        │                          │                                │                                                                │                       │
# │                        │                        │                          │                                │ * name: numbers                                                │                       │
# │                        │                        │                          │                                │         * comment: External table                              │                       │
# │                        │                        │                          │                                │         * created_at: 1721241605617                            │                       │
# │                        │                        │                          │                                │         * updated_at: 1721241605617                            │                       │
# │                        │                        │                          │                                │         * table_id: 32025924-be53-4d67-ac39-501a86046c01       │                       │
# │                        │                        │                          │                                │         * table_type: EXTERNAL                                 │                       │
# │                        │                        │                          │                                │         * src_format: DELTA                                    │                       │
# │                        │                        │                          │                                │                                                                │                       │
# │                        │                        │                          │                                │                                                                │                       │
# │                        │                        │                          │                                │ * name: user_countries                                         │                       │
# │                        │                        │                          │                                │         * comment: Partitioned table                           │                       │
# │                        │                        │                          │                                │         * created_at: 1721241605622                            │                       │
# │                        │                        │                          │                                │         * updated_at: 1721241605622                            │                       │
# │                        │                        │                          │                                │         * table_id: 26ed93b5-9a18-4726-8ae8-c89dfcfea069       │                       │
# │                        │                        │                          │                                │         * table_type: EXTERNAL                                 │                       │
# │                        │                        │                          │                                │         * src_format: DELTA                                    │                       │
# │                        │                        │                          │                                │                                                                │                       │
# ╰────────────────────────┴────────────────────────┴──────────────────────────┴────────────────────────────────┴────────────────────────────────────────────────────────────────┴───────────────────────╯
#                                                                               Running on http://host.docker.internal:8081
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from pyegeria import AssetCatalog

# %%
a_client = AssetCatalog('view-server', 'https://host.docker.internal:9443','erinoverview','secret')
token = a_client.create_egeria_bearer_token()

asset_guid = 'd6b1a015-90b3-42fe-89df-beadac21b74a'

asset_graph = a_client.get_asset_graph(asset_guid)

# %%
display_name = asset_graph['properties']['displayName']
relationships = asset_graph['relationships']
for rel in relationships:
    type_name = rel['type']['typeName']
    if type_name == 'ExternalIdScope':
        catalog = rel["end1"]["uniqueName"]
        print(f"Name: {display_name}, Catalog: {catalog}\n")

# %%
catalog_guid = '79454899-6550-48ab-b2ff-d988fb687110'
