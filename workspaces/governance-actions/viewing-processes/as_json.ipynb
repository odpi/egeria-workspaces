# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Egeria Workbook
#
# # Retrieving the definition of a Governance Action Process
#
# ## Introduction
#
# [Governance Action Processes](https://egeria-project.org/concepts/governance-action-process/) are defined as a set of linked open metadata elements.  The elements define the action to take and the links define the conditions that define which action to take ext after an action completes.
#
# The code below lists the governance action processes that are defined in the connected open metadata repositories.
#
# ----

# %%
import os
view_server = os.environ.get("VIEW_SERVER","view-server")
url = os.environ.get("EGERIA_VIEW_SERVER_URL","https://host.docker.internal:9443")
user_id = os.environ.get("EGERIA_USER", "peterprofile")
user_pwd = os.environ.get("EGERIA_USER_PASSWORD")

from pyegeria import EgeriaTech
import asyncio
import nest_asyncio
nest_asyncio.apply()

egeria_tech = EgeriaTech(view_server, url, user_id, user_pwd)
token = egeria_tech.create_egeria_bearer_token()

# %%
processList = egeria_tech.get_elements("GovernanceActionProcess")

if processList:
    print("Known Governance Action Processes:")
    for process in processList:
        if process:
            guid="???"
            processName="????"
            elementHeader = process.get('elementHeader')
            if elementHeader:
                guid = elementHeader.get('guid')
            properties = process.get('properties')
            if properties:
                processName=properties.get('qualifiedName')
            print("* " + processName + " (" + guid + ")")
# Out:
# Known Governance Action Processes:
# * UnityCatalogServer:CreateAndCatalogGovernanceActionProcess (4082f11e-ac17-404b-b48f-477714a52457)
# * Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding (58050a15-745a-4727-8257-074c19b02796)
# * UnityCatalogServer:CreateAndSurveyGovernanceActionProcess (39dbedae-7753-4d05-9a7a-4a6c80cb02f5)
# * Egeria:DailyGovernanceActionProcess (dde1e255-6d0c-4589-b4a6-17e7d01db5ab)

# %% [markdown]
# ----
#
# This next piece of code extracts the unique identifier (guid) of a particular govenrance action process.  You can change the name to view a different process.
#
# -----

# %%
process_guid = egeria_tech.get_element_guid_by_unique_name("Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding")

print(process_guid)
# Out:
# 58050a15-745a-4727-8257-074c19b02796

# %% [markdown]
# ----
#
# Finally, the unique identifier of the process is used to retrieve its definition.
#
# ----

# %%
import json

print(json.dumps(egeria_tech.get_gov_action_process_graph("58050a15-745a-4727-8257-074c19b02796"), indent=2))
# Out:
# {
#   "governanceActionProcess": {
#     "elementHeader": {
#       "class": "ElementHeader",
#       "headerVersion": 0,
#       "status": "ACTIVE",
#       "type": {
#         "typeId": "4d3a2b8d-9e2e-4832-b338-21c74e45b238",
#         "typeName": "GovernanceActionProcess",
#         "superTypeNames": [
#           "Process",
#           "Asset",
#           "Referenceable",
#           "OpenMetadataRoot"
#         ],
#         "typeVersion": 2,
#         "typeDescription": "A process implemented by chained engine actions that call governance services."
#       },
#       "origin": {
#         "sourceServer": "active-metadata-store",
#         "originCategory": "CONTENT_PACK",
#         "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#         "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#         "license": "Apache 2.0"
#       },
#       "versions": {
#         "createdBy": "Egeria Project",
#         "createTime": "2024-09-09T08:09:22.382+00:00",
#         "version": 1725869362382
#       },
#       "guid": "58050a15-745a-4727-8257-074c19b02796",
#       "classifications": [
#         {
#           "class": "ElementClassification",
#           "headerVersion": 0,
#           "status": "ACTIVE",
#           "type": {
#             "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#             "typeName": "Anchors",
#             "typeVersion": 3,
#             "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#           },
#           "origin": {
#             "sourceServer": "active-metadata-store",
#             "originCategory": "CONTENT_PACK",
#             "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#             "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#           },
#           "versions": {
#             "createdBy": "Egeria Project",
#             "createTime": "2024-09-09T08:09:22.382+00:00",
#             "version": 1725869362382
#           },
#           "classificationOrigin": "ASSIGNED",
#           "classificationName": "Anchors",
#           "classificationProperties": {
#             "anchorTypeName": "GovernanceActionProcess",
#             "anchorDomainName": "Asset",
#             "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#           }
#         }
#       ]
#     },
#     "processProperties": {
#       "class": "GovernanceActionProcessProperties",
#       "qualifiedName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding",
#       "domainIdentifier": 0,
#       "displayName": "Onboard Landing Area Files For Teddy Bear Drop Foot Project",
#       "description": "Ensures that new files added to the landing are correctly catalogued in the data lake.\n\nThis process performs the follow function:\n     1) The physical file is moved to the data lake and renamed,\n     2) A new asset is created for the new file,\n     3) Lineage is created between the original file asset and the new file asset,\n     4) The owner and origin are assigned,\n     5) The governance zones are assigned to make the new asset visible to the research team.",
#       "versionIdentifier": "V1.0"
#     }
#   },
#   "firstProcessStep": {
#     "element": {
#       "elementHeader": {
#         "class": "ElementHeader",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "9832623c-9383-4c4d-9588-93cf79b8327f",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ]
#       },
#       "processStepProperties": {
#         "class": "GovernanceActionProcessStepProperties",
#         "qualifiedName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:MoveWeeklyMeasurementsFile",
#         "domainIdentifier": 0,
#         "displayName": "Move Weekly Measurements File",
#         "description": "The physical file is moved to the data lake and renamed, an asset is created for the new file (in the quarantine zone) and a lineage relationship is created between the original file asset and the new file asset.",
#         "waitTime": 0,
#         "ignoreMultipleTriggers": true
#       }
#     },
#     "linkGUID": "01257f4d-51e9-489a-ac4e-9534811328ea"
#   },
#   "nextProcessSteps": [
#     {
#       "elementHeader": {
#         "class": "ElementHeader",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "aecfe10d-9100-4846-9663-926d73f0080d",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ]
#       },
#       "processStepProperties": {
#         "class": "GovernanceActionProcessStepProperties",
#         "qualifiedName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SeekOrigin",
#         "domainIdentifier": 0,
#         "displayName": "Seek and validate origin",
#         "description": "Validate that origin of the file is correctly set up.",
#         "waitTime": 0,
#         "ignoreMultipleTriggers": true
#       }
#     },
#     {
#       "elementHeader": {
#         "class": "ElementHeader",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "c456dede-836b-469e-97c0-b51d46515ec4",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ]
#       },
#       "processStepProperties": {
#         "class": "GovernanceActionProcessStepProperties",
#         "qualifiedName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SetRetention",
#         "domainIdentifier": 0,
#         "displayName": "SetRetentionPeriod.",
#         "description": "Set up the dates went the data associated with the asset should be archived and then deleted.",
#         "waitTime": 0,
#         "ignoreMultipleTriggers": true
#       }
#     },
#     {
#       "elementHeader": {
#         "class": "ElementHeader",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "fd6780e1-d2f1-4b76-b08d-20acbb45c2c4",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ]
#       },
#       "processStepProperties": {
#         "class": "GovernanceActionProcessStepProperties",
#         "qualifiedName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SetZones",
#         "domainIdentifier": 0,
#         "displayName": "Publish asset.",
#         "description": "Set up the zones in the asset so that is it visible in the data lake.",
#         "waitTime": 0,
#         "ignoreMultipleTriggers": true
#       }
#     },
#     {
#       "elementHeader": {
#         "class": "ElementHeader",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "845251df-9c6d-4102-bf64-45f71a3c2fb5",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ]
#       },
#       "processStepProperties": {
#         "class": "GovernanceActionProcessStepProperties",
#         "qualifiedName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:DataQuality",
#         "domainIdentifier": 0,
#         "displayName": "Check quality of data",
#         "description": "Validate that origin of the file is correctly set up.",
#         "waitTime": 0,
#         "ignoreMultipleTriggers": true
#       }
#     },
#     {
#       "elementHeader": {
#         "class": "ElementHeader",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "4c586c55-8d2a-4073-9afe-c1606e1a804d",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ]
#       },
#       "processStepProperties": {
#         "class": "GovernanceActionProcessStepProperties",
#         "qualifiedName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:CheckForRFAs",
#         "domainIdentifier": 0,
#         "displayName": "Check for quality issues",
#         "description": "Validate that there are no reported data qualify issues.",
#         "waitTime": 0,
#         "ignoreMultipleTriggers": true
#       }
#     }
#   ],
#   "processStepLinks": [
#     {
#       "previousProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "9832623c-9383-4c4d-9588-93cf79b8327f",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:MoveWeeklyMeasurementsFile"
#       },
#       "nextProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "aecfe10d-9100-4846-9663-926d73f0080d",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SeekOrigin"
#       },
#       "nextProcessStepLinkGUID": "729968e6-060d-42fc-bb5d-6a6de79158e7",
#       "guard": "provisioning-complete",
#       "mandatoryGuard": false
#     },
#     {
#       "previousProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "aecfe10d-9100-4846-9663-926d73f0080d",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SeekOrigin"
#       },
#       "nextProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "c456dede-836b-469e-97c0-b51d46515ec4",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SetRetention"
#       },
#       "nextProcessStepLinkGUID": "77eafb1e-d598-4b95-be44-e6455e286dd0",
#       "guard": "origin-assigned",
#       "mandatoryGuard": false
#     },
#     {
#       "previousProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "c456dede-836b-469e-97c0-b51d46515ec4",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SetRetention"
#       },
#       "nextProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "fd6780e1-d2f1-4b76-b08d-20acbb45c2c4",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SetZones"
#       },
#       "nextProcessStepLinkGUID": "84bdb672-e8b5-4bc1-87bf-a92aa611642c",
#       "guard": "classification-assigned",
#       "mandatoryGuard": true
#     },
#     {
#       "previousProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "aecfe10d-9100-4846-9663-926d73f0080d",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SeekOrigin"
#       },
#       "nextProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "c456dede-836b-469e-97c0-b51d46515ec4",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SetRetention"
#       },
#       "nextProcessStepLinkGUID": "e0c57d33-1eca-4be6-b4e2-487d06420e60",
#       "guard": "origin-already-assigned",
#       "mandatoryGuard": false
#     },
#     {
#       "previousProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "9832623c-9383-4c4d-9588-93cf79b8327f",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:MoveWeeklyMeasurementsFile"
#       },
#       "nextProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "845251df-9c6d-4102-bf64-45f71a3c2fb5",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:DataQuality"
#       },
#       "nextProcessStepLinkGUID": "02bfc363-bd06-46b0-9be4-258b7d270b4d",
#       "guard": "provisioning-complete",
#       "mandatoryGuard": false
#     },
#     {
#       "previousProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "845251df-9c6d-4102-bf64-45f71a3c2fb5",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:DataQuality"
#       },
#       "nextProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "4c586c55-8d2a-4073-9afe-c1606e1a804d",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:CheckForRFAs"
#       },
#       "nextProcessStepLinkGUID": "f457a1bb-f7b8-49e3-bb5d-ace0d0de125b",
#       "guard": "survey-completed",
#       "mandatoryGuard": false
#     },
#     {
#       "previousProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "4c586c55-8d2a-4073-9afe-c1606e1a804d",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:CheckForRFAs"
#       },
#       "nextProcessStep": {
#         "class": "ElementStub",
#         "headerVersion": 0,
#         "status": "ACTIVE",
#         "type": {
#           "typeId": "7ae66fcc-09be-4d16-b39f-b5e299473586",
#           "typeName": "GovernanceActionProcessStep",
#           "superTypeNames": [
#             "GovernanceActionType",
#             "Referenceable",
#             "OpenMetadataRoot"
#           ],
#           "typeVersion": 1,
#           "typeDescription": "A description of a call to a step in a governance action process that acts as a template when creating the appropriate engine action instance."
#         },
#         "origin": {
#           "sourceServer": "active-metadata-store",
#           "originCategory": "CONTENT_PACK",
#           "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#           "homeMetadataCollectionName": "Coco Pharmaceuticals Combination",
#           "license": "Apache 2.0"
#         },
#         "versions": {
#           "createdBy": "Egeria Project",
#           "createTime": "2024-09-09T08:09:22.382+00:00",
#           "version": 1725869362382
#         },
#         "guid": "fd6780e1-d2f1-4b76-b08d-20acbb45c2c4",
#         "classifications": [
#           {
#             "class": "ElementClassification",
#             "headerVersion": 0,
#             "status": "ACTIVE",
#             "type": {
#               "typeId": "aa44f302-2e43-4669-a1e7-edaae414fc6e",
#               "typeName": "Anchors",
#               "typeVersion": 3,
#               "typeDescription": "Identifies the anchor entity for an element that is part of a large composite object such as an asset."
#             },
#             "origin": {
#               "sourceServer": "active-metadata-store",
#               "originCategory": "CONTENT_PACK",
#               "homeMetadataCollectionId": "655b1965-4c29-4a0e-8a5d-3f55a37b3799",
#               "homeMetadataCollectionName": "Coco Pharmaceuticals Combination"
#             },
#             "versions": {
#               "createdBy": "Egeria Project",
#               "createTime": "2024-09-09T08:09:22.382+00:00",
#               "version": 1725869362382
#             },
#             "classificationOrigin": "ASSIGNED",
#             "classificationName": "Anchors",
#             "classificationProperties": {
#               "anchorTypeName": "GovernanceActionProcess",
#               "anchorDomainName": "Asset",
#               "anchorGUID": "58050a15-745a-4727-8257-074c19b02796"
#             }
#           }
#         ],
#         "uniqueName": "Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding:SetZones"
#       },
#       "nextProcessStepLinkGUID": "5eba1f57-2374-488b-a34c-1a03798e9351",
#       "guard": "actions-actioned",
#       "mandatoryGuard": true
#     }
#   ]
# }
