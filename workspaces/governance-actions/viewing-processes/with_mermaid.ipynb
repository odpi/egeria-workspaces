# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Egeria Workbook
#
# # Using Mermaid to view a Governance Action Process
#
# ## Introduction
#
# [Mermaid](https://mermaid.js.org/intro/) is a Javascript based viewer for graphical structures.
# The `pyegeria` libraries include functions to display [Governance Action Processes](https://egeria-project.org/concepts/governance-action-process/) using mermaid.
#
# There are three functions:
#
# * `load_mermaid()` - must be executed once per session to inject mermaid javascript code into the Jupyter environment.
# * `mermaid_graph(process_guid, view_server, url, user_id, password)` - generates Mermaid markdown for the Egeria process.
# * `render_mermaid(mermaid_code)` - renders and displays the Mermaid markdown code generated by `mermaid_graph`.
#
# Let begin by loading the mermaid libraries
#
# ----

# %%
from pyegeria import load_mermaid, render_mermaid, generate_process_graph

load_mermaid()
# Out:
#     <script type="text/javascript">
#         if (!window.mermaid) {
#             var mermaidScript = document.createElement('script');
#             mermaidScript.src = "https://cdnjs.cloudflare.com/ajax/libs/mermaid/10.9.1/mermaid.min.js";
#             document.head.appendChild(mermaidScript);
#         }
#     </script>

# %% [markdown]
# ----
#
# The `mermaid_graph` function needs the unique identifier of a governance action process.  This can be queried from Egeria.   The next piece of code sets up the `pyegeria` client needed to retrieve details of the governance action process.
#
# ----

# %%
import os
view_server = os.environ.get("VIEW_SERVER","view-server")
url = os.environ.get("EGERIA_VIEW_SERVER_URL","https://host.docker.internal:9443")
user_id = os.environ.get("EGERIA_USER", "peterprofile")
user_pwd = os.environ.get("EGERIA_USER_PASSWORD")

from pyegeria import EgeriaTech
import asyncio
import nest_asyncio
nest_asyncio.apply()

egeria_tech = EgeriaTech(view_server, url, user_id, user_pwd)
token = egeria_tech.create_egeria_bearer_token()

# %% [markdown]
# ----
#
# The code below lists the governance action processes that are defined in the connected open metadata repositories.
#
# ----

# %%
processList = egeria_tech.get_elements("GovernanceActionProcess")

if processList:
    print("Known Governance Action Processes:")
    for process in processList:
        if process:
            guid="???"
            processName="????"
            elementHeader = process.get('elementHeader')
            if elementHeader:
                guid = elementHeader.get('guid')
            properties = process.get('properties')
            if properties:
                processName=properties.get('qualifiedName')
            print("* " + processName + " (" + guid + ")")
# Out:
# Known Governance Action Processes:
# * Egeria:DailyGovernanceActionProcess (dde1e255-6d0c-4589-b4a6-17e7d01db5ab)

# %% [markdown]
# ----
#
# This next piece of code extracts the unique identifier (guid) of a particular govenrance action process.  You can change the name to view a different process.
#
# -----

# %%
process_guid = egeria_tech.get_element_guid_by_unique_name("Coco:GovernanceActionProcess:ClinicalTrials:WeeklyMeasurements:Onboarding")

print(process_guid)
# Out:
# da0442bf-818f-406b-99dc-83b72605cc98

# %% [markdown]
# ----
#
# The `generate_process_graph` creates the mermaid markdown string.  It is printed out below.
#
# ----

# %%
mermaid_graph = generate_process_graph(process_guid)

print(mermaid_graph)
# Out:
# ---
# title: Onboard Landing Area Files For Teddy Bear Drop Foot Project
# ---
# flowchart LR
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# Step1("`**Move Weekly Measurements File**
# *nwait_time*: 0
# *nmult_trig*: True`")
# Step2("`**Check quality of data**
# *wait_time*: 0
# *mult_trig*: True`")
# Step3("`**Check for quality issues**
# *wait_time*: 0
# *mult_trig*: True`")
# Step4("`**Publish asset.**
# *wait_time*: 0
# *mult_trig*: True`")
# Step5("`**Seek and validate origin**
# *wait_time*: 0
# *mult_trig*: True`")
# Step6("`**SetRetentionPeriod.**
# *wait_time*: 0
# *mult_trig*: True`")
# Step1-->|provisioning-complete|Step2
# Step2-->|survey-completed|Step3
# Step3-->|Mandatory:actions-actioned|Step4
# Step1-->|provisioning-complete|Step5
# Step5-->|origin-already-assigned|Step6
# Step6-->|Mandatory:classification-assigned|Step4
# Step5-->|origin-assigned|Step6

# %%
mermaid_graph = "---\ntitle: Anchor Element - active-metadata-store [6204f340-d7fd-4cc8-922a-8851fb889dc2]\n---\nflowchart LR\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n6204f340-d7fd-4cc8-922a-8851fb889dc2(\"`*SoftwareServer*\n**active-metadata-store**`\")\n8ea8528e-0286-44f7-95da-db87a502b577(\"`*APIManager*\n**Open Metadata Repository Access APIs**`\")\n6a4413b0-726d-4000-8cf2-0add52b15178(\"`*Endpoint*\n**active-metadata-store endpoint**`\")\n278af35a-5a8c-4c8f-a6d2-c2f9f7e6b6df(\"`*Connection*\n**active-metadata-store connection**`\")\n6204f340-d7fd-4cc8-922a-8851fb889dc2-->|SourcedFrom|bd8de890-fa79-4c24-aab8-20b41b5893dd\n6204f340-d7fd-4cc8-922a-8851fb889dc2-->|ServerEndpoint|6a4413b0-726d-4000-8cf2-0add52b15178\n6204f340-d7fd-4cc8-922a-8851fb889dc2-->|SupportedSoftwareCapability|8ea8528e-0286-44f7-95da-db87a502b577\n278af35a-5a8c-4c8f-a6d2-c2f9f7e6b6df-->|ConnectionConnectorType|4f670bba-a0b5-4748-83b5-f7490d091f89\n6a4413b0-726d-4000-8cf2-0add52b15178-->|ConnectionEndpoint|278af35a-5a8c-4c8f-a6d2-c2f9f7e6b6df\n6204f340-d7fd-4cc8-922a-8851fb889dc2-->|DeployedOn|44bf319f-1e41-4da1-b771-2753b92b631a\n278af35a-5a8c-4c8f-a6d2-c2f9f7e6b6df-->|ConnectionToAsset|6204f340-d7fd-4cc8-922a-8851fb889dc2\n"

# %% [markdown]
# ----
#
# Finally, `render_mermaid` prints out the mermaid markdown string.
#
# ----

# %%
render_mermaid(mermaid_graph)
# Out:
#     <div class="mermaid">
#
# ---
# title: Onboard Landing Area Files For Teddy Bear Drop Foot Project
# ---
# flowchart LR
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# Step1("`**Move Weekly Measurements File**
# *nwait_time*: 0
# *nmult_trig*: True`")
# Step2("`**Check quality of data**
# *wait_time*: 0
# *mult_trig*: True`")
# Step3("`**Check for quality issues**
# *wait_time*: 0
# *mult_trig*: True`")
# Step4("`**Publish asset.**
# *wait_time*: 0
# *mult_trig*: True`")
# Step5("`**Seek and validate origin**
# *wait_time*: 0
# *mult_trig*: True`")
# Step6("`**SetRetentionPeriod.**
# *wait_time*: 0
# *mult_trig*: True`")
# Step1-->|provisioning-complete|Step2
# Step2-->|survey-completed|Step3
# Step3-->|Mandatory:actions-actioned|Step4
# Step1-->|provisioning-complete|Step5
# Step5-->|origin-already-assigned|Step6
# Step6-->|Mandatory:classification-assigned|Step4
# Step5-->|origin-assigned|Step6
#     </div>
#     <script type="text/javascript">
# ...

# %%
mermaid_graph = "---\ntitle: Relationships matching Query\n---\nflowchart LR\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n6204f340-d7fd-4cc8-922a-8851fb889dc2(\"`*SourcedFrom*\n**Metadata Access Server:active-metadata-store**`\")\nbd8de890-fa79-4c24-aab8-20b41b5893dd(\"`*SourcedFrom*\n**Metadata Access Server:{{serverName}}**`\")\n87415bbe-f554-46b3-9754-048d46e5d605(\"`*SourcedFrom*\n**GlossaryTerm:TeddyBearDropFootTerminology:TemplateSubstitute:PatientId**`\")\n25c8210d-8ec9-47d3-bf73-92bc34af67d8(\"`*SourcedFrom*\n**GlossaryTerm:TeddyBearDropFootTerminology:Patient Identifier**`\")\nfd023af9-4ea2-4a15-92ea-ebcbb76ebece(\"`*SourcedFrom*\n**Metadata Access Server:simple-metadata-store**`\")\n49baff7f-9e2f-41e4-acbc-d47b71e91e46(\"`*SourcedFrom*\n**Engine Host:engine-host**`\")\n1764a891-4234-45f1-8cc3-536af40c790d(\"`*SourcedFrom*\n**Engine Host:{{serverName}}**`\")\n091c532f-c783-4fdf-bf00-fbf75b992ca6(\"`*SourcedFrom*\n**Integration Daemon:integration-daemon**`\")\n6b3516f0-dd13-4786-9601-07215f995197(\"`*SourcedFrom*\n**Integration Daemon:{{serverName}}**`\")\n806b24cd-b9a0-422d-ac6e-dee32a3a34a9(\"`*SourcedFrom*\n**GlossaryTerm:TeddyBearDropFootTerminology:TemplateSubstitute:AngleLeft**`\")\n2ecb87ed-d323-46da-a2eb-04d0b01618ba(\"`*SourcedFrom*\n**GlossaryTerm:TeddyBearDropFootTerminology:Left Hip Rotation Angle**`\")\n1dfb68d4-4fc7-49d1-9cac-11b0073e6266(\"`*SourcedFrom*\n**GlossaryTerm:TeddyBearDropFootTerminology:TemplateSubstitute:AngleRight**`\")\n06b6c02c-d8cc-4dbe-877c-5b1e6757f97d(\"`*SourcedFrom*\n**GlossaryTerm:TeddyBearDropFootTerminology:Right Hip Rotation Angle**`\")\n571466cd-6e34-471b-b238-a41f5402d98a(\"`*SourcedFrom*\n**GlossaryTerm:TeddyBearDropFootTerminology:TemplateSubstitute:MeasurementDate**`\")\n93edac3c-907f-4c04-978e-2706aba9f282(\"`*SourcedFrom*\n**GlossaryTerm:TeddyBearDropFootTerminology:Measurement Date**`\")\n13f86b2b-b1cc-4d96-b7da-f63156331728(\"`*SourcedFrom*\n**View Server:view-server**`\")\nfd61ca01-390d-4aa2-a55d-426826aa4e1b(\"`*SourcedFrom*\n**View Server:{{serverName}}**`\")\n6204f340-d7fd-4cc8-922a-8851fb889dc2-->|SourcedFrom|bd8de890-fa79-4c24-aab8-20b41b5893dd\n87415bbe-f554-46b3-9754-048d46e5d605-->|SourcedFrom|25c8210d-8ec9-47d3-bf73-92bc34af67d8\nfd023af9-4ea2-4a15-92ea-ebcbb76ebece-->|SourcedFrom|bd8de890-fa79-4c24-aab8-20b41b5893dd\n49baff7f-9e2f-41e4-acbc-d47b71e91e46-->|SourcedFrom|1764a891-4234-45f1-8cc3-536af40c790d\n091c532f-c783-4fdf-bf00-fbf75b992ca6-->|SourcedFrom|6b3516f0-dd13-4786-9601-07215f995197\n806b24cd-b9a0-422d-ac6e-dee32a3a34a9-->|SourcedFrom|2ecb87ed-d323-46da-a2eb-04d0b01618ba\n1dfb68d4-4fc7-49d1-9cac-11b0073e6266-->|SourcedFrom|06b6c02c-d8cc-4dbe-877c-5b1e6757f97d\n571466cd-6e34-471b-b238-a41f5402d98a-->|SourcedFrom|93edac3c-907f-4c04-978e-2706aba9f282\n13f86b2b-b1cc-4d96-b7da-f63156331728-->|SourcedFrom|fd61ca01-390d-4aa2-a55d-426826aa4e1b\n"

# %%
render_mermaid(mermaid_graph)
# Out:
#     <div class="mermaid">
#         ---
# title: Relationships matching Query
# ---
# flowchart LR
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# 6204f340-d7fd-4cc8-922a-8851fb889dc2("`*SourcedFrom*
# **Metadata Access Server:active-metadata-store**`")
# bd8de890-fa79-4c24-aab8-20b41b5893dd("`*SourcedFrom*
# **Metadata Access Server:{{serverName}}**`")
# 87415bbe-f554-46b3-9754-048d46e5d605("`*SourcedFrom*
# **GlossaryTerm:TeddyBearDropFootTerminology:TemplateSubstitute:PatientId**`")
# 25c8210d-8ec9-47d3-bf73-92bc34af67d8("`*SourcedFrom*
# **GlossaryTerm:TeddyBearDropFootTerminology:Patient Identifier**`")
# fd023af9-4ea2-4a15-92ea-ebcbb76ebece("`*SourcedFrom*
# **Metadata Access Server:simple-metadata-store**`")
# 49baff7f-9e2f-41e4-acbc-d47b71e91e46("`*SourcedFrom*
# **Engine Host:engine-host**`")
# 1764a891-4234-45f1-8cc3-536af40c790d("`*SourcedFrom*
# **Engine Host:{{serverName}}**`")
# 091c532f-c783-4fdf-bf00-fbf75b992ca6("`*SourcedFrom*
# ...

# %%
mermaid_graph = "---\ntitle: Anchor Element - ResourceList:resourceUse- [81969abe-0140-4001-85cd-5c44668961ea]\n---\nflowchart LR\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n81969abe-0140-4001-85cd-5c44668961ea(\"`*ValidValuesSet*\n**ResourceList:resourceUse-**`\")\n602e027b-7a75-493a-8e3b-c40a25b72289(\"`*ValidValuesSet*\n**Configure Connector**`\")\nfaf11ab1-746e-4081-9c05-2a3f588acb99(\"`*ValidValuesSet*\n**Watch Metadata Element**`\")\n928ecaea-c2a5-4cee-ad97-432cf969b07a(\"`*ValidValuesSet*\n**Improve Metadata Element**`\")\nc3692f08-88d5-4d77-a909-07856210a42f(\"`*ValidValuesSet*\n**Inform Steward**`\")\n0799259d-0eca-4198-8899-3d816bbd2292(\"`*ValidValuesSet*\n**Called Service**`\")\n00d80eca-93b0-4ecd-84df-18520bab58d7(\"`*ValidValuesSet*\n**Validate Resource**`\")\n46e5f600-6c98-4f0e-a372-6c6feb0faaf8(\"`*ValidValuesSet*\n**Derived Element Template**`\")\nbbc80560-7ef4-4402-90f0-8878f4d81f40(\"`*ValidValuesSet*\n**Survey Resource**`\")\n51e37cac-f1bc-4355-9df9-a7b7812ea5ff(\"`*ValidValuesSet*\n**Certify Resource**`\")\n3da817c4-c353-4d4c-ba0f-6a5461dcd008(\"`*ValidValuesSet*\n**Hosted Governance Engine**`\")\n36507d79-d073-440d-a0fe-13426c71c01b(\"`*ValidValuesSet*\n**Activity Folder**`\")\n93bfaac9-f92b-4d30-9f70-a48f505f9eb3(\"`*ValidValuesSet*\n**Supporting Process**`\")\n3fd2d19b-55c
# c3692f08-88d5-4d77-a909-07856210a42f("`*ValidValuesSet*
# **Inform Steward**`")
# 0799259d-0eca-4198-8899-3d816bbd2292("`*ValidValuesSet*
# **Called Service**`")
# 00d80eca-93b0-4ecd-84df-18520bab58d7("`*ValidValuesSet*
# **Validate Resource**`")
# 46e5f600-6c98-4f0e-a372-6c6feb0faaf8("`*ValidValuesSet*
# **Derived Element Template**`")
# bbc80560-7ef4-4402-90f0-8878f4d81f40("`*ValidValuesSet*
# **Survey Resource**`")
# ...

# %%
mermaid_graph="---\ntitle: Starting Element - 81969abe-0140-4001-85cd-5c44668961ea\n---\nflowchart LR\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n81969abe-0140-4001-85cd-5c44668961ea(\"`*Starting from*\n**81969abe-0140-4001-85cd-5c44668961ea**`\")\n0799259d-0eca-4198-8899-3d816bbd2292(\"`*ValidValueMember*\n**Called Service**`\")\nbbe263ad-3549-4f24-8a76-b9bf90f2b898(\"`*ValidValueMember*\n**Member Template**`\")\nabe0a148-cf1f-49c2-8908-6157b514e6ca(\"`*ValidValueMember*\n**Hosted Connector**`\")\n51e37cac-f1bc-4355-9df9-a7b7812ea5ff(\"`*ValidValueMember*\n**Certify Resource**`\")\nf28a154b-ecdc-49b1-bfac-29da9d44fb99(\"`*ValidValueMember*\n**Uncatalog Resource**`\")\n3a3c39af-cdf4-4f4f-b4c1-c1f0de550f3e(\"`*ValidValueMember*\n**Supporting Person**`\")\nfaf11ab1-746e-4081-9c05-2a3f588acb99(\"`*ValidValueMember*\n**Watch Metadata Element**`\")\n36507d79-d073-440d-a0fe-13426c71c01b(\"`*ValidValueMember*\n**Activity Folder**`\")\n928ecaea-c2a5-4cee-ad97-432cf969b07a(\"`*ValidValueMember*\n**Improve Metadata Element**`\")\n3da817c4-c353-4d4c-ba0f-6a5461dcd008(\"`*ValidValueMember*\n**Hosted Governance Engine**`\")\n3fd2d19b-55cb-4ea9-bd8e-048d4671301f(\"`*ValidValueMember*\n**Hosted Service**`\")\n93bfaac9-f92b-4d30-9f70-a48f505f9eb3(\"`*ValidValueMember*\n**Supporting Process**`\")\n37e65826-57d8-4e31-ba53-5dfd4679912a(\"`*ValidValueMember*\n**Catalog Resource**`\")\n74dd87b6-a886-4f1b-93de-66d52f04500c(\"`*ValidValueMember*\n**Choose Path**`\")\n3738b3c7-ed28-49bc-8e5f-03de15d09375(\"`*ValidValueMember*\n**Supporting Team**`\")\na64d05d3-b139-4f47-bf42-47bc4e4a1e6d(\"`*ValidValueMember*\n**Supporting Template**`\")\nbbc80560-7ef4-4402-90f0-8878f4d81f40(\"`*ValidValueMember*\n**Survey Resource**`\")\nb525a356-a0ae-485d-b9f3-a01207dd8655(\"`*ValidValueMember*\n**ResourceList:**`\")\nc3692f08-88d5-4d77-a909-07856210a42f(\"`*ValidValueMember*\n**Inform Steward**`\")\n84a7f0ba-26a0-4a2a-b50c-1014c7c36f36(\"`*ValidValueMember*\n**Provision Resource**`\")\n602e027b-7a75-493a-8e3b-c40a25b72289(\"`*ValidValueMember*\n**Configure Connector**`\")\n46e5f600-6c98-4f0e-a372-6c6feb0faaf8(\"`*ValidValueMember*\n**Derived Element Template**`\")\n00d80eca-93b0-4ecd-84df-18520bab58d7(\"`*ValidValueMember*\n**Validate Resource**`\")\n81969abe-0140-4001-85cd-5c44668961ea-->|ValidValueMember
n81969abe-0140-4001-85cd-5c44668961ea-->|ValidValueMember|faf11ab1-746e-4081-9c05-2a3f588acb99\n81969abe-0140-4001-85cd-5c44668961ea-->|ValidValueMember|3a3c39af-cdf4-4f4f-b4c1-c1f0de550f3e\n81969abe-0140-4001-85cd-5c44668961ea-->|ValidValueMember|928ecaea-c2a5-4cee-ad97-432cf969b07a\n81969abe-0140-4001-85cd-5c44668961ea-->|ValidValueMember|37e65826-57d8-4e31-ba53-5dfd4679912a\n81969abe-0140-4001-85cd-5c44668961ea-->|ValidValueMember|3fd2d19b-55cb-4ea9-bd8e-048d4671301f\n81969abe-0140-4001-85cd-5c44668961ea-->|ValidValueMember|bbe263ad-3549-4f24-8a76-b9bf90f2b898\n81969abe-0140-4001-85cd-5c44668961ea-->|ValidValueMember|51e37cac-f1bc-4355-9df9-a7b7812ea5ff\n81969abe-0140-4001-85cd-5c44668961ea-->|ValidValueMember|3738b3c7-ed28-49bc-8e5f-03de15d09375\n"

# %%
render_mermaid(mermaid_graph)
# Out:
#     <div class="mermaid">
#         ---
# title: Anchor Element - ResourceList:resourceUse- [81969abe-0140-4001-85cd-5c44668961ea]
# ---
# flowchart LR
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# 81969abe-0140-4001-85cd-5c44668961ea("`*ValidValuesSet*
# **ResourceList:resourceUse-**`")
# 602e027b-7a75-493a-8e3b-c40a25b72289("`*ValidValuesSet*
# **Configure Connector**`")
# faf11ab1-746e-4081-9c05-2a3f588acb99("`*ValidValuesSet*
# **Watch Metadata Element**`")
# 928ecaea-c2a5-4cee-ad97-432cf969b07a("`*ValidValuesSet*
# **Improve Metadata Element**`")
# 0799259d-0eca-4198-8899-3d816bbd2292("`*ValidValuesSet*
# **Called Service**`")
# c3692f08-88d5-4d77-a909-07856210a42f("`*ValidValuesSet*
# **Inform Steward**`")
# 00d80eca-93b0-4ecd-84df-18520bab58d7("`*ValidValuesSet*
# **Validate Resource**`")
# 46e5f600-6c98-4f0e-a372-6c6feb0faaf8("`*ValidValuesSet*
# **Derived Element Template**`")
# bbc80560-7ef4-4402-90f0-8878f4d81f40("`*ValidValuesSet*
# **Survey Resource**`")
# ...

# %%
mermaid_graph = "---\ntitle: Anchor Element - active-metadata-store [0995c3d2-ddea-4ec2-a820-e56286452b3e]\n---\nflowchart LR\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n0995c3d2-ddea-4ec2-a820-e56286452b3e(\"`*SoftwareServer*\n**active-metadata-store**`\")\n072bf7a2-6951-4083-8e35-a114a49f24dd(\"`*Connection*\n**active-metadata-store connection**`\")\nd39c1307-e8c9-4649-9c32-c5faa5eaf5fb(\"`*APIManager*\n**Open Metadata Repository Access APIs**`\")\n2969adc8-ad5b-4cd7-840d-fa420b54e881(\"`*Endpoint*\n**active-metadata-store endpoint**`\")\n0995c3d2-ddea-4ec2-a820-e56286452b3e-->|SupportedSoftwareCapability|d39c1307-e8c9-4649-9c32-c5faa5eaf5fb\n072bf7a2-6951-4083-8e35-a114a49f24dd-->|ConnectionConnectorType|4f670bba-a0b5-4748-83b5-f7490d091f89\n0995c3d2-ddea-4ec2-a820-e56286452b3e-->|DeployedOn|44bf319f-1e41-4da1-b771-2753b92b631a\n0995c3d2-ddea-4ec2-a820-e56286452b3e-->|ServerEndpoint|2969adc8-ad5b-4cd7-840d-fa420b54e881\n2969adc8-ad5b-4cd7-840d-fa420b54e881-->|ConnectionEndpoint|072bf7a2-6951-4083-8e35-a114a49f24dd\n0995c3d2-ddea-4ec2-a820-e56286452b3e-->|SourcedFrom|bd8de890-fa79-4c24-aab8-20b41b5893dd\n072bf7a2-6951-4083-8e35-a114a49f24dd-->|ConnectionToAsset|0995c3d2-ddea-4ec2-a820-e56286452b3e\n"

# %%
render_mermaid(mermaid_graph)
# Out:
#     <div class="mermaid">
#         ---
# title: Anchor Element - active-metadata-store [0995c3d2-ddea-4ec2-a820-e56286452b3e]
# ---
# flowchart LR
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# 0995c3d2-ddea-4ec2-a820-e56286452b3e("`*SoftwareServer*
# **active-metadata-store**`")
# 072bf7a2-6951-4083-8e35-a114a49f24dd("`*Connection*
# **active-metadata-store connection**`")
# d39c1307-e8c9-4649-9c32-c5faa5eaf5fb("`*APIManager*
# **Open Metadata Repository Access APIs**`")
# 2969adc8-ad5b-4cd7-840d-fa420b54e881("`*Endpoint*
# **active-metadata-store endpoint**`")
# 0995c3d2-ddea-4ec2-a820-e56286452b3e-->|SupportedSoftwareCapability|d39c1307-e8c9-4649-9c32-c5faa5eaf5fb
# 072bf7a2-6951-4083-8e35-a114a49f24dd-->|ConnectionConnectorType|4f670bba-a0b5-4748-83b5-f7490d091f89
# 0995c3d2-ddea-4ec2-a820-e56286452b3e-->|DeployedOn|44bf319f-1e41-4da1-b771-2753b92b631a
# 0995c3d2-ddea-4ec2-a820-e56286452b3e-->|ServerEndpoint|2969adc8-ad5b-4cd7-840d-fa420b54e881
# ...

# %%
mermaid_graph="---\ntitle: Relationships matching Query\n---\nflowchart LR\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\nea98029b-a432-4b94-9aa1-ef4ff7781f75(\"`*ResourceList*\n**Egeria:ValidMetadataValue:DataFile:deployedImplementationType-(Data File)**`\")\n3a15cfe4-e130-4b8c-b4fb-eedd39e1a2ae(\"`*ResourceList*\n**FileSurveys:survey-data-file**`\")\n0432df9c-d04d-4a41-8a27-599e0331d167(\"`*ResourceList*\n**Egeria:ValidMetadataValue::typeName-(DataFolder)**`\")\na6f2f6e8-d912-4101-982f-79c62190f1ba(\"`*ResourceList*\n**FileSurveys:survey-all-folders**`\")\n9805da73-c308-44ee-979c-86b1ef018dad(\"`*ResourceList*\n**Egeria:ValidMetadataValue::typeName-(DataFile)**`\")\n4a4d75eb-9098-4e06-8873-47d026f5867f(\"`*ResourceList*\n**Egeria:ValidMetadataValue::typeName-(FileFolder)**`\")\n633e7711-0c65-47b5-894f-c9dba5472412(\"`*ResourceList*\n**FileSurveys:survey-folder-and-files**`\")\n8153a074-c499-43b0-aed5-0866b1b4d250(\"`*ResourceList*\n**Egeria:ValidMetadataValue:FileFolder:deployedImplementationType-(File System Directory)**`\")\n4b94afcc-e648-4c8a-8fa7-818e40b634bb(\"`*ResourceList*\n**Egeria:ValidMetadataValue:CSVFile:deployedImplementationType-(CSV Data File)**`\")\nfcd7ddce-b61e-49eb-b993-293907dadf72(\"`*ResourceList*\n**FileSurveys:survey-csv-file**`\")\n5fb513c9-69ee-414c-9941-204451429787(\"`*ResourceList*\n**Egeria:ValidMetadataValue:DataFolder:deployedImplementationType-(Data Folder)**`\")\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->|ResourceList|3a15cfe4-e130-4b8c-b4fb-eedd39e1a2ae\n0432df9c-d04d-4a41-8a27-599e0331d167-->|ResourceList|a6f2f6e8-d912-4101-982f-79c62190f1ba\n9805da73-c308-44ee-979c-86b1ef018dad-->|ResourceList|3a15cfe4-e130-4b8c-b4fb-eedd39e1a2ae\n4a4d75eb-9098-4e06-8873-47d026f5867f-->|ResourceList|633e7711-0c65-47b5-894f-c9dba5472412\n8153a074-c499-43b0-aed5-0866b1b4d250-->|ResourceList|633e7711-0c65-47b5-894f-c9dba5472412\n4a4d75eb-9098-4e06-8873-47d026f5867f-->|ResourceList|a6f2f6e8-d912-4101-982f-79c62190f1ba\n4b94afcc-e648-4c8a-8fa7-818e40b634bb-->|ResourceList|fcd7ddce-b61e-49eb-b993-293907dadf72\n8153a074-c499-43b0-aed5-0866b1b4d250-->|ResourceList|a6f2f6e8-d912-4101-982f-79c62190f1ba\n5fb513c9-69ee-414c-9941-204451429787-->|ResourceList|633e7711-0c65-47b5-894f-c9dba5472412\n5fb513c9-69ee-414c-9941-204451429787-->|ResourceList|a6f2f6e8-d912-4101-982f-79c62190f1ba\n"

# %%
render_mermaid(mermaid_graph)
# Out:
#     <div class="mermaid">
#         ---
# title: Relationships matching Query
# ---
# flowchart LR
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# ea98029b-a432-4b94-9aa1-ef4ff7781f75("`*ResourceList*
# **Egeria:ValidMetadataValue:DataFile:deployedImplementationType-(Data File)**`")
# 3a15cfe4-e130-4b8c-b4fb-eedd39e1a2ae("`*ResourceList*
# **FileSurveys:survey-data-file**`")
# 0432df9c-d04d-4a41-8a27-599e0331d167("`*ResourceList*
# **Egeria:ValidMetadataValue::typeName-(DataFolder)**`")
# a6f2f6e8-d912-4101-982f-79c62190f1ba("`*ResourceList*
# **FileSurveys:survey-all-folders**`")
# 9805da73-c308-44ee-979c-86b1ef018dad("`*ResourceList*
# **Egeria:ValidMetadataValue::typeName-(DataFile)**`")
# 4a4d75eb-9098-4e06-8873-47d026f5867f("`*ResourceList*
# **Egeria:ValidMetadataValue::typeName-(FileFolder)**`")
# 633e7711-0c65-47b5-894f-c9dba5472412("`*ResourceList*
# **FileSurveys:survey-folder-and-files**`")
# 8153a074-c499-43b0-aed5-0866b1b4d250("`*ResourceList*
# ...

# %%
mermaid_graph="---\ntitle: Technology type hierarchy - Software Server [8086bc7a-ad3f-466e-90d7-799eeec9266e]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n8086bc7a-ad3f-466e-90d7-799eeec9266e(\"`*SoftwareServer:deployedImplementationType*\n**Software Server**`\")\na3ad8720-2320-4687-9aa9-9968d5f8f3f9(\"`*SoftwareServer:deployedImplementationType*\n**OMAG Server**`\")\nae502604-62dc-4a11-80b9-53ab39cc2bf1(\"`*SoftwareServer:deployedImplementationType*\n**Engine Host**`\")\n4ff55a45-174f-4f88-ba7f-9ea2da3adcd7(\"`*SoftwareServer:deployedImplementationType*\n**Integration Daemon**`\")\n16999ab5-ffd3-47b1-bbfb-79ae850a67e0(\"`*SoftwareServer:deployedImplementationType*\n**Metadata Access Server**`\")\n89868dc5-a94b-488a-9d0b-062999b336d2(\"`*SoftwareServer:deployedImplementationType*\n**View Server**`\")\n4390ac78-92af-4a1c-9760-fc4eb793ccec(\"`*SoftwareServer:deployedImplementationType*\n**PostgreSQL Server**`\")\ndbc0f469-713f-4175-a432-cbb233e1f88b(\"`*SoftwareServerPlatform:deployedImplementationType*\n**OMAG Server Runtime**`\")\n7ef1b6de-3c8b-4977-8fd2-66a7573c6eef(\"`*SoftwareServerPlatform:deployedImplementationType*\n**OMAG Server Platform**`\")\nf207e9f3-a8b0-4fc3-a004-9c7011e5bba8(\"`*SoftwareServer:deployedImplementationType*\n**Marquez Server**`\")\n8086bc7a-ad3f-466e-90d7-799eeec9266e-->a3ad8720-2320-4687-9aa9-9968d5f8f3f9\n8086bc7a-ad3f-466e-90d7-799eeec9266e-->4390ac78-92af-4a1c-9760-fc4eb793ccec\n8086bc7a-ad3f-466e-90d7-799eeec9266e-->dbc0f469-713f-4175-a432-cbb233e1f88b\n8086bc7a-ad3f-466e-90d7-799eeec9266e-->7ef1b6de-3c8b-4977-8fd2-66a7573c6eef\n8086bc7a-ad3f-466e-90d7-799eeec9266e-->f207e9f3-a8b0-4fc3-a004-9c7011e5bba8\na3ad8720-2320-4687-9aa9-9968d5f8f3f9-->ae502604-62dc-4a11-80b9-53ab39cc2bf1\na3ad8720-2320-4687-9aa9-9968d5f8f3f9-->4ff55a45-174f-4f88-ba7f-9ea2da3adcd7\na3ad8720-2320-4687-9aa9-9968d5f8f3f9-->16999ab5-ffd3-47b1-bbfb-79ae850a67e0\na3ad8720-2320-4687-9aa9-9968d5f8f3f9-->89868dc5-a94b-488a-9d0b-062999b336d2\n"

# %%
render_mermaid(mermaid_graph)
# Out:
#     <div class="mermaid">
#         ---
# title: Technology type hierarchy - Software Server [8086bc7a-ad3f-466e-90d7-799eeec9266e]
# ---
# flowchart TD
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# 8086bc7a-ad3f-466e-90d7-799eeec9266e("`*SoftwareServer:deployedImplementationType*
# **Software Server**`")
# a3ad8720-2320-4687-9aa9-9968d5f8f3f9("`*SoftwareServer:deployedImplementationType*
# **OMAG Server**`")
# ae502604-62dc-4a11-80b9-53ab39cc2bf1("`*SoftwareServer:deployedImplementationType*
# **Engine Host**`")
# 4ff55a45-174f-4f88-ba7f-9ea2da3adcd7("`*SoftwareServer:deployedImplementationType*
# **Integration Daemon**`")
# 16999ab5-ffd3-47b1-bbfb-79ae850a67e0("`*SoftwareServer:deployedImplementationType*
# **Metadata Access Server**`")
# 89868dc5-a94b-488a-9d0b-062999b336d2("`*SoftwareServer:deployedImplementationType*
# **View Server**`")
# 4390ac78-92af-4a1c-9760-fc4eb793ccec("`*SoftwareServer:deployedImplementationType*
# **PostgreSQL Server**`")
# ...

# %%
mermaid_graph="---\ntitle: Technology type hierarchy - Root Technology Type [3adcc010-9118-4b9d-abc9-6eb466ea2e9c]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n3adcc010-9118-4b9d-abc9-6eb466ea2e9c(\"`*Referenceable:deployedImplementationType*\n**Root Technology Type**`\")\ned6fca34-8083-47ed-be86-7149b2b838b6(\"`*BareMetalComputer:deployedImplementationType*\n**Bare Metal Computer**`\")\n6bdc3631-c608-4112-a7b4-59f09754a8e2(\"`*BareMetalComputer:deployedImplementationType*\n**Small Form Factor (SFF) Computer**`\")\ne70cd4b8-e02e-4f75-8952-89696d207093(\"`*BareMetalComputer:deployedImplementationType*\n**Laptop Computer**`\")\nb4e5958b-a8bf-4475-b990-29d2a8f5f090(\"`*BareMetalComputer:deployedImplementationType*\n**Apple MacBook Pro**`\")\n86f51267-f68b-4f72-bd2c-eb08a5122f94(\"`*SoftwareCapability:deployedImplementationType*\n**Software Capability**`\")\nb7f03d16-80dd-4e40-a5ac-05f4bb8fbd76(\"`*GovernanceEngine:deployedImplementationType*\n**Governance Engine**`\")\n4ad9d999-5ecc-43d8-944b-323c18ab41b9(\"`*ContextEventEngine:deployedImplementationType*\n**Context Event Engine**`\")\n8336f034-0f18-4625-8c71-b9307f86cc2b(\"`*SurveyActionEngine:deployedImplementationType*\n**Survey Action Engine**`\")\ncb3d734f-1530-4d5d-bfe5-33af191c50c1(\"`*GovernanceActionEngine:deployedImplementationType*\n**Governance Action Engine**`\")\n266e3cce-4ba8-4d83-a050-4d1402ee6a68(\"`*RepositoryGovernanceEngine:deployedImplementationType*\n**Repository Governance Engine**`\")\n86753a98-db46-4691-b000-35cde9a7800d(\"`*DatabaseManager:deployedImplementationType*\n**Relational database manager (RDBMS)**`\")\nc90ffbd7-7bab-4757-859a-d0a029272288(\"`*DatabaseManager:deployedImplementationType*\n**PostgreSQL database manager (RDBMS)**`\")\nfedc55c9-a432-4f31-9545-82e2592f49f2(\"`*InventoryCatalog:deployedImplementationType*\n**Asset Metadata Catalog**`\")\na52062df-d925-427e-9728-2ee0b9bdfb48(\"`*DataManager:deployedImplementationType*\n**UNIX File System**`\")\nc2403a3a-5c5e-4fa9-accf-f4567b7cff4a(\"`*UserAuthenticationManager:deployedImplementationType*\n**User Authentication Manager**`\")\n08ece759-457b-4f32-8bbb-3c934cae7cbf(\"`*DataManager:deployedImplementationType*\n**File System**`\")\nc32dc5f9-9af4-4e47-9fbe-36d06d1bd3c1(\"`*EventBroker:deployedImplementationType*\n**Event Broker**`\")\n44c749ce-801a-4fed-b0eb-1045ae127a4a(\"`*APIManager:deployedImplementationType*\n**API Manager**`\")\ne6cada82-8d6c-4516-9a9a-c235b174d110(\"`*APIManager:deployedImplementationType*\n**REST API Manager**`\")\n1c0b40d4-85f8-4ba4-b4df-34286bf9a1a3(\"`*IntegrationGroup:deployedImplementationType*\n**Dynamic Integration Group**`\")\n548f4b5f-3360-4c40-a75d-71ff219a6e69(\"`*Application:deployedImplementationType*\n**Business Application**`\")\nd7e60344-87ab-4ce2-a3e7-5c5d93e4147d(\"`*Endpoint:deployedImplementationType*\n**Endpoint**`\")\n59ab70c0-7e2f-47c8-b553-18a5b9622917(\"`*Endpoint:deployedImplementationType*\n**JDBC Endpoint**`\")\ne13cef95-8582-4700-8c17-4b5b6415efc0(\"`*Endpoint:deployedImplementationType*\n**REST API Endpoint**`\")\n14f4db87-6c29-45d0-934a-549a79d7ea07(\"`*Asset:deployedImplementationType*\n**Asset**`\")\n81db2811-04c3-419b-9eda-e83405684966(\"`*DataAsset:deployedImplementationType*\n**Data Asset**`\")\nd04b8186-7f40-4e5b-8676-af8af26a897b(\"`*KafkaTopic:deployedImplementationType*\n**Apache Kafka Topic**`\")\n8e7d1d1d-62d2-4e30-b3dc-dd2a4548d274(\"`*DeployedDatabaseSchema:deployedImplementationType*\n**JDBC Relational Database Schema**`\")\n05023a11-a5e6-4d15-b6a0-a9e53f130b34(\"`*DeployedDatabaseSchema:deployedImplementationType*\n**PostgreSQL Relational Database Schema**`\")\n8153a074-c499-43b0-aed5-0866b1b4d250(\"`*FileFolder:deployedImplementationType*\n**File System Directory**`\")\n5fb513c9-69ee-414c-9941-204451429787(\"`*DataFolder:deployedImplementationType*\n**Data Folder**`\")\na56a40c5-156d-4369-9baa-bcf628957280(\"`*DataFile:deployedImplementationType*\n**File**`\")\n105c3b28-dba1-4265-927f-9c8b0cb4649a(\"`*DataFile:deployedImplementationType*\n**Program File**`\")\nd48dd8be-dd4a-4750-842f-ce783d935311(\"`*PropertiesFile:deployedImplementationType*\n**Properties File**`\")\n4e81acab-ad9c-428b-b6b3-b1fdfd128966(\"`*YAMLFile:deployedImplementationType*\n**YAML File**`\")\nc8cb8ed8-805e-4419-96d3-33967793951b(\"`*ScriptFile:deployedImplementationType*\n**Script File**`\")\n6ddd2a14-072f-45f5-9a43-1a52e07c4ab6(\"`*SourceCodeFile:deployedImplementationType*\n**Source Code File**`\")\nd7214f17-3162-4fbc-ae4f-b66d2d08ef79(\"`*ExecutableFile:deployedImplementationType*\n**Executable File**`\")\ne7d810bf-af78-4112-ae7c-d160e68be066(\"`*BuildInstructionFile:deployedImplementationType*\n**Build Instruction File**`\")\nea98029b-a432-4b94-9aa1-ef4ff7781f75(\"`*DataFile:deployedImplementationType*\n**Data File**`\")\n821abd5b-3fdc-4e73-903f-2d9e45990823(\"`*VideoFile:deployedImplementationType*\n**Video Data File**`\")\n42b076c5-9647-4570-99de-80bb0b6e834d(\"`*XMLFile:deployedImplementationType*\n**XML Data File**`\")\nb888dab3-5ecd-4dd4-8387-b37e909b5789(\"`*3DImageFile:deployedImplementationType*\n**3D Image Data File**`\")\n4c3707ab-79b8-4640-bb82-46b164ecd674(\"`*JSONFile:deployedImplementationType*\n**JSON Data File**`\")\n4b94afcc-e648-4c8a-8fa7-818e40b634bb(\"`*CSVFile:deployedImplementationType*\n**CSV Data File**`\")\nc2cfddae-ab45-42f7-b8df-bb744d543cc8(\"`*ArchiveFile:deployedImplementationType*\n**Archive File**`\")\n8f15c13f-142d-495e-be95-cd2039e545cd(\"`*SpreadsheetFile:deployedImplementationType*\n**Spreadsheet Data File**`\")\nb4c8dad2-4515-4315-8cf4-02d4425b4544(\"`*ParquetFile:deployedImplementationType*\n**Parquet Data File**`\")\n5b3dd268-2da9-450e-8a90-1d5cd30a6f6d(\"`*LogFile:deployedImplementationType*\n**Log File**`\")\nb2dccca8-04ba-4888-8276-df24f38692b8(\"`*AudioFile:deployedImplementationType*\n**Audio Data File**`\")\ndb4e5e7e-6145-46f6-a6d6-36e97d504f84(\"`*AvroFile:deployedImplementationType*\n**Avro Data File**`\")\ndf5f5bd0-23a9-47db-87c9-fe9263787709(\"`*KeystoreFile:deployedImplementationType*\n**Keystore File**`\")\n3c035220-7016-45a7-b050-187b11f7794c(\"`*VectorFile:deployedImplementationType*\n**Vector Data File**`\")\n613105c2-8bc0-43a6-8c03-052f532c31d2(\"`*RasterFile:deployedImplementationType*\n**Raster Data File**`\")\n3ce34827-91e6-4eba-b9d4-826db86a2fd4(\"`*Document:deployedImplementationType*\n**Document File**`\")\n2732e538-017a-4256-8d6d-4b19194e16c2(\"`*RelationalDatabase:deployedImplementationType*\n**JDBC Relational Database**`\")\nbf31c5ee-fdcf-41bf-bbed-0a4d86b58287(\"`*RelationalDatabase:deployedImplementationType*\n**PostgreSQL Relational Database**`\")\nd460539c-de76-42d7-8162-2942b16dddd6(\"`*TableDataSet:deployedImplementationType*\n**PostgreSQL Relational Database Table**`\")\n13f0f62c-b13d-4363-9133-1cef5c0d2212(\"`*TableDataSet:deployedImplementationType*\n**JDBC Relational Database Table**`\")\n8086bc7a-ad3f-466e-90d7-799eeec9266e(\"`*SoftwareServer:deployedImplementationType*\n**Software Server**`\")\na3ad8720-2320-4687-9aa9-9968d5f8f3f9(\"`*SoftwareServer:deployedImplementationType*\n**OMAG Server**`\")\nae502604-62dc-4a11-80b9-53ab39cc2bf1(\"`*SoftwareServer:deployedImplementationType*\n**Engine Host**`\")\n4ff55a45-174f-4f88-ba7f-9ea2da3adcd7(\"`*SoftwareServer:deployedImplementationType*\n**Integration Daemon**`\")\n16999ab5-ffd3-47b1-bbfb-79ae850a67e0(\"`*SoftwareServer:deployedImplementationType*\n**Metadata Access Server**`\")\n89868dc5-a94b-488a-9d0b-062999b336d2(\"`*SoftwareServer:deployedImplementationType*\n**View Server**`\")\n4390ac78-92af-4a1c-9760-fc4eb793ccec(\"`*SoftwareServer:deployedImplementationType*\n**PostgreSQL Server**`\")\ndbc0f469-713f-4175-a432-cbb233e1f88b(\"`*SoftwareServerPlatform:deployedImplementationType*\n**OMAG Server Runtime**`\")\n7ef1b6de-3c8b-4977-8fd2-66a7573c6eef(\"`*SoftwareServerPlatform:deployedImplementationType*\n**OMAG Server Platform**`\")\nf207e9f3-a8b0-4fc3-a004-9c7011e5bba8(\"`*SoftwareServer:deployedImplementationType*\n**Marquez Server**`\")\n6ea1eab7-e03d-4dd6-beb2-bdd931265f96(\"`*Process:deployedImplementationType*\n**Process**`\")\nd830bf6c-79ad-4415-a28b-befc5cc52e41(\"`*DeployedSoftwareComponent:deployedImplementationType*\n**Software Component**`\")\n791d51ba-8250-49bd-af76-02e0a743ad8f(\"`*DeployedConnector:deployedImplementationType*\n**Open Connector Framework (OCF) Connector**`\")\na9109950-357f-45d6-8515-62d52521653b(\"`*DeployedConnector:deployedImplementationType*\n**Open Metadata Archive Store Connector**`\")\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7(\"`*IntegrationConnector:deployedImplementationType*\n**Integration Connector**`\")\n750ea239-5795-400e-87a3-46dc630be825(\"`*IntegrationConnector:deployedImplementationType*\n**Lineage Integration Connector**`\")\nb857b613-d1c0-41a1-a4b1-ac7494d3a81d(\"`*IntegrationConnector:deployedImplementationType*\n**Organization Integration Connector**`\")\n155175e2-782e-48fd-b096-7cb389fea5e1(\"`*IntegrationConnector:deployedImplementationType*\n**Analytics Integration Connector**`\")\n2d25900b-7353-4c1a-927f-bd42b86de739(\"`*IntegrationConnector:deployedImplementationType*\n**Search Integration Connector**`\")\n3c254fa2-411e-4b39-a2d1-d88e5b6334de(\"`*IntegrationConnector:deployedImplementationType*\n**Topic Integration Connector**`\")\n091a7e00-454b-4ff2-92e6-58ca86b8f4e5(\"`*IntegrationConnector:deployedImplementationType*\n**Files Integration Connector**`\")\n6cffc505-feee-47c3-a858-794ab6214a81(\"`*IntegrationConnector:deployedImplementationType*\n**Database Integration Connector**`\")\nd7fae5d1-10c0-44f3-bb2b-ede604e293ec(\"`*IntegrationConnector:deployedImplementationType*\n**Display Integration Connector**`\")\n5fba1e41-d6bb-4df4-8dcc-7df0c6bb263b(\"`*IntegrationConnector:deployedImplementationType*\n**Catalog Integration Connector**`\")\n718aced1-2433-4d24-8178-dfdf9366d6a4(\"`*IntegrationConnector:deployedImplementationType*\n**Security Integration Connector**`\")\n42022ae5-d173-4cb5-9779-1e0a8cd5802f(\"`*IntegrationConnector:deployedImplementationType*\n**Infrastructure Integration Connector**`\")\n06804bbf-e2b5-4298-a3b1-459d72cb919f(\"`*IntegrationConnector:deployedImplementationType*\n**API Integration Connector**`\")\n29682c43-7c48-4191-a246-bc42cf658ddf(\"`*GovernanceService:deployedImplementationType*\n**Governance Service**`\")\n62906407-5e08-441b-8e6a-5cc8668e7b78(\"`*RepositoryGovernanceService:deployedImplementationType*\n**Repository Governance Service Connector**`\")\nd04c08c0-3c88-4654-a517-75505bdce71f(\"`*GovernanceActionService:deployedImplementationType*\n**Governance Action Service**`\")\na0b1db07-d772-4b5b-bc9f-817d87057028(\"`*ContextEventService:deployedImplementationType*\n**Context Event Service**`\")\n08dcd3fc-62f9-4594-b4a2-88d19d64ae69(\"`*SurveyActionService:deployedImplementationType*\n**Survey Action Service**`\")\n7b9e748e-fd08-4ce2-b158-b067a076c370(\"`*DeployedConnector:deployedImplementationType*\n**Audit Log Destination**`\")\ne96ab2bc-5faf-4768-a370-bf51b1e0373c(\"`*DeployedSoftwareComponent:deployedImplementationType*\n**OMRS Repository Connector**`\")\n2e47115b-705b-4af8-abcc-117d9c3fb3c5(\"`*DeployedConnector:deployedImplementationType*\n**Platform Metadata Security Connector**`\")\nd2d7ef71-70e6-4c8f-942b-745270798b0c(\"`*DeployedConnector:deployedImplementationType*\n**Server Metadata Security Connector**`\")\n4da5c45a-fd81-4762-92a4-3c437575e979(\"`*DeployedConnector:deployedImplementationType*\n**Cohort Registry Store**`\")\n3adcc010-9118-4b9d-abc9-6eb466ea2e9c-->ed6fca34-8083-47ed-be86-7149b2b838b6\n3adcc010-9118-4b9d-abc9-6eb466ea2e9c-->86f51267-f68b-4f72-bd2c-eb08a5122f94\n3adcc010-9118-4b9d-abc9-6eb466ea2e9c-->d7e60344-87ab-4ce2-a3e7-5c5d93e4147d\n3adcc010-9118-4b9d-abc9-6eb466ea2e9c-->14f4db87-6c29-45d0-934a-549a79d7ea07\ned6fca34-8083-47ed-be86-7149b2b838b6-->6bdc3631-c608-4112-a7b4-59f09754a8e2\ned6fca34-8083-47ed-be86-7149b2b838b6-->e70cd4b8-e02e-4f75-8952-89696d207093\ne70cd4b8-e02e-4f75-8952-89696d207093-->b4e5958b-a8bf-4475-b990-29d2a8f5f090\n86f51267-f68b-4f72-bd2c-eb08a5122f94-->b7f03d16-80dd-4e40-a5ac-05f4bb8fbd76\n86f51267-f68b-4f72-bd2c-eb08a5122f94-->86753a98-db46-4691-b000-35cde9a7800d\n86f51267-f68b-4f72-bd2c-eb08a5122f94-
n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->b857b613-d1c0-41a1-a4b1-ac7494d3a81d\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->155175e2-782e-48fd-b096-7cb389fea5e1\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->2d25900b-7353-4c1a-927f-bd42b86de739\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->3c254fa2-411e-4b39-a2d1-d88e5b6334de\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->091a7e00-454b-4ff2-92e6-58ca86b8f4e5\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->6cffc505-feee-47c3-a858-794ab6214a81\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->d7fae5d1-10c0-44f3-bb2b-ede604e293ec\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->5fba1e41-d6bb-4df4-8dcc-7df0c6bb263b\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->718aced1-2433-4d24-8178-dfdf9366d6a4\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->42022ae5-d173-4cb5-9779-1e0a8cd5802f\n4df8788f-ca48-42c3-bf19-2e6187f8dbc7-->06804bbf-e2b5-4298-a3b1-459d72cb919f\n29682c43-7c48-4191-a246-bc42cf658ddf-->62906407-5e08-441b-8e6a-5cc8668e7b78\n29682c43-7c48-4191-a246-bc42cf658ddf-->d04c08c0-3c88-4654-a517-75505bdce71f\n29682c43-7c48-4191-a246-bc42cf658ddf-->a0b1db07-d772-4b5b-bc9f-817d87057028\n29682c43-7c48-4191-a246-bc42cf658ddf-->08dcd3fc-62f9-4594-b4a2-88d19d64ae69\n"

# %%
render_mermaid(mermaid_graph)
# Out:
#     <div class="mermaid">
#         ---
# title: Technology type hierarchy - Root Technology Type [3adcc010-9118-4b9d-abc9-6eb466ea2e9c]
# ---
# flowchart TD
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# 3adcc010-9118-4b9d-abc9-6eb466ea2e9c("`*Referenceable:deployedImplementationType*
# **Root Technology Type**`")
# ed6fca34-8083-47ed-be86-7149b2b838b6("`*BareMetalComputer:deployedImplementationType*
# **Bare Metal Computer**`")
# 6bdc3631-c608-4112-a7b4-59f09754a8e2("`*BareMetalComputer:deployedImplementationType*
# **Small Form Factor (SFF) Computer**`")
# e70cd4b8-e02e-4f75-8952-89696d207093("`*BareMetalComputer:deployedImplementationType*
# **Laptop Computer**`")
# b4e5958b-a8bf-4475-b990-29d2a8f5f090("`*BareMetalComputer:deployedImplementationType*
# **Apple MacBook Pro**`")
# 86f51267-f68b-4f72-bd2c-eb08a5122f94("`*SoftwareCapability:deployedImplementationType*
# **Software Capability**`")
# ...

# %%
mermaid_graph="---\ntitle: Technology type hierarchy - File [a56a40c5-156d-4369-9baa-bcf628957280]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\na56a40c5-156d-4369-9baa-bcf628957280(\"`*DataFile:deployedImplementationType*\n**File**`\")\n105c3b28-dba1-4265-927f-9c8b0cb4649a(\"`*DataFile:deployedImplementationType*\n**Program File**`\")\nd48dd8be-dd4a-4750-842f-ce783d935311(\"`*PropertiesFile:deployedImplementationType*\n**Properties File**`\")\n4e81acab-ad9c-428b-b6b3-b1fdfd128966(\"`*YAMLFile:deployedImplementationType*\n**YAML File**`\")\nc8cb8ed8-805e-4419-96d3-33967793951b(\"`*ScriptFile:deployedImplementationType*\n**Script File**`\")\n6ddd2a14-072f-45f5-9a43-1a52e07c4ab6(\"`*SourceCodeFile:deployedImplementationType*\n**Source Code File**`\")\nd7214f17-3162-4fbc-ae4f-b66d2d08ef79(\"`*ExecutableFile:deployedImplementationType*\n**Executable File**`\")\ne7d810bf-af78-4112-ae7c-d160e68be066(\"`*BuildInstructionFile:deployedImplementationType*\n**Build Instruction File**`\")\nea98029b-a432-4b94-9aa1-ef4ff7781f75(\"`*DataFile:deployedImplementationType*\n**Data File**`\")\n821abd5b-3fdc-4e73-903f-2d9e45990823(\"`*VideoFile:deployedImplementationType*\n**Video Data File**`\")\n42b076c5-9647-4570-99de-80bb0b6e834d(\"`*XMLFile:deployedImplementationType*\n**XML Data File**`\")\nb888dab3-5ecd-4dd4-8387-b37e909b5789(\"`*3DImageFile:deployedImplementationType*\n**3D Image Data File**`\")\n4c3707ab-79b8-4640-bb82-46b164ecd674(\"`*JSONFile:deployedImplementationType*\n**JSON Data File**`\")\n4b94afcc-e648-4c8a-8fa7-818e40b634bb(\"`*CSVFile:deployedImplementationType*\n**CSV Data File**`\")\nc2cfddae-ab45-42f7-b8df-bb744d543cc8(\"`*ArchiveFile:deployedImplementationType*\n**Archive File**`\")\n8f15c13f-142d-495e-be95-cd2039e545cd(\"`*SpreadsheetFile:deployedImplementationType*\n**Spreadsheet Data File**`\")\nb4c8dad2-4515-4315-8cf4-02d4425b4544(\"`*ParquetFile:deployedImplementationType*\n**Parquet Data File**`\")\n5b3dd268-2da9-450e-8a90-1d5cd30a6f6d(\"`*LogFile:deployedImplementationType*\n**Log File**`\")\nb2dccca8-04ba-4888-8276-df24f38692b8(\"`*AudioFile:deployedImplementationType*\n**Audio Data File**`\")\ndb4e5e7e-6145-46f6-a6d6-36e97d504f84(\"`*AvroFile:deployedImplementationType*\n**Avro Data File**`\")\ndf5f5bd0-23a9-47db-87c9-fe9263787709(\"`*KeystoreFile:deployedImplementationType*\n**Keystore File**`\")\n3c035220-7016-45a7-b050-187b11f7794c(\"`*VectorFile:deployedImplementationType*\n**Vector Data File**`\")\n613105c2-8bc0-43a6-8c03-052f532c31d2(\"`*RasterFile:deployedImplementationType*\n**Raster Data File**`\")\n3ce34827-91e6-4eba-b9d4-826db86a2fd4(\"`*Document:deployedImplementationType*\n**Document File**`\")\na56a40c5-156d-4369-9baa-bcf628957280-->105c3b28-dba1-4265-927f-9c8b0cb4649a\na56a40c5-156d-4369-9baa-bcf628957280-->ea98029b-a432-4b94-9aa1-ef4ff7781f75\n105c3b28-dba1-4265-927f-9c8b0cb4649a-->d48dd8be-dd4a-4750-842f-ce783d935311\n105c3b28-dba1-4265-927f-9c8b0cb4649a-->c8cb8ed8-805e-4419-96d3-33967793951b\n105c3b28-dba1-4265-927f-9c8b0cb4649a-->6ddd2a14-072f-45f5-9a43-1a52e07c4ab6\n105c3b28-dba1-4265-927f-9c8b0cb4649a-->d7214f17-3162-4fbc-ae4f-b66d2d08ef79\n105c3b28-dba1-4265-927f-9c8b0cb4649a-->e7d810bf-af78-4112-ae7c-d160e68be066\nd48dd8be-dd4a-4750-842f-ce783d935311-->4e81acab-ad9c-428b-b6b3-b1fdfd128966\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->821abd5b-3fdc-4e73-903f-2d9e45990823\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->42b076c5-9647-4570-99de-80bb0b6e834d\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->b888dab3-5ecd-4dd4-8387-b37e909b5789\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->4c3707ab-79b8-4640-bb82-46b164ecd674\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->4b94afcc-e648-4c8a-8fa7-818e40b634bb\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->c2cfddae-ab45-42f7-b8df-bb744d543cc8\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->8f15c13f-142d-495e-be95-cd2039e545cd\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->b4c8dad2-4515-4315-8cf4-02d4425b4544\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->5b3dd268-2da9-450e-8a90-1d5cd30a6f6d\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->b2dccca8-04ba-4888-8276-df24f38692b8\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->db4e5e7e-6145-46f6-a6d6-36e97d504f84\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->df5f5bd0-23a9-47db-87c9-fe9263787709\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->3c035220-7016-45a7-b050-187b11f7794c\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->613105c2-8bc0-43a6-8c03-052f532c31d2\nea98029b-a432-4b94-9aa1-ef4ff7781f75-->3ce34827-91e6-4eba-b9d4-826db86a2fd4\n"

# %%
render_mermaid(mermaid_graph)
# Out:
#     <div class="mermaid">
#         ---
# title: Technology type hierarchy - File [a56a40c5-156d-4369-9baa-bcf628957280]
# ---
# flowchart TD
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# a56a40c5-156d-4369-9baa-bcf628957280("`*DataFile:deployedImplementationType*
# **File**`")
# 105c3b28-dba1-4265-927f-9c8b0cb4649a("`*DataFile:deployedImplementationType*
# **Program File**`")
# d48dd8be-dd4a-4750-842f-ce783d935311("`*PropertiesFile:deployedImplementationType*
# **Properties File**`")
# 4e81acab-ad9c-428b-b6b3-b1fdfd128966("`*YAMLFile:deployedImplementationType*
# **YAML File**`")
# c8cb8ed8-805e-4419-96d3-33967793951b("`*ScriptFile:deployedImplementationType*
# **Script File**`")
# 6ddd2a14-072f-45f5-9a43-1a52e07c4ab6("`*SourceCodeFile:deployedImplementationType*
# **Source Code File**`")
# d7214f17-3162-4fbc-ae4f-b66d2d08ef79("`*ExecutableFile:deployedImplementationType*
# **Executable File**`")
# ...

# %%
mermaid_graph="---\ntitle: Lineage Graph for Asset - coco-sus [8a578f0d-f7ae-4255-b4a5-236241fa5449]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n8a578f0d-f7ae-4255-b4a5-236241fa5449(\"`*SoftwareServer*\n**coco-sus**`\")\nad8eab54-c2f7-494d-82d0-bf5985e5a58d(\"`*SoftwareServer*\n**coco-expenses**`\")\n88c42780-6fb1-49e2-a584-8af90cdc7728(\"`*SoftwareServer*\n**coco-hrim**`\")\nae0c7768-c01e-4bd1-8a47-fbacfccf2f63(\"`*SoftwareServer*\n**Netherlands payroll**`\")\n12c9d1a4-2a5d-4e7c-a640-97f206270425(\"`*SoftwareServer*\n**UK payroll**`\")\na47906f0-67f0-46ed-890d-85cb049ffa60(\"`*SoftwareServer*\n**cocopages**`\")\n35bef6c5-25d7-47b1-91db-f9bce0238612(\"`*SoftwareServer*\n**Canadian payroll**`\")\n9e29ee1f-01d3-482c-9d1b-8b3f36ce62d2(\"`*SoftwareServer*\n**aus-inventory**`\")\nc24e9ea0-171a-46d8-a5d8-3fedcfe97aa4(\"`*SoftwareServer*\n**MFCTRL9482**`\")\n25e2e56d-2e2f-4f6f-a1ed-019dd76d589a(\"`*SoftwareServer*\n**manufacturing-planning**`\")\na2e43afa-386a-4acd-ba1d-7773b368c34a(\"`*SoftwareServer*\n**globalCRM**`\")\ndd424526-24e9-4a10-a575-0700dfb8743a(\"`*SoftwareServer*\n**cocoProducts**`\")\n11071e76-23a8-4f3d-bd07-3b9aa9781bda(\"`*SoftwareServer*\n**coco-ledgers**`\")\na5abdf72-0e5f-4366-8072-fac3bbb41ea6(\"`*SoftwareServer*\n**procurement05**`\")\n467dd9a0-89d6-4796-a058
print(mermaid_graph)
# Out:
# ---
# title: Lineage Graph for Asset - coco-sus [8a578f0d-f7ae-4255-b4a5-236241fa5449]
# ---
# flowchart TD
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# 8a578f0d-f7ae-4255-b4a5-236241fa5449("`*SoftwareServer*
# **coco-sus**`")
# ad8eab54-c2f7-494d-82d0-bf5985e5a58d("`*SoftwareServer*
# **coco-expenses**`")
# 88c42780-6fb1-49e2-a584-8af90cdc7728("`*SoftwareServer*
# **coco-hrim**`")
# ae0c7768-c01e-4bd1-8a47-fbacfccf2f63("`*SoftwareServer*
# **Netherlands payroll**`")
# 12c9d1a4-2a5d-4e7c-a640-97f206270425("`*SoftwareServer*
# **UK payroll**`")
# a47906f0-67f0-46ed-890d-85cb049ffa60("`*SoftwareServer*
# **cocopages**`")
# 35bef6c5-25d7-47b1-91db-f9bce0238612("`*SoftwareServer*
# **Canadian payroll**`")
# 9e29ee1f-01d3-482c-9d1b-8b3f36ce62d2("`*SoftwareServer*
# **aus-inventory**`")
# c24e9ea0-171a-46d8-a5d8-3fedcfe97aa4("`*SoftwareServer*
# **MFCTRL9482**`")
# 25e2e56d-2e2f-4f6f-a1ed-019dd76d589a("`*SoftwareServer*
# **manufacturing-planning**`")
# ...

# %%
render_mermaid(mermaid_graph)
# Out:
#     <div class="mermaid">
#         ---
# title: Lineage Graph for Asset - coco-sus [8a578f0d-f7ae-4255-b4a5-236241fa5449]
# ---
# flowchart TD
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# 8a578f0d-f7ae-4255-b4a5-236241fa5449("`*SoftwareServer*
# **coco-sus**`")
# ad8eab54-c2f7-494d-82d0-bf5985e5a58d("`*SoftwareServer*
# **coco-expenses**`")
# 88c42780-6fb1-49e2-a584-8af90cdc7728("`*SoftwareServer*
# **coco-hrim**`")
# ae0c7768-c01e-4bd1-8a47-fbacfccf2f63("`*SoftwareServer*
# **Netherlands payroll**`")
# 12c9d1a4-2a5d-4e7c-a640-97f206270425("`*SoftwareServer*
# **UK payroll**`")
# a47906f0-67f0-46ed-890d-85cb049ffa60("`*SoftwareServer*
# **cocopages**`")
# 35bef6c5-25d7-47b1-91db-f9bce0238612("`*SoftwareServer*
# **Canadian payroll**`")
# 9e29ee1f-01d3-482c-9d1b-8b3f36ce62d2("`*SoftwareServer*
# **aus-inventory**`")
# c24e9ea0-171a-46d8-a5d8-3fedcfe97aa4("`*SoftwareServer*
# **MFCTRL9482**`")
# 25e2e56d-2e2f-4f6f-a1ed-019dd76d589a("`*SoftwareServer*
# ...

# %%
mermaid_graph="---\ntitle: Starting Element - 8a578f0d-f7ae-4255-b4a5-236241fa5449\n---\nflowchart LR\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n8a578f0d-f7ae-4255-b4a5-236241fa5449(\"`*Starting from*\n**8a578f0d-f7ae-4255-b4a5-236241fa5449**`\")\n6ec9c4e9-3c98-4b00-b525-403e046522c3(\"`*AssetLocation*\n**Amsterdam Data Centre**`\")\n314a8387-d601-4237-bfc0-9b44a0ad6171(\"`*SupportedSoftwareCapability*\n**DatabaseManager for System:coco-sus**`\")\n096c23fc-ab28-471b-bb73-fcac4da25eb6(\"`*DeployedOn*\n**ams04**`\")\n5a2927f3-eed6-4509-bceb-2c29aa415090(\"`*DataFlow*\n**coco-sus-dashboards**`\")\n11071e76-23a8-4f3d-bd07-3b9aa9781bda(\"`*DataFlow*\n**coco-ledgers**`\")\nad8eab54-c2f7-494d-82d0-bf5985e5a58d(\"`*DataFlow*\n**coco-expenses**`\")\n047691ac-8628-472d-aca0-82bedc947ef4(\"`*DataFlow*\n**austin-haz-mat**`\")\n3dbe7e96-c9e5-4336-a29a-9342258e50f8(\"`*DataFlow*\n**coco-sus-calculators**`\")\n9e29ee1f-01d3-482c-9d1b-8b3f36ce62d2(\"`*DataFlow*\n**aus-inventory**`\")\n6e786315-ae54-445b-b516-f3c1f0e5f289(\"`*DataFlow*\n**coco-haz-mat**`\")\n467dd9a0-89d6-4796-a058-c079bf54b6c7(\"`*DataFlow*\n**coco-inventory**`\")\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|AssetLocation|6ec9c4e9-3c98-4b00-b525-403e046522c3\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|SupportedSoftwareCapability|314a8387-d601-4237-bfc0-9b44a0ad6171\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|DeployedOn|096c23fc-ab28-471b-bb73-fcac4da25eb6\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|DataFlow|5a2927f3-eed6-4509-bceb-2c29aa415090\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|DataFlow|11071e76-23a8-4f3d-bd07-3b9aa9781bda\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|DataFlow|ad8eab54-c2f7-494d-82d0-bf5985e5a58d\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|DataFlow|047691ac-8628-472d-aca0-82bedc947ef4\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|DataFlow|3dbe7e96-c9e5-4336-a29a-9342258e50f8\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|DataFlow|9e29ee1f-01d3-482c-9d1b-8b3f36ce62d2\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|DataFlow|6e786315-ae54-445b-b516-f3c1f0e5f289\n8a578f0d-f7ae-4255-b4a5-236241fa5449-->|DataFlow|467dd9a0-89d6-4796-a058-c079bf54b6c7\n"

# %%
render_mermaid(mermaid_graph)
# Out:
#     <div class="mermaid">
#         ---
# title: Starting Element - 8a578f0d-f7ae-4255-b4a5-236241fa5449
# ---
# flowchart LR
# %%{init: {"flowchart": {"htmlLabels": false}} }%%
#
# 8a578f0d-f7ae-4255-b4a5-236241fa5449("`*Starting from*
# **8a578f0d-f7ae-4255-b4a5-236241fa5449**`")
# 6ec9c4e9-3c98-4b00-b525-403e046522c3("`*AssetLocation*
# **Amsterdam Data Centre**`")
# 314a8387-d601-4237-bfc0-9b44a0ad6171("`*SupportedSoftwareCapability*
# **DatabaseManager for System:coco-sus**`")
# 096c23fc-ab28-471b-bb73-fcac4da25eb6("`*DeployedOn*
# **ams04**`")
# 5a2927f3-eed6-4509-bceb-2c29aa415090("`*DataFlow*
# **coco-sus-dashboards**`")
# 11071e76-23a8-4f3d-bd07-3b9aa9781bda("`*DataFlow*
# **coco-ledgers**`")
# ad8eab54-c2f7-494d-82d0-bf5985e5a58d("`*DataFlow*
# **coco-expenses**`")
# 047691ac-8628-472d-aca0-82bedc947ef4("`*DataFlow*
# **austin-haz-mat**`")
# 3dbe7e96-c9e5-4336-a29a-9342258e50f8("`*DataFlow*
# **coco-sus-calculators**`")
# 9e29ee1f-01d3-482c-9d1b-8b3f36ce62d2("`*DataFlow*
# ...
