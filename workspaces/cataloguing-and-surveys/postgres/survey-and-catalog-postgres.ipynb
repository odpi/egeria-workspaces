# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Egeria Workbook
#
# # Cataloguing and surveying PostgreSQL Servers
#
# ## Introduction
#
# A [PostgreSQL server](https://www.postgresql.org/) is an open source technology that supports multiple relational databases.  The contents of these databases are organized into schemas, tables and columns giving a 4 level name space.  The default schema for a database is called **public** and there is also a special database called **pgcatalog** that provides a metadata catalog for the other databases managed by the servers.  PostgreSQL is a mature, fast and flexible database that is widely use in the industry.   Egeria itself uses a PostgreSQL database as an option for its metadata repository, and for the management of its observability data.
#
# Egeria also has support for understanding and governing postgreSQL databases whatever their use.  This notebook takes you through these capabilities.
#
# First lets initialize **pyegeria**.

# %%
# Initialize pyegeria

# %run ../../pyegeria/initialize-pyegeria.ipynb
# Out:
#     <script src="https://unpkg.com/mermaid@11.4.1/dist/mermaid.min.js"></script>
#     <script>
#         document.addEventListener('DOMContentLoaded', function() {
#             mermaid.initialize({startOnLoad: true});
#         });
#     </script>

# %%
egeria_tech = EgeriaTech(view_server, url, user_id, user_pwd)
token = egeria_tech.create_egeria_bearer_token()

# %% [markdown]
# ---
#
# ## Loading support for PostgreSQL Servers
#
# The definition of the postgres connectors, templates and associated reference data are loaded via a [Content Pack](https://egeria-project.org/content-packs/) called `PostgresContentPack.omarchive`.  The content pack can be loaded multiple times without ill-effect so run the following command to make sure it is loaded.
#
# ---

# %%
egeria_tech.add_archive_file("content-packs/PostgresContentPack.omarchive", None, "qs-metadata-store")

print("Archive loaded!")
# Out:
# Archive loaded!

# %% [markdown]
# ----
#
# ## Survey a PostgreSQL Server
#
# Egeria's PostgreSQL support includes the ability to survey the contents of a PostgreSQL Server to discover the databases that is manages.  This command creates a description of the PostgreSQL Server and runs a survey to understand its contents.  A summary of the survey results can be found in /distribution-hub/surveys.
#
# ---

# %%
createAndSurveyServerName="PostgreSQLServer:CreateAndSurveyGovernanceActionProcess"

process_guid = egeria_tech.get_element_guid_by_unique_name(createAndSurveyServerName)

process_graph = egeria_tech.get_gov_action_process_graph(process_guid)
print_governance_action_process_graph(process_graph)
# Out:
#     <div id="mermaid-graph-626a45d8-196b-49e2-9615-5ec991665072-container" class="diagram-container"
#
#          style="width: 90%; max-width: 800px; margin: auto; padding: 20px;
#                 background: white; border: 1px solid #ddd;
#                 border-radius: 12px; position: relative;">
#
#         <h2 style="text-align: center; color: #007acc; margin-bottom: 16px;">
#             Process - PostgreSQLServer:CreateAndSurvey
#         </h2>
# GUID: 626a45d8-196b-49e2-9615-5ec991665072
#
#         <div class="pan-zoom-container"
#              style="width: 100%; height: 500px; overflow: hidden;
#                     position: relative; background: #f9f9f9;
#                     border: 1px solid #ccc; cursor: grab;">
#             <div id="pz-mermaid-graph-626a45d8-196b-49e2-9615-5ec991665072" class="mermaid pan-zoom-content"
#                  style="position: absolute; transform-origin: 0 0;">
#                 flowchart LR
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 8de6f60b-3184-4f65-a95f-092109fc2136(&quot;`*Governance Action Process Step*
# **Create the asset entity**`&quot;)
# 725fdcc4-d05a-4033-9f1f-40cf373c8a3b(&quot;`*Governance Action Process Step*
# **Run the survey.**`&quot;)
# 5eb84d65-fbc6-4801-a5f8-fa01cf708da3(&quot;`*Governance Action Process Step*
# **Print the survey report.**`&quot;)
# 8de6f60b-3184-4f65-a95f-092109fc2136==&gt;|&quot;set-up-complete&quot;|725fdcc4-d05a-4033-9f1f-40cf373c8a3b
# 725fdcc4-d05a-4033-9f1f-40cf373c8a3b==&gt;|&quot;survey-completed&quot;|5eb84d65-fbc6-4801-a5f8-fa01cf708da3
#             </div>
#         </div>
#     </div>
#     <script>
#         (function() {
#             // Ensure Mermaid.js is loaded
#             if (typeof mermaid === "undefined") {
#                 const script = document.createElement('script');
#                 script.src = "https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js";
#                 script.onload = () => renderGraph();
#                 document.head.appendChild(script);
#             } else {
#                 renderGraph();
#             }
#
#             function renderGraph() {
#                 // Render the Mermaid graph
#                 mermaid.initialize({ startOnLoad: true });
#                 mermaid.init(undefined, `#pz-mermaid-graph-626a45d8-196b-49e2-9615-5ec991665072`);
#
#                 // Pan and Zoom Variables
#                 const container = document.querySelector(`#mermaid-graph-626a45d8-196b-49e2-9615-5ec991665072-container .pan-zoom-container`);
#                 const content = document.querySelector(`#mermaid-graph-626a45d8-196b-49e2-9615-5ec991665072-container .pan-zoom-content`);
#
#                 if (!container || !content) {
#                     console.error("Pan/Zoom container or content not found");
#                     return;
#                 }
#
#                 let scale = 1;  // Current zoom level
#                 let panX = 0;   // X-axis pan
#                 let panY = 0;   // Y-axis pan
#                 let isDragging = false;
#                 let startX, startY;
#
#                 // Apply Transformations
#                 const applyTransform = () => {
#                     content.style.transform = `translate(${panX}px, ${panY}px) scale(${scale})`;
#                 };
#
#                 // Center Diagram on Load
#                 const centerAndFitDiagram = () => {
#                     const containerRect = container.getBoundingClientRect();
#                     const rect = content.getBoundingClientRect();
#
#                     // Calculate scale
#                     scale = Math.min(
#                         containerRect.width / rect.width,
#                         containerRect.height / rect.height
#                     );
#
#                     // Set panning to center the diagram
#                     panX = (containerRect.width - rect.width * scale) / 2;
#                     panY = (containerRect.height - rect.height * scale) / 2;
#
#                     applyTransform();
#                 };
#
#                 // Delay centering to ensure rendering is complete
#                 setTimeout(centerAndFitDiagram, 500);
#
#                 // Pan/Drag Logic
#                 container.addEventListener("mousedown", (e) => {
#                     isDragging = true;
#                     startX = e.clientX - panX;
#                     startY = e.clientY - panY;
#                     container.style.cursor = "grabbing";
#                 });
#
#                 window.addEventListener("mousemove", (e) => {
#                     if (!isDragging) return;
#                     panX = e.clientX - startX;
#                     panY = e.clientY - startY;
#                     applyTransform();
#                 });
#
#                 window.addEventListener("mouseup", () => {
#                     isDragging = false;
#                     container.style.cursor = "grab";
#                 });
#
#                 // Scroll-Wheel Zoom Logic
#                 container.addEventListener("wheel", (e) => {
#                     e.preventDefault();
#                     const delta = -Math.sign(e.deltaY); // Dynamic zoom direction
#                     const zoomIntensity = 0.1; // Adjust zoom speed
#                     const zoomFactor = 1 + delta * zoomIntensity;
#
#                     scale *= zoomFactor;
#
#                     // Clamp the zoom level to a minimum and maximum level
#                     scale = Math.min(Math.max(scale, 0.5), 5);
#
#                     applyTransform();
#                 });
#             }
#         })();
#     </script>
#     <div id="mermaid-graph-626a45d8-196b-49e2-9615-5ec991665072-container" class="diagram-container"
#
#          style="width: 90%; max-width: 800px; margin: auto; padding: 20px;
#                 background: white; border: 1px solid #ddd;
#                 border-radius: 12px; position: relative;">
#
#         <h2 style="text-align: center; color: #007acc; margin-bottom: 16px;">
#             Specification for - PostgreSQLServer:CreateAndSurvey
#         </h2>
# GUID: 626a45d8-196b-49e2-9615-5ec991665072
#
#         <div class="pan-zoom-container"
#              style="width: 100%; height: 500px; overflow: hidden;
#                     position: relative; background: #f9f9f9;
#                     border: 1px solid #ccc; cursor: grab;">
#             <div id="pz-mermaid-graph-626a45d8-196b-49e2-9615-5ec991665072" class="mermaid pan-zoom-content"
#                  style="position: absolute; transform-origin: 0 0;">
#                 flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# supportedRequestParameter(&quot;`*property Type*
# **supportedRequestParameter**`&quot;)
# supportedRequestParameter:0(&quot;`**secretsStorePathName**
# dataType: string
# description: The full path name to the secrets store file where the secrets collection for this server is located.
# required: true
# example: loading-bay/secrets/default.omsecrets
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:0
# supportedRequestParameter:1(&quot;`**description**
# dataType: string
# required: true
# example: This file contains a week&#x27;s worth of patient data for the Teddy Bear Drop Foot clinical trial.
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:1
# supportedRequestParameter:2(&quot;`**hostIdentifier**
# dataType: string
# description: The host IP address or domain name.
# required: true
# example: coconet.com
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:2
# supportedRequestParameter:3(&quot;`**versionIdentifier**
# dataType: string
# description: The string version identifier for the element.  This is typically of the form Vx.y.z where x is the major version number, y is the minor version number, and z is an option patch identifier.
# required: true
# example: V1.0
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:3
# supportedRequestParameter:4(&quot;`**portNumber**
# dataType: string
# description: The number of the port to use to connect to a service.
# required: true
# example: 1234
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:4
# supportedRequestParameter:5(&quot;`**serverName**
# dataType: string
# description: The name of the server being catalogued.
# required: true
# example: myServer
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:5
#             </div>
#         </div>
#     </div>
#     <script>
#         (function() {
#             // Ensure Mermaid.js is loaded
#             if (typeof mermaid === "undefined") {
#                 const script = document.createElement('script');
#                 script.src = "https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js";
#                 script.onload = () => renderGraph();
#                 document.head.appendChild(script);
#             } else {
#                 renderGraph();
#             }
#
#             function renderGraph() {
#                 // Render the Mermaid graph
#                 mermaid.initialize({ startOnLoad: true });
#                 mermaid.init(undefined, `#pz-mermaid-graph-626a45d8-196b-49e2-9615-5ec991665072`);
#
#                 // Pan and Zoom Variables
#                 const container = document.querySelector(`#mermaid-graph-626a45d8-196b-49e2-9615-5ec991665072-container .pan-zoom-container`);
#                 const content = document.querySelector(`#mermaid-graph-626a45d8-196b-49e2-9615-5ec991665072-container .pan-zoom-content`);
#
#                 if (!container || !content) {
#                     console.error("Pan/Zoom container or content not found");
#                     return;
#                 }
#
#                 let scale = 1;  // Current zoom level
#                 let panX = 0;   // X-axis pan
#                 let panY = 0;   // Y-axis pan
#                 let isDragging = false;
#                 let startX, startY;
#
#                 // Apply Transformations
#                 const applyTransform = () => {
#                     content.style.transform = `translate(${panX}px, ${panY}px) scale(${scale})`;
#                 };
#
#                 // Center Diagram on Load
#                 const centerAndFitDiagram = () => {
#                     const containerRect = container.getBoundingClientRect();
#                     const rect = content.getBoundingClientRect();
#
#                     // Calculate scale
#                     scale = Math.min(
#                         containerRect.width / rect.width,
#                         containerRect.height / rect.height
#                     );
#
#                     // Set panning to center the diagram
#                     panX = (containerRect.width - rect.width * scale) / 2;
#                     panY = (containerRect.height - rect.height * scale) / 2;
#
#                     applyTransform();
#                 };
#
#                 // Delay centering to ensure rendering is complete
#                 setTimeout(centerAndFitDiagram, 500);
#
#                 // Pan/Drag Logic
#                 container.addEventListener("mousedown", (e) => {
#                     isDragging = true;
#                     startX = e.clientX - panX;
#                     startY = e.clientY - panY;
#                     container.style.cursor = "grabbing";
#                 });
#
#                 window.addEventListener("mousemove", (e) => {
#                     if (!isDragging) return;
#                     panX = e.clientX - startX;
#                     panY = e.clientY - startY;
#                     applyTransform();
#                 });
#
#                 window.addEventListener("mouseup", () => {
#                     isDragging = false;
#                     container.style.cursor = "grab";
#                 });
#
#                 // Scroll-Wheel Zoom Logic
#                 container.addEventListener("wheel", (e) => {
#                     e.preventDefault();
#                     const delta = -Math.sign(e.deltaY); // Dynamic zoom direction
#                     const zoomIntensity = 0.1; // Adjust zoom speed
#                     const zoomFactor = 1 + delta * zoomIntensity;
#
#                     scale *= zoomFactor;
#
#                     // Clamp the zoom level to a minimum and maximum level
#                     scale = Math.min(Math.max(scale, 0.5), 5);
#
#                     applyTransform();
#                 });
#             }
#         })();
#     </script>

# %%
requestParameters = {
    "serverName" : "LocalPostgreSQL1",
    "hostIdentifier" : "localhost",
    "portNumber" : "5442",
    "secretsStorePathName" : "loading-bay/secrets/default.omsecrets",
    "versionIdentifier" : "1.0",
    "description" : "PostgreSQL database in egeria-workspaces."
}

egeria_tech.initiate_gov_action_process(createAndSurveyServerName, None, None, None, requestParameters, None, None)
# Out:
# 'a96abc23-716a-47f2-b3ea-54e86734fce6'

# %% [markdown]
# ----
#
# This next command catalogs the databases it finds on the PostgreSQL Server.
#
# ----

# %%
createAndCatalogServerName="PostgreSQLServer:CreateAsCatalogTargetGovernanceActionProcess"

process_guid = egeria_tech.get_element_guid_by_unique_name(createAndCatalogServerName)

process_graph = egeria_tech.get_gov_action_process_graph(process_guid)
print_governance_action_process_graph(process_graph)
# Out:
#     <div id="mermaid-graph-1c1683e2-ca8f-4e43-84c8-4bfce6c9488a-container" class="diagram-container"
#
#          style="width: 90%; max-width: 800px; margin: auto; padding: 20px;
#                 background: white; border: 1px solid #ddd;
#                 border-radius: 12px; position: relative;">
#
#         <h2 style="text-align: center; color: #007acc; margin-bottom: 16px;">
#             Process - PostgreSQLServer:CreateAsCatalogTarget
#         </h2>
# GUID: 1c1683e2-ca8f-4e43-84c8-4bfce6c9488a
#
#         <div class="pan-zoom-container"
#              style="width: 100%; height: 500px; overflow: hidden;
#                     position: relative; background: #f9f9f9;
#                     border: 1px solid #ccc; cursor: grab;">
#             <div id="pz-mermaid-graph-1c1683e2-ca8f-4e43-84c8-4bfce6c9488a" class="mermaid pan-zoom-content"
#                  style="position: absolute; transform-origin: 0 0;">
#                 flowchart LR
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# d30f59d2-5b76-4c28-82fb-bee706f5b281(&quot;`*Governance Action Process Step*
# **Create the SoftwareServer entity**`&quot;)
# 72003a6c-79b7-4acc-b2f1-2ba441315550(&quot;`*Governance Action Process Step*
# **Connect new asset to integration connector**`&quot;)
# d30f59d2-5b76-4c28-82fb-bee706f5b281==&gt;|&quot;set-up-complete&quot;|72003a6c-79b7-4acc-b2f1-2ba441315550
#             </div>
#         </div>
#     </div>
#     <script>
#         (function() {
#             // Ensure Mermaid.js is loaded
#             if (typeof mermaid === "undefined") {
#                 const script = document.createElement('script');
#                 script.src = "https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js";
#                 script.onload = () => renderGraph();
#                 document.head.appendChild(script);
#             } else {
#                 renderGraph();
#             }
#
#             function renderGraph() {
#                 // Render the Mermaid graph
#                 mermaid.initialize({ startOnLoad: true });
#                 mermaid.init(undefined, `#pz-mermaid-graph-1c1683e2-ca8f-4e43-84c8-4bfce6c9488a`);
#
#                 // Pan and Zoom Variables
#                 const container = document.querySelector(`#mermaid-graph-1c1683e2-ca8f-4e43-84c8-4bfce6c9488a-container .pan-zoom-container`);
#                 const content = document.querySelector(`#mermaid-graph-1c1683e2-ca8f-4e43-84c8-4bfce6c9488a-container .pan-zoom-content`);
#
#                 if (!container || !content) {
#                     console.error("Pan/Zoom container or content not found");
#                     return;
#                 }
#
#                 let scale = 1;  // Current zoom level
#                 let panX = 0;   // X-axis pan
#                 let panY = 0;   // Y-axis pan
#                 let isDragging = false;
#                 let startX, startY;
#
#                 // Apply Transformations
#                 const applyTransform = () => {
#                     content.style.transform = `translate(${panX}px, ${panY}px) scale(${scale})`;
#                 };
#
#                 // Center Diagram on Load
#                 const centerAndFitDiagram = () => {
#                     const containerRect = container.getBoundingClientRect();
#                     const rect = content.getBoundingClientRect();
#
#                     // Calculate scale
#                     scale = Math.min(
#                         containerRect.width / rect.width,
#                         containerRect.height / rect.height
#                     );
#
#                     // Set panning to center the diagram
#                     panX = (containerRect.width - rect.width * scale) / 2;
#                     panY = (containerRect.height - rect.height * scale) / 2;
#
#                     applyTransform();
#                 };
#
#                 // Delay centering to ensure rendering is complete
#                 setTimeout(centerAndFitDiagram, 500);
#
#                 // Pan/Drag Logic
#                 container.addEventListener("mousedown", (e) => {
#                     isDragging = true;
#                     startX = e.clientX - panX;
#                     startY = e.clientY - panY;
#                     container.style.cursor = "grabbing";
#                 });
#
#                 window.addEventListener("mousemove", (e) => {
#                     if (!isDragging) return;
#                     panX = e.clientX - startX;
#                     panY = e.clientY - startY;
#                     applyTransform();
#                 });
#
#                 window.addEventListener("mouseup", () => {
#                     isDragging = false;
#                     container.style.cursor = "grab";
#                 });
#
#                 // Scroll-Wheel Zoom Logic
#                 container.addEventListener("wheel", (e) => {
#                     e.preventDefault();
#                     const delta = -Math.sign(e.deltaY); // Dynamic zoom direction
#                     const zoomIntensity = 0.1; // Adjust zoom speed
#                     const zoomFactor = 1 + delta * zoomIntensity;
#
#                     scale *= zoomFactor;
#
#                     // Clamp the zoom level to a minimum and maximum level
#                     scale = Math.min(Math.max(scale, 0.5), 5);
#
#                     applyTransform();
#                 });
#             }
#         })();
#     </script>
#     <div id="mermaid-graph-1c1683e2-ca8f-4e43-84c8-4bfce6c9488a-container" class="diagram-container"
#
#          style="width: 90%; max-width: 800px; margin: auto; padding: 20px;
#                 background: white; border: 1px solid #ddd;
#                 border-radius: 12px; position: relative;">
#
#         <h2 style="text-align: center; color: #007acc; margin-bottom: 16px;">
#             Specification for - PostgreSQLServer:CreateAsCatalogTarget
#         </h2>
# GUID: 1c1683e2-ca8f-4e43-84c8-4bfce6c9488a
#
#         <div class="pan-zoom-container"
#              style="width: 100%; height: 500px; overflow: hidden;
#                     position: relative; background: #f9f9f9;
#                     border: 1px solid #ccc; cursor: grab;">
#             <div id="pz-mermaid-graph-1c1683e2-ca8f-4e43-84c8-4bfce6c9488a" class="mermaid pan-zoom-content"
#                  style="position: absolute; transform-origin: 0 0;">
#                 flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# supportedRequestParameter(&quot;`*property Type*
# **supportedRequestParameter**`&quot;)
# supportedRequestParameter:0(&quot;`**versionIdentifier**
# dataType: string
# description: The string version identifier for the element.  This is typically of the form Vx.y.z where x is the major version number, y is the minor version number, and z is an option patch identifier.
# required: true
# example: V1.0
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:0
# supportedRequestParameter:1(&quot;`**hostIdentifier**
# dataType: string
# description: The host IP address or domain name.
# required: true
# example: coconet.com
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:1
# supportedRequestParameter:2(&quot;`**secretsStorePathName**
# dataType: string
# description: The full path name to the secrets store file where the secrets collection for this server is located.
# required: true
# example: loading-bay/secrets/default.omsecrets
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:2
# supportedRequestParameter:3(&quot;`**description**
# dataType: string
# required: true
# example: This file contains a week&#x27;s worth of patient data for the Teddy Bear Drop Foot clinical trial.
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:3
# supportedRequestParameter:4(&quot;`**portNumber**
# dataType: string
# description: The number of the port to use to connect to a service.
# required: true
# example: 1234
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:4
# supportedRequestParameter:5(&quot;`**serverName**
# dataType: string
# description: The name of the server being catalogued.
# required: true
# example: myServer
# `&quot;)
# supportedRequestParameter==&gt;supportedRequestParameter:5
#             </div>
#         </div>
#     </div>
#     <script>
#         (function() {
#             // Ensure Mermaid.js is loaded
#             if (typeof mermaid === "undefined") {
#                 const script = document.createElement('script');
#                 script.src = "https://cdn.jsdelivr.net/npm/mermaid/dist/mermaid.min.js";
#                 script.onload = () => renderGraph();
#                 document.head.appendChild(script);
#             } else {
#                 renderGraph();
#             }
#
#             function renderGraph() {
#                 // Render the Mermaid graph
#                 mermaid.initialize({ startOnLoad: true });
#                 mermaid.init(undefined, `#pz-mermaid-graph-1c1683e2-ca8f-4e43-84c8-4bfce6c9488a`);
#
#                 // Pan and Zoom Variables
#                 const container = document.querySelector(`#mermaid-graph-1c1683e2-ca8f-4e43-84c8-4bfce6c9488a-container .pan-zoom-container`);
#                 const content = document.querySelector(`#mermaid-graph-1c1683e2-ca8f-4e43-84c8-4bfce6c9488a-container .pan-zoom-content`);
#
#                 if (!container || !content) {
#                     console.error("Pan/Zoom container or content not found");
#                     return;
#                 }
#
#                 let scale = 1;  // Current zoom level
#                 let panX = 0;   // X-axis pan
#                 let panY = 0;   // Y-axis pan
#                 let isDragging = false;
#                 let startX, startY;
#
#                 // Apply Transformations
#                 const applyTransform = () => {
#                     content.style.transform = `translate(${panX}px, ${panY}px) scale(${scale})`;
#                 };
#
#                 // Center Diagram on Load
#                 const centerAndFitDiagram = () => {
#                     const containerRect = container.getBoundingClientRect();
#                     const rect = content.getBoundingClientRect();
#
#                     // Calculate scale
#                     scale = Math.min(
#                         containerRect.width / rect.width,
#                         containerRect.height / rect.height
#                     );
#
#                     // Set panning to center the diagram
#                     panX = (containerRect.width - rect.width * scale) / 2;
#                     panY = (containerRect.height - rect.height * scale) / 2;
#
#                     applyTransform();
#                 };
#
#                 // Delay centering to ensure rendering is complete
#                 setTimeout(centerAndFitDiagram, 500);
#
#                 // Pan/Drag Logic
#                 container.addEventListener("mousedown", (e) => {
#                     isDragging = true;
#                     startX = e.clientX - panX;
#                     startY = e.clientY - panY;
#                     container.style.cursor = "grabbing";
#                 });
#
#                 window.addEventListener("mousemove", (e) => {
#                     if (!isDragging) return;
#                     panX = e.clientX - startX;
#                     panY = e.clientY - startY;
#                     applyTransform();
#                 });
#
#                 window.addEventListener("mouseup", () => {
#                     isDragging = false;
#                     container.style.cursor = "grab";
#                 });
#
#                 // Scroll-Wheel Zoom Logic
#                 container.addEventListener("wheel", (e) => {
#                     e.preventDefault();
#                     const delta = -Math.sign(e.deltaY); // Dynamic zoom direction
#                     const zoomIntensity = 0.1; // Adjust zoom speed
#                     const zoomFactor = 1 + delta * zoomIntensity;
#
#                     scale *= zoomFactor;
#
#                     // Clamp the zoom level to a minimum and maximum level
#                     scale = Math.min(Math.max(scale, 0.5), 5);
#
#                     applyTransform();
#                 });
#             }
#         })();
#     </script>

# %%
requestParameters = {
    "serverName" : "LocalPostgreSQL1",
    "hostIdentifier" : "host.docker.internal",
    "portNumber" : "5442",
    "secretsStorePathName" : "loading-bay/secrets/default.omsecrets",
    "versionIdentifier" : "1.0",
    "description" : "PostgreSQL database in egeria-workspaces."
}

egeria_tech.initiate_gov_action_process(createAndCatalogServerName, None, None, None, requestParameters, None, None)
# Out:
# 'd41ffe37-13cc-4ee3-a58a-920af61671d6'
