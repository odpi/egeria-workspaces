# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Egeria Workbook
#
# # Querying glossaries
#
# ## Introduction

# %%
# Initialize pyegeria

# %run ../pyegeria/initialize-pyegeria.ipynb
# Out:
#     <script src="https://unpkg.com/mermaid@11.6.0/dist/mermaid.min.js"></script>
#     <script>
#         document.addEventListener('DOMContentLoaded', function() {
#             mermaid.initialize({startOnLoad: true},
#             {maxTextSize: 300000});
#         });
#     </script>

# %%
egeria_tech = EgeriaTech(view_server, url, user_id, user_pwd)
token = egeria_tech.create_egeria_bearer_token()

# %%
egeria_tech.add_archive_file("content-packs/CloudInformationModel.omarchive", None, "qs-metadata-store")

print("Archive loaded!")
# Out:
# Archive loaded!

# %%
egeria_tech.add_archive_file("content-packs/SimpleCatalog.omarchive", None, "qs-metadata-store")

print("Archive loaded!")
# Out:
# Archive loaded!

# %%
egeria_tech.add_archive_file("content-packs/CocoComboArchive.omarchive", None, "qs-metadata-store")

print("Archive loaded!")
# Out:
# Archive loaded!

# %%
egeria_cat = EgeriaCat(view_server, url, user_id, user_pwd)
egeria_cat.set_bearer_token(token)

# %%
print_glossaries(egeria_tech, "Glossary::CloudInformationModel")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-7a20c26c-266e-45e3-82f5-c20cace5d7ee-0aa9-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary - Cloud Information Model (CIM)
#                 </h3>
#                 <p id="mermaid-graph-7a20c26c-266e-45e3-82f5-c20cace5d7ee-0aa9-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 7a20c26c-266e-45e3-82f5-c20cace5d7ee
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary*
# **Cloud Information Model (CIM)**&quot;}
# 2@{ shape: text, label: &quot;*Description*
# **The Cloud Information Model (CIM) is an open source data model that describes commerce concepts such as parties, products, sales order, payments and shipments.**&quot;}
# 2~~~1
# subgraph 3 [Classifications]
# direction TB
# 4@{ shape: rounded, label: &quot;*Anchors*
# **anchorTypeName
#  - Glossary
# anchorDomainName
#  - Glossary
# anchorGUID
#  - 7a20c26c-266e-45e3-82f5-c20cace5d7ee
# **&quot;}
# 5@{ shape: rounded, label: &quot;*Canonical Vocabulary*
# **scope
#  - People, organizations, accounts and contact details, orders and payments.
# **&quot;}
# end
# 6@{ shape: docs, label: &quot;*External Reference*
# **https:/ /github.com/cloudinformationmodel/cloudinformationmodel**&quot;}
# 1==&gt;|&quot;External Reference Link&quot;|6
# subgraph 7 [Category Hierarchy]
# direction LR
# 8@{ shape: rect, label: &quot;*Glossary Category*
# **Property Groups for the Cloud Information Model (CIM)**&quot;}
# 9@{ shape: rect, label: &quot;*Glossary Category*
# **Storage Property Group**&quot;}
# 8-.-&gt;9
# 10@{ shape: rect, label: &quot;*Glossary Category*
# **Buying Property Group**&quot;}
# 8-.-&gt;10
# 11@{ shape: rect, label: &quot;*Glossary Category*
# **Disposition Property Group**&quot;}
# 8-.-&gt;11
# 12@{ shape: rect, label: &quot;*Glossary Category*
# **Weighting Property Group**&quot;}
# 8-.-&gt;12
# 13@{ shape: rect, label: &quot;*Glossary Category*
# ** Property Group**&quot;}
# 8-.-&gt;13
# 14@{ shape: rect, label: &quot;*Glossary Category*
# **Progress Property Group**&quot;}
# 8-.-&gt;14
# 15@{ shape: rect, label: &quot;*Glossary Category*
# **Training Property Group**&quot;}
# 8-.-&gt;15
# 16@{ shape: rect, label: &quot;*Glossary Category*
# **Sizing Property Group**&quot;}
# 8-.-&gt;16
# 17@{ shape: rect, label: &quot;*Glossary Category*
# **Usage Property Group**&quot;}
# 8-.-&gt;17
# 18@{ shape: rect, label: &quot;*Glossary Category*
# **Define Property Group**&quot;}
# 8-.-&gt;18
# 19@{ shape: rect, label: &quot;*Glossary Category*
# **Interaction Property Group**&quot;}
# 8-.-&gt;19
# 20@{ shape: rect, label: &quot;*Glossary Category*
# **Legal Property Group**&quot;}
# 8-.-&gt;20
# 21@{ shape: rect, label: &quot;*Glossary Category*
# **Use Property Group**&quot;}
# 8-.-&gt;21
# 22@{ shape: rect, label: &quot;*Glossary Category*
# **Business Interaction Property Group**&quot;}
# 8-.-&gt;22
# 23@{ shape: rect, label: &quot;*Glossary Category*
# **Shipping Property Group**&quot;}
# 8-.-&gt;23
# 24@{ shape: rect, label: &quot;*Glossary Category*
# **Defining Property Group**&quot;}
# 8-.-&gt;24
# 25@{ shape: rect, label: &quot;*Glossary Category*
# **ContactInfo Property Group**&quot;}
# 8-.-&gt;25
# 26@{ shape: rect, label: &quot;*Glossary Category*
# **Naming Property Group**&quot;}
# 8-.-&gt;26
# 27@{ shape: rect, label: &quot;*Glossary Category*
# **AccountContact Property Group**&quot;}
# 8-.-&gt;27
# 28@{ shape: rect, label: &quot;*Glossary Category*
# **Life Cycle Property Group**&quot;}
# 8-.-&gt;28
# 29@{ shape: rect, label: &quot;*Glossary Category*
# **Party Property Group**&quot;}
# 8-.-&gt;29
# 30@{ shape: rect, label: &quot;*Glossary Category*
# **Rating - Satisfaction Property Group**&quot;}
# 8-.-&gt;30
# 31@{ shape: rect, label: &quot;*Glossary Category*
# **Contact Consent Property Group**&quot;}
# 8-.-&gt;31
# 32@{ shape: rect, label: &quot;*Glossary Category*
# **Score Calculation Property Group**&quot;}
# 8-.-&gt;32
# 33@{ shape: rect, label: &quot;*Glossary Category*
# **Detailed Info Property Group**&quot;}
# 8-.-&gt;33
# 34@{ shape: rect, label: &quot;*Glossary Category*
# **Shipment Property Group**&quot;}
# 8-.-&gt;34
# 35@{ shape: rect, label: &quot;*Glossary Category*
# **Asset Property Group**&quot;}
# 8-.-&gt;35
# 36@{ shape: rect, label: &quot;*Glossary Category*
# **CRE Property Group**&quot;}
# 8-.-&gt;36
# 37@{ shape: rect, label: &quot;*Glossary Category*
# **payment Property Group**&quot;}
# 8-.-&gt;37
# 38@{ shape: rect, label: &quot;*Glossary Category*
# **Taxation Property Group**&quot;}
# 8-.-&gt;38
# 39@{ shape: rect, label: &quot;*Glossary Category*
# **Geography Property Group**&quot;}
# 8-.-&gt;39
# 40@{ shape: rect, label: &quot;*Glossary Category*
# **Translated Property Group**&quot;}
# 8-.-&gt;40
# 41@{ shape: rect, label: &quot;*Glossary Category*
# **Engagement Property Group**&quot;}
# 8-.-&gt;41
# 42@{ shape: rect, label: &quot;*Glossary Category*
# **Operational Property Group**&quot;}
# 8-.-&gt;42
# 43@{ shape: rect, label: &quot;*Glossary Category*
# **Scope Property Group**&quot;}
# 8-.-&gt;43
# 44@{ shape: rect, label: &quot;*Glossary Category*
# **Address Property Group**&quot;}
# 8-.-&gt;44
# 45@{ shape: rect, label: &quot;*Glossary Category*
# **Billing Property Group**&quot;}
# 8-.-&gt;45
# 46@{ shape: rect, label: &quot;*Glossary Category*
# **Lead Property Group**&quot;}
# 8-.-&gt;46
# 47@{ shape: rect, label: &quot;*Glossary Category*
# **Styling Property Group**&quot;}
# 8-.-&gt;47
# 48@{ shape: rect, label: &quot;*Glossary Category*
# **Success Property Group**&quot;}
# 8-.-&gt;48
# 49@{ shape: rect, label: &quot;*Glossary Category*
# **BusinessInfo Property Group**&quot;}
# 8-.-&gt;49
# 50@{ shape: rect, label: &quot;*Glossary Category*
# **Result Property Group**&quot;}
# 8-.-&gt;50
# 51@{ shape: rect, label: &quot;*Glossary Category*
# **Denormalized Property Group**&quot;}
# 8-.-&gt;51
# 52@{ shape: rect, label: &quot;*Glossary Category*
# **Sales Property Group**&quot;}
# 8-.-&gt;52
# 53@{ shape: rect, label: &quot;*Glossary Category*
# **Marketing Property Group**&quot;}
# 8-.-&gt;53
# 54@{ shape: rect, label: &quot;*Glossary Category*
# **Financial Property Group**&quot;}
# 8-.-&gt;54
# 55@{ shape: rect, label: &quot;*Glossary Category*
# **Support Property Group**&quot;}
# 8-.-&gt;55
# 56@{ shape: rect, label: &quot;*Glossary Category*
# **Classification Property Group**&quot;}
# 8-.-&gt;56
# 57@{ shape: rect, label: &quot;*Glossary Category*
# **Campaign Property Group**&quot;}
# 8-.-&gt;57
# 58@{ shape: rect, label: &quot;*Glossary Category*
# **identifying Property Group**&quot;}
# 8-.-&gt;58
# 59@{ shape: rect, label: &quot;*Glossary Category*
# **Basic Property Group**&quot;}
# 8-.-&gt;59
# 60@{ shape: rect, label: &quot;*Glossary Category*
# **Contract Property Group**&quot;}
# 8-.-&gt;60
# 61@{ shape: rect, label: &quot;*Glossary Category*
# **Credit Memo Property Group**&quot;}
# 8-.-&gt;61
# 62@{ shape: rect, label: &quot;*Glossary Category*
# **Fulfillment Property Group**&quot;}
# 8-.-&gt;62
# 63@{ shape: rect, label: &quot;*Glossary Category*
# **System Property Group**&quot;}
# 8-.-&gt;63
# 64@{ shape: rect, label: &quot;*Glossary Category*
# **Rating - Competitive Property Group**&quot;}
# 8-.-&gt;64
# 65@{ shape: rect, label: &quot;*Glossary Category*
# **Id Property Group**&quot;}
# 8-.-&gt;65
# 66@{ shape: rect, label: &quot;*Glossary Category*
# **Deployment Property Group**&quot;}
# 8-.-&gt;66
# 67@{ shape: rect, label: &quot;*Glossary Category*
# **Geographic Property Group**&quot;}
# 8-.-&gt;67
# 68@{ shape: rect, label: &quot;*Glossary Category*
# **Psychographic Property Group**&quot;}
# 8-.-&gt;68
# 69@{ shape: rect, label: &quot;*Glossary Category*
# **Opportunity Property Group**&quot;}
# 8-.-&gt;69
# 70@{ shape: rect, label: &quot;*Glossary Category*
# **Descriptive Property Group**&quot;}
# 8-.-&gt;70
# 71@{ shape: rect, label: &quot;*Glossary Category*
# **SalesDiscount Property Group**&quot;}
# 8-.-&gt;71
# 72@{ shape: rect, label: &quot;*Glossary Category*
# **Incorporation Property Group**&quot;}
# 8-.-&gt;72
# 73@{ shape: rect, label: &quot;*Glossary Category*
# **Validity Property G

# %%
print_glossaries(egeria_tech, "Sustainability")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-30bfe79e-adf2-4fda-b9c5-9c86ad6b0d6c-1a0b-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary - Sustainability Glossary
#                 </h3>
#                 <p id="mermaid-graph-30bfe79e-adf2-4fda-b9c5-9c86ad6b0d6c-1a0b-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 30bfe79e-adf2-4fda-b9c5-9c86ad6b0d6c
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary*
# **Sustainability Glossary**&quot;}
# 2@{ shape: text, label: &quot;*Description*
# **Terminology associated with Coco Pharmaceutical&#x27;s sustainability initiative.**&quot;}
# 2~~~1
# subgraph 3 [Classifications]
# direction TB
# 4@{ shape: rounded, label: &quot;*Anchors*
# **anchorTypeName
#  - Glossary
# anchorDomainName
#  - Glossary
# anchorGUID
#  - 30bfe79e-adf2-4fda-b9c5-9c86ad6b0d6c
# **&quot;}
# 5@{ shape: rounded, label: &quot;*Subject Area*
# **name
#  - SubjectArea:Sustainability
# **&quot;}
# 6@{ shape: rounded, label: &quot;*Canonical Vocabulary*
# **scope
#  - Across Coco Pharmaceuticals
# **&quot;}
# end
# subgraph 7 [Category Hierarchy]
# direction LR
# 8@{ shape: rect, label: &quot;*Glossary Category*
# **Chemicals**&quot;}
# end
# 1-.-&gt;7
# style 1 color:#FFFFFF, fill:#008080, stroke:#000000
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 4 color:#000000, fill:#e0ab18, stroke:#004563
# style 5 color:#000000, fill:#e0ab18, stroke:#004563
# style 6 color:#000000, fill:#e0ab18, stroke:#004563
# style 7 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 8 color:#FFFFFF, fill:#008080, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_glossary_categories(egeria_tech, "Chemicals")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-0759666b-5aff-4840-8432-63389bd2326a-9b37-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary Category - Chemicals
#                 </h3>
#                 <p id="mermaid-graph-0759666b-5aff-4840-8432-63389bd2326a-9b37-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 0759666b-5aff-4840-8432-63389bd2326a
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Category*
# **Chemicals**&quot;}
# 2@{ shape: text, label: &quot;*Description*
# **Types of chemicals that are significant in managing sustainability.**&quot;}
# 2~~~1
# 3@{ shape: rect, label: &quot;*Glossary*
# **Sustainability Glossary**&quot;}
# 3-.-&gt;1
# subgraph 4 [Terms]
# 5@{ shape: rect, label: &quot;*Glossary Term*
# **Hydrofluorocarbon**&quot;}
# 6@{ shape: rect, label: &quot;*Glossary Term*
# **Carbon Dioxide**&quot;}
# end
# 1-.-&gt;4
# style 1 color:#FFFFFF, fill:#008080, stroke:#000000
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#FFFFFF, fill:#008080, stroke:#000000
# style 4 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 5 color:#000000, fill:#66cdaa, stroke:#008080
# style 6 color:#000000, fill:#66cdaa, stroke:#008080
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_glossary_categories(egeria_tech, "Party")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-ac5c56c2-af69-4b59-bd7a-4718cf45f58c-2c50-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary Category - PartyRole Property Group
#                 </h3>
#                 <p id="mermaid-graph-ac5c56c2-af69-4b59-bd7a-4718cf45f58c-2c50-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: ac5c56c2-af69-4b59-bd7a-4718cf45f58c
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Category*
# **PartyRole Property Group**&quot;}
# 2@{ shape: rect, label: &quot;*Glossary*
# **Cloud Information Model (CIM)**&quot;}
# 3@{ shape: rect, label: &quot;*Glossary Category*
# **Property Groups for the Cloud Information Model (CIM)**&quot;}
# 2-.-&gt;3
# 3-.-&gt;1
# subgraph 4 [Terms]
# 5@{ shape: rect, label: &quot;*Glossary Term*
# **Seller Tier**&quot;}
# end
# 1-.-&gt;4
# style 1 color:#FFFFFF, fill:#008080, stroke:#000000
# style 2 color:#FFFFFF, fill:#008080, stroke:#000000
# style 3 color:#FFFFFF, fill:#008080, stroke:#000000
# style 4 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 5 color:#000000, fill:#66cdaa, stroke:#008080
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>
#     <div>
#                 <h3 id="mermaid-graph-dc447e00-4873-4e5f-afdf-1ee4a38943fb-f375-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary Category - Party Property Group
#                 </h3>
#                 <p id="mermaid-graph-dc447e00-4873-4e5f-afdf-1ee4a38943fb-f375-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: dc447e00-4873-4e5f-afdf-1ee4a38943fb
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Category*
# **Party Property Group**&quot;}
# 2@{ shape: rect, label: &quot;*Glossary*
# **Cloud Information Model (CIM)**&quot;}
# 3@{ shape: rect, label: &quot;*Glossary Category*
# **Property Groups for the Cloud Information Model (CIM)**&quot;}
# 2-.-&gt;3
# 3-.-&gt;1
# subgraph 4 [Terms]
# 5@{ shape: rect, label: &quot;*Glossary Term*
# **Customer Status**&quot;}
# 6@{ shape: rect, label: &quot;*Glossary Term*
# **License Expiration Date**&quot;}
# 7@{ shape: rect, label: &quot;*Glossary Term*
# **Party Professional Credential Type**&quot;}
# 8@{ shape: rect, label: &quot;*Glossary Term*
# **Party Hierarchy Start Date**&quot;}
# 9@{ shape: rect, label: &quot;*Glossary Term*
# **Web Site URL**&quot;}
# 10@{ shape: rect, label: &quot;*Glossary Term*
# **Individual Full Name**&quot;}
# 11@{ shape: rect, label: &quot;*Glossary Term*
# **Middle Name**&quot;}
# 12@{ shape: rect, label: &quot;*Glossary Term*
# **Suffix**&quot;}
# 13@{ shape: rect, label: &quot;*Glossary Term*
# **Software Application Version**&quot;}
# 14@{ shape: rect, label: &quot;*Glossary Term*
# **Customer**&quot;}
# 15@{ shape: rect, label: &quot;*Glossary Term*
# **Party Hierarchy Type**&quot;}
# 5~~~15
# 16@{ shape: rect, label: &quot;*Glossary Term*
# **First Name**&quot;}
# 6~~~16
# 17@{ shape: rect, label: &quot;*Glossary Term*
# **License Issued Date**&quot;}
# 7~~~17
# 18@{ shape: rect, label: &quot;*Glossary Term*
# **Second Last Name**&quot;}
# 8~~~18
# 19@{ shape: rect, label: &quot;*Glossary Term*
# **Full Name**&quot;}
# 9~~~19
# 20@{ shape: rect, label: &quot;*Glossary Term*
# **Party Additional Name Type**&quot;}
# 10~~~20
# 21@{ shape: rect, label: &quot;*Glossary Term*
# **SDK Version Name**&quot;}
# 11~~~21
# 22@{ shape: rect, label: &quot;*Glossary Term*
# **Begin Effective Date**&quot;}
# 12~~~22
# 23@{ shape: rect, label: &quot;*Glossary Term*
# **Software Application Prior Version**&quot;}
# 13~~~23
# 24@{ shape: rect, label: &quot;*Glossary Term*
# **Membership Start Date**&quot;}
# 14~~~24
# 25@{ shape: rect, label: &quot;*Glossary Term*
# **Tax Exemption Start Date**&quot;}
# 15~~~25
# 26@{ shape: rect, label: &quot;*Glossary Term*
# **Party Hierarchy**&quot;}
# 16~~~26
# 27@{ shape: rect, label: &quot;*Glossary Term*
# **Award Issuer Name**&quot;}
# 17~~~27
# 28@{ shape: rect, label: &quot;*Glossary Term*
# **Tax Exemption End Date**&quot;}
# 18~~~28
# 29@{ shape: rect, label: &quot;*Glossary Term*
# **Parent Party Identification Type**&quot;}
# 19~~~29
# 30@{ shape: rect, label: &quot;*Glossary Term*
# **Last Name**&quot;}
# 20~~~30
# 31@{ shape: rect, label: &quot;*Glossary Term*
# **End Effective Date**&quot;}
# 21~~~31
# 32@{ shape: rect, label: &quot;*Glossary Term*
# **Party**&quot;}
# 22~~~32
# 33@{ shape: rect, label: &quot;*Glossary Term*
# **Organization Name**&quot;}
# 23~~~33
# 34@{ shape: rect, label: &quot;*Glossary Term*
# **Training Point Total**&quot;}
# 24~~~34
# 35@{ shape: rect, label: &quot;*Glossary Term*
# **Membership End Date**&quot;}
# 25~~~35
# 36@{ shape: rect, label: &quot;*Glossary Term*
# **Product Name**&quot;}
# 26~~~36
# 37@{ shape: rect, label: &quot;*Glossary Term*
# **License Number**&quot;}
# 27~~~37
# 38@{ shape: rect, label: &quot;*Glossary Term*
# **Tax Exemption Certificate Number**&quot;}
# 28~~~38
# 39@{ shape: rect, label: &quot;*Glossary Term*
# **Organization Legal Name**&quot;}
# 29~~~39
# 40@{ shape: rect, label: &quot;*Glossary Term*
# **Party Hierarchy End Date**&quot;}
# 30~~~40
# 41@{ shape: rect, label: &quot;*Glossary Term*
# **Accreditation Issuer Name**&quot;}
# 31~~~41
# 42@{ shape: rect, label: &quot;*Glossary Term*
# **Tax Exemption Jurisdiction**&quot;}
# 32~~~42
# 43@{ shape: rect, label: &quot;*Glossary Term*
# **Training Tier Name**&quot;}
# 33~~~43
# end
# 1-.-&gt;4
# style 22 color:#000000, fill:#66cdaa, stroke:#008080
# style 23 color:#000000, fill:#66cdaa, stroke:#008080
# style 24 color:#000000, fill:#66cdaa, stroke:#008080
# style 25 color:#000000, fill:#66cdaa, stroke:#008080
# style 26 color:#000000, fill:#66cdaa, stroke:#008080
# style 27 color:#000000, fill:#66cdaa, stroke:#008080
# style 28 color:#000000, fill:#66cdaa, stroke:#008080
# style 29 color:#000000, fill:#66cdaa, stroke:#008080
# style 30 color:#000000, fill:#66cdaa, stroke:#008080
# style 31 color:#000000, fill:#66cdaa, stroke:#008080
# style 10 color:#000000, fill:#66cdaa, stroke:#008080
# style 32 color:#000000, fill:#66cdaa, stroke:#008080
# style 11 color:#000000, fill:#66cdaa, stroke:#008080
# style 33 color:#000000, fill:#66cdaa, stroke:#008080
# style 12 color:#000000, fill:#66cdaa, stroke:#008080
# style 34 color:#000000, fill:#66cdaa, stroke:#008080
# style 13 color:#000000, fill:#66cdaa, stroke:#008080
# style 35 color:#000000, fill:#66cdaa, stroke:#008080
# style 14 color:#000000, fill:#66cdaa, stroke:#008080
# style 36 color:#000000, fill:#66cdaa, stroke:#008080
# style 15 color:#000000, fill:#66cdaa, stroke:#008080
# style 37 color:#000000, fill:#66cdaa, stroke:#008080
# style 16 color:#000000, fill:#66cdaa, stroke:#008080
# style 38 color:#000000, fill:#66cdaa, stroke:#008080
# style 17 color:#000000, fill:#66cdaa, stroke:#008080
# style 39 color:#000000, fill:#66cdaa, stroke:#008080
# style 18 color:#000000, fill:#66cdaa, stroke:#008080
# style 19 color:#000000, fill:#66cdaa, stroke:#008080
# style 1 color:#FFFFFF, fill:#008080, stroke:#000000
# style 2 color:#FFFFFF, fill:#008080, stroke:#000000
# style 3 color:#FFFFFF, fill:#008080, stroke:#000000
# style 4 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 5 color:#000000, fill:#66cdaa, stroke:#008080
# style 6 color:#000000, fill:#66cdaa, stroke:#008080
# style 7 color:#000000, fill:#66cdaa, stroke:#008080
# style 8 color:#000000, fill:#66cdaa, stroke:#008080
# style 9 color:#000000, fill:#66cdaa, stroke:#008080
# style 40 color:#000000, fill:#66cdaa, stroke:#008080
# style 41 color:#000000, fill:#66cdaa, stroke:#008080
# style 20 color:#000000, fill:#66cdaa, stroke:#008080
# style 42 color:#000000, fill:#66cdaa, stroke:#008080
# style 21 color:#000000, fill:#66cdaa, stroke:#008080
# style 43 color:#000000, fill:#66cdaa, stroke:#008080
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_glossary_terms(egeria_tech, "Party Role")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-28c3e831-f6c4-49c9-88ab-684d86ff07c1-0c37-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary Term - Party Role
#                 </h3>
#                 <p id="mermaid-graph-28c3e831-f6c4-49c9-88ab-684d86ff07c1-0c37-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 28c3e831-f6c4-49c9-88ab-684d86ff07c1
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Term*
# **Party Role**&quot;}
# subgraph 2 [Term Details]
# 3@{ shape: text, label: &quot;*Description*
# **Trading roles a party may play at the same time i.e. Customer, Supplier, Seller, Competitor, Worker**&quot;}
# end
# 4@{ shape: rect, label: &quot;*Glossary*
# **Cloud Information Model (CIM)**&quot;}
# 5@{ shape: rect, label: &quot;*Glossary Category*
# **Employee Property Group**&quot;}
# 4-.-&gt;5
# 5-.-&gt;1
# style 1 color:#000000, fill:#66cdaa, stroke:#008080
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 4 color:#FFFFFF, fill:#008080, stroke:#000000
# style 5 color:#FFFFFF, fill:#008080, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>
#     <div>
#                 <h3 id="mermaid-graph-1e35f588-9dee-4cf9-9768-b05bac0b9186-ceeb-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary Term - Party Role
#                 </h3>
#                 <p id="mermaid-graph-1e35f588-9dee-4cf9-9768-b05bac0b9186-ceeb-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 1e35f588-9dee-4cf9-9768-b05bac0b9186
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Term*
# **Party Role**&quot;}
# subgraph 2 [Term Details]
# 3@{ shape: text, label: &quot;*Description*
# **Trading roles a party may play at the same time i.e. Customer, Supplier, Seller, Competitor, Worker**&quot;}
# end
# 4@{ shape: rect, label: &quot;*Glossary*
# **Cloud Information Model (CIM)**&quot;}
# 5@{ shape: rect, label: &quot;*Glossary Category*
# **Id Property Group**&quot;}
# 4-.-&gt;5
# 5-.-&gt;1
# style 1 color:#000000, fill:#66cdaa, stroke:#008080
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 4 color:#FFFFFF, fill:#008080, stroke:#000000
# style 5 color:#FFFFFF, fill:#008080, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>
#     <div>
#                 <h3 id="mermaid-graph-9509dc98-b858-4e8d-8362-53640f50ac06-3df4-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary Term - Party Role
#                 </h3>
#                 <p id="mermaid-graph-9509dc98-b858-4e8d-8362-53640f50ac06-3df4-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 9509dc98-b858-4e8d-8362-53640f50ac06
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Term*
# **Party Role**&quot;}
# subgraph 2 [Term Details]
# 3@{ shape: text, label: &quot;*Description*
# **Trading roles a party may play at the same time i.e. Customer, Supplier, Seller, Competitor, Worker**&quot;}
# end
# 4@{ shape: rect, label: &quot;*Glossary*
# **Cloud Information Model (CIM)**&quot;}
# 5@{ shape: rect, label: &quot;*Glossary Category*
# **Define Property Group**&quot;}
# 4-.-&gt;5
# 5-.-&gt;1
# style 1 color:#000000, fill:#66cdaa, stroke:#008080
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 4 color:#FFFFFF, fill:#008080, stroke:#000000
# style 5 color:#FFFFFF, fill:#008080, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>
#     <div>
#                 <h3 id="mermaid-graph-c723bec6-8adb-4c46-baaa-e389a1e1dd25-fab2-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary Term - Party Role
#                 </h3>
#                 <p id="mermaid-graph-c723bec6-8adb-4c46-baaa-e389a1e1dd25-fab2-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: c723bec6-8adb-4c46-baaa-e389a1e1dd25
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Term*
# **Party Role**&quot;}
# subgraph 2 [Term Details]
# 3@{ shape: text, label: &quot;*Description*
# **Trading roles a party may play at the same time i.e. Customer, Supplier, Seller, Competitor, Worker**&quot;}
# end
# 4@{ shape: rect, label: &quot;*Glossary*
# **Cloud Information Model (CIM)**&quot;}
# 5@{ shape: rect, label: &quot;*Glossary Category*
# **Basic Property Group**&quot;}
# 4-.-&gt;5
# 5-.-&gt;1
# style 1 color:#000000, fill:#66cdaa, stroke:#008080
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 4 color:#FFFFFF, fill:#008080, stroke:#000000
# style 5 color:#FFFFFF, fill:#008080, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>
#     <div>
#                 <h3 id="mermaid-graph-d122b413-75e7-4077-a743-188b79ef8c8d-3b2a-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary Term - Related Party Role
#                 </h3>
#                 <p id="mermaid-graph-d122b413-75e7-4077-a743-188b79ef8c8d-3b2a-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: d122b413-75e7-4077-a743-188b79ef8c8d
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Term*
# **Related Party Role**&quot;}
# subgraph 2 [Term Details]
# 3@{ shape: text, label: &quot;*Description*
# **What is the secondary party role this relation involves**&quot;}
# end
# 4@{ shape: rect, label: &quot;*Glossary*
# **Cloud Information Model (CIM)**&quot;}
# 5@{ shape: rect, label: &quot;*Glossary Category*
# **Define Property Group**&quot;}
# 4-.-&gt;5
# 5-.-&gt;1
# style 1 color:#000000, fill:#66cdaa, stroke:#008080
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 4 color:#FFFFFF, fill:#008080, stroke:#000000
# style 5 color:#FFFFFF, fill:#008080, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_glossary_terms(egeria_tech, "Right Hip")
# Out:
#     <div></div>
#     <div class="mermaid">
#         ---
# title: Glossary Term - Right Hip Rotation Angle [60df8a83-50da-485b-9545-c337559948d6]
# ---
# flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: card, label: &quot;*Template Substitute*
# **Right Hip Rotation Angle**&quot;}
# subgraph 2 [Term Details]
# 3@{ shape: text, label: &quot;*Summary*
# **Template Substitute for Right Hip Rotation Angle**&quot;}
# end
# 4@{ shape: rect, label: &quot;*Glossary*
# **Coco Pharmaceuticals Clinical Trial Terminology**&quot;}
# 5@{ shape: rect, label: &quot;*Glossary Category*
# **Template substitutes**&quot;}
# 4-.-&gt;5
# 5-.-&gt;1
# 6@{ shape: rect, label: &quot;*Glossary Term*
# **Right Hip Rotation Angle**&quot;}
# 1==&gt;|&quot;Sourced From&quot;|6
# 7@{ shape: rect, label: &quot;*Tabular Column*
# **AngleRight**&quot;}
# 1 8@-- &quot;Semantic Assignment&quot; ------&gt;7
# 9@{ shape: rounded, label: &quot;*C  S  V  File*
# **54dc48be-98d9-4ee2-87aa-d072b4cad07a**&quot;}
# 7-. &quot;Anchored to&quot; .-&gt;9
# 10@{ shape: rect, label: &quot;*Tabular Column*
# **AngleRight**&quot;}
# 1 11@-- &quot;Semantic Assignment&quot; ------&gt;10
# 12@{ shape: rounded, label: &quot;*C  S  V  File*
# **4dfb19c2-9087-43fe-af4d-29aa7f7b7144**&quot;}
# 10-. &quot;Anchored to&quot; .-&gt;12
# style 1 color:#004563, fill:#b0e0e6, stroke:#004563
# style 12 color:#000000, fill:#e0ab18, stroke:#004563
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 4 color:#FFFFFF, fill:#008080, stroke:#000000
# style 5 color:#FFFFFF, fill:#008080, stroke:#000000
# style 6 color:#000000, fill:#66cdaa, stroke:#008080
# style 7 color:#FFFFCC, fill:#7d669e, stroke:#CCFFFF
# style 9 color:#000000, fill:#e0ab18, stroke:#004563
# style 10 color:#FFFFCC, fill:#7d669e, stroke:#CCFFFF
# 11@{ animation: fast }
# 8@{ animation: fast }
#
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>
#     <div>
#                 <h3 id="mermaid-graph-363a54e0-2196-4d1c-b153-c10dc58440e1-fc87-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary Term - Right Hip Rotation Angle
#                 </h3>
#                 <p id="mermaid-graph-363a54e0-2196-4d1c-b153-c10dc58440e1-fc87-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 363a54e0-2196-4d1c-b153-c10dc58440e1
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Term*
# **Right Hip Rotation Angle**&quot;}
# subgraph 2 [Term Details]
# 3@{ shape: text, label: &quot;*Summary*
# **The number of degrees of rotation of the right foot measured from vertical.**&quot;}
# end
# 4@{ shape: rect, label: &quot;*Glossary*
# **Coco Pharmaceuticals Clinical Trial Terminology**&quot;}
# 5@{ shape: rect, label: &quot;*Glossary Category*
# **Teddy Bear Drop Foot Data Fields**&quot;}
# 4-.-&gt;5
# 5-.-&gt;1
# 6@{ shape: card, label: &quot;*Template Substitute*
# **Right Hip Rotation Angle**&quot;}
# 1==&gt;|&quot;Sourced From&quot;|6
# style 1 color:#000000, fill:#66cdaa, stroke:#008080
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 4 color:#FFFFFF, fill:#008080, stroke:#000000
# style 5 color:#FFFFFF, fill:#008080, stroke:#000000
# style 6 color:#004563, fill:#b0e0e6, stroke:#004563
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
print_glossary_terms(egeria_tech, "CustomerId")
# Out:
#     <div>
#                 <h3 id="mermaid-graph-a27b8894-e1ae-48f4-a854-904db9e0fc06-6770-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Glossary Term - Sold To Customer
#                 </h3>
#                 <p id="mermaid-graph-a27b8894-e1ae-48f4-a854-904db9e0fc06-6770-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: a27b8894-e1ae-48f4-a854-904db9e0fc06
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Term*
# **Sold To Customer**&quot;}
# subgraph 2 [Term Details]
# 3@{ shape: text, label: &quot;*Description*
# **Reference to the Customer (party role) of a person who is buyer (sell-to), when that is different than the bill-to for the sales order.**&quot;}
# end
# 4@{ shape: rect, label: &quot;*Glossary*
# **Cloud Information Model (CIM)**&quot;}
# 5@{ shape: rect, label: &quot;*Glossary Category*
# **Buying Property Group**&quot;}
# 4-.-&gt;5
# 5-.-&gt;1
# style 1 color:#000000, fill:#66cdaa, stroke:#008080
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 4 color:#FFFFFF, fill:#008080, stroke:#000000
# style 5 color:#FFFFFF, fill:#008080, stroke:#000000
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>
#     <div></div>
#     <div class="mermaid">
#         ---
# title: Glossary Term - UniqueCustomerIdentifier [912e7871-539a-46a8-b17c-665d772eaa2f]
# ---
# flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rect, label: &quot;*Glossary Term*
# **UniqueCustomerIdentifier**&quot;}
# subgraph 2 [Term Details]
# 3@{ shape: text, label: &quot;*Description*
# **Unique identifier for a customer generated on first contact.**&quot;}
# end
# 4@{ shape: rect, label: &quot;*Glossary*
# **Main Glossary**&quot;}
# 4-.-&gt;1
# 5@{ shape: rect, label: &quot;*Event Schema Attribute*
# **customerId**&quot;}
# 1 6@-- &quot;Semantic Assignment&quot; ------&gt;5
# 7@{ shape: rounded, label: &quot;*Kafka  Topic*
# **fa67f6eb-f299-4056-ad64-4307a98a43d0**&quot;}
# 5-. &quot;Anchored to&quot; .-&gt;7
# 8@{ shape: rect, label: &quot;*Relational Column*
# **CUSTID**&quot;}
# 1 9@-- &quot;Semantic Assignment&quot; ------&gt;8
# 10@{ shape: rounded, label: &quot;*Deployed  Database  Schema*
# **8b9cce34-ff42-4f9d-b4b3-6317c8a767c3**&quot;}
# 8-. &quot;Anchored to&quot; .-&gt;10
# 11@{ shape: rect, label: &quot;*A P I Parameter*
# **customerNo**&quot;}
# 1 12@-- &quot;Semantic Assignment&quot; ------&gt;11
# 13@{ shape: rounded, label: &quot;*Deployed  A  P  I*
# **bf2da857-4829-47a4-a9ee-94becc709baa**&quot;}
# 11-. &quot;Anchored to&quot; .-&gt;13
# 14@{ shape: rect, label: &quot;*A P I Parameter*
# **customerNo**&quot;}
# 1 15@-- &quot;Semantic Assignment&quot; ------&gt;14
# 14-. &quot;Anchored to&quot; .-&gt;13
# style 11 color:#FFFFCC, fill:#7d669e, stroke:#CCFFFF
# style 1 color:#000000, fill:#66cdaa, stroke:#008080
# style 2 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 13 color:#000000, fill:#e0ab18, stroke:#004563
# style 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7
# style 14 color:#FFFFCC, fill:#7d669e, stroke:#CCFFFF
# style 4 color:#FFFFFF, fill:#008080, stroke:#000000
# style 5 color:#FFFFCC, fill:#7d669e, stroke:#CCFFFF
# style 7 color:#000000, fill:#e0ab18, stroke:#004563
# style 8 color:#FFFFCC, fill:#7d669e, stroke:#CCFFFF
# style 10 color:#000000, fill:#e0ab18, stroke:#004563
# 12@{ animation: fast }
# 15@{ animation: fast }
# 6@{ animation: fast }
# 9@{ animation: fast }
#
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>
