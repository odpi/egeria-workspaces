# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Coco Pharmaceuticals Labs
#
# # Run Sustainability Initiative Samples
#
# The subfolders in this folder contain samples for defining different parts of the sustainability initiative at [Coco Pharmaceuticals](https://egeria-project.org/practices/coco-pharmaceuticals/). Each gives an explanation and code for how to perform the specific task.  You can go through them in turn if this detail is interesting.  Alternatively, if you just want the metadata loaded, then run this notebook and it will choreograph the execution of them in a single run.
#
# -----

# %%
# %run <notebook name>
