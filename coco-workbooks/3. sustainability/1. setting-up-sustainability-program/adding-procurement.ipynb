# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Egeria Workbook
#
# # Adding Procurement Business Capability
#
# As part of the sustainability initiative [Tom Tally]() notices that the Procurement function is not represented in her sustainability community.  This notebook adds a new business capabilty for procurement, creates a community role and appoints Sally Counter as the representative.
#
# ----

# %%
identifier="PROCUREMENT"
displayName="Procurement"
description="Purchasing of goods and services for Coco Pharmaceuticals. Responsible for managing supplier relationships."
