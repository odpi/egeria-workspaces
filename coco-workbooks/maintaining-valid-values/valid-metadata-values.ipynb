# %% [markdown]
# # Valid Metadata Values Samples

# %%
import json
import time
import os
from rich import print, print_json
from rich.console import Console
from rich.markdown import Markdown

from pyegeria import (
    ValidMetadataManager,
    InvalidParameterException,
    PropertyServerException,
    UserNotAuthorizedException,
    ValidMetadataManager,
    print_basic_exception, PyegeriaException,
    settings, load_app_config,
    render_mermaid
)
env = settings.Environment
EGERIA_USER = os.environ.get("EGERIA_USER", "erinoverview")
EGERIA_USER_PASSWORD = os.environ.get("EGERIA_USER_PASSWORD", "secret")
console = Console(width = 250)

# %%
client = ValidMetadataManager(view_server=env.egeria_view_server, 
                              platform_url = env.egeria_view_server_url,
                              user_id = EGERIA_USER, 
                              user_pwd = EGERIA_USER_PASSWORD)
client.create_egeria_bearer_token()
# Out:
# 'eyJraWQiOiI1YzA1N2FkMi1kNDNjLTQ3ZjUtOGRmOC0wYzNmYzZhOGI5YjIiLCJhbGciOiJSUzI1NiJ9.eyJpc3MiOiJzZWxmIiwic3ViIjoiZXJpbm92ZXJ2aWV3IiwiZXhwIjoxNzY0MTI3MTg3LCJpYXQiOjE3NjQxMjM1ODcsImRpc3BsYXlOYW1lIjoiRXJpbiBPdmVydmlldyJ9.YDPBoW4dMNRgylb0juZP3nr1qtZZ7zmYMYcJZd4PkTlRCUEd5nMOhqUTd4GGiQQX_RD6xVFvOu1Vg-HvS5lesR7UdkpjVvNMuv6615XGY2pYti-1MM1y4Tr8gJ8iK8SN4G6B0Z5tKszkNFd4LuqF_OaFwKK7RVo8p6tw23Nt3eOOZxGBGtTnU0QQhHu4ytOcRQ2SMlXoRqISC1alBf1M5drIIS1RARFgPf0x-eM7PvSbgjY2Di3jXEQtleyu0InT4686E1hNL3bBcTMyQINQbGJsq6fNNZvS_Tgw4sHyqkDOAdkNw1QObfTw3vzN9E8tX1xvEpeIqSoW2OAbtp_aOQ'

# %% [markdown]
# ## Setting up a valid metadata value for a string property

# %%
body = {
          "displayName": "Clinical Trial",
          "description": "Element supporting one or more clinical trials.",
          "preferredValue": "clinical-trial",
          "dataType": "string",
          "isCaseSensitive": False,
       }

client.setup_valid_metadata_value(property_name = "category", 
                                  type_name = None, 
                                  body = body)

# %%
body = {
            "displayName": "Governance",
            "description": "Indicates that this project is supporting a governance requirement.",
            "preferredValue": "governance",
            "dataType": "string",
            "isCaseSensitive": False,
        }
client.setup_valid_metadata_value(property_name = "purposes",
                                  type_name = "Project", 
                                  body = body)

# %% [markdown]
# ## Setting up a valid metadata value for a map property

# %%
body = {
            "displayName": "Expected Duration",
            "description": "How long (roughly) is this project expected to run?",
            "preferredValue": "expectedDuration",
            "dataType": "string",
            "isCaseSensitive": False
        }
client.setup_valid_metadata_map_name(property_name = "additionalProperties",
                                     type_name = "Project", 
                                     body = body)

# %%
body = {
    "displayName": "One Month",
    "description": "The project is expected to run for a month.",
    "preferredValue": "1 month",
    "dataType": "string",
    "isCaseSensitive": False
}

client.setup_valid_metadata_value(property_name = "additionalProperties", 
                                  type_name = "Project", 
                                  body = body)

# %%
body = {
    "displayName": "Two Months",
    "description": "The project is expected to run for two months.",
    "preferredValue": "Two months",
    "dataType": "string",
    "isCaseSensitive": False
}

client.setup_valid_metadata_value(property_name = "additionalProperties", 
                                  type_name = "Project", 
                                  body = body)

# %% [markdown]
# ## Retrieving single valid metadata values

# %%
# Retrieving a single value
result = client.get_valid_metadata_value(property_name = 'category',
                                         type_name = 'Project', 
                                         preferred_value = 'clinical-trial')
print(json.dumps(result, indent = 4))

# %%
# Retrieving a single valid metadata map name - expectedDuration
result = client.get_valid_metadata_map_name(property_name='additionalProperties', 
                                            type_name='Project', 
                                            map_name='expectedDuration')
print(json.dumps(result, indent = 4))

# %%
# Retrieving a single valid metadata map value - 1 month
result = client.get_valid_metadata_map_value(property_name='additionalProperties', 
                                            type_name='Project', 
                                            map_name = 'expectedDuration',
                                            preferred_value= '1 month')
print(json.dumps(result, indent = 4))

# %% [markdown]
# ## Retrieving all valid metadata values for an attribute

# %%
# Retrieve all valid metadata values for an attribute - purposes
result = client.get_valid_metadata_values(property_name = 'purposes',
                                          type_name = 'Project')
print(json.dumps(result, indent = 4))

# %%
# Retrieve all valid metadata values for an attribute - purposes
result = client.get_valid_metadata_values(property_name = 'purposes',
                                          type_name = 'Project',
                                         output_format = 'LIST',
                                         report_spec = 'Valid-Values')
console.print(Markdown(result))
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                                  Valid-Valuess Table                                                                                                                   ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# Valid-Valuess found from the search string: purposes
#
#
#   Name                   Category                Property Name   Description                                                                                                Preferred Value        Data Type   Is Case Sensitive   Additional Properties
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Product Development    Valid Metadata Values   purposes        Indicates that this project is supporting the development of a new product.                                product-development    string      True                None
#   Market Analysis        Valid Metadata Values   purposes        Indicates that this project is supporting analysis of a new market requirement, or the perception of the   market-analysis        string      True                None
#                                                                  company and/or its products in the market.
#   Patient Treatment      Valid Metadata Values   purposes        Indicates that this project is supporting the treatment of a patient.                                      patient-treatment      string      True                None
#   Product Verification   Valid Metadata Values   purposes        Indicates that this project is supporting the verification of all aspects of a new product (including      product-verification   string      True                None
#                                                                  clinical trials).
#   Governance             Valid Metadata Values   purposes        Indicates that this project is supporting a governance requirement.                                        governance             string      False               None

# %% [markdown]
# ## Validating attribute values

# %%
result = client.validate_metadata_value(property_name = 'purposes',
                                        type_name = 'Project',
                                        actual_value = 'marketing',
                                       )
console.print(result)

# %% [markdown]
# ## Consistent values - linking values to show they should be used together

# %%
# Linking clinical-trials(category) and product-verification(purposes). 
# Note that map_names aren't set for simple values and that if type isn't specified it applies to all types.

client.set_consistent_metadata_values( property_name1 = 'category',
                                       type_name1 = None,
                                       map_name1 = None,
                                       preferred_value1 = 'clinical-trial',
                                       property_name2 = 'purposes',
                                       type_name2 = 'Project',
                                       map_name2 = None,
                                       preferred_value2 = 'product-verification')

# %% [markdown]
# # Retrieving consistent values

# %%
result = client.get_consistent_metadata_values(property_name = 'category',
                                               type_name = 'Project',
                                               map_name = None,
                                               preferred_value = "clinical-trial")
print(json.dumps(result, indent=4))

# %%
# List all data file types
result = client.get_valid_metadata_values(property_name = 'fileType',
                                          output_format = "LIST",report_spec="Valid-Values")
# render_markdown(result)
console.print(Markdown(result))

# %%
out_struct = {
                    "heading": "Valid Metadata Values",
                    "description": "Valid Metadata Values",
                    "formats": {
                        "types":["ALL"],
                        "attributes": [
                        {'name': 'Property Name', 'key': 'propertyName'},
                        {'name': 'Map Property Name', 'key': 'mapName'},
                        {'name': 'Type Name', 'key': 'typeName'},
                        {'name': 'Preferred Value', 'key': 'preferred_value'}
                        ]
                    }

                }
result = client.get_valid_metadata_values(property_name = 'fileType',
                                          output_format = "LIST",report_spec=out_struct)
# render_markdown(result)
console.print(Markdown(result))
# print(json.dumps(result, indent=2))
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                                                               ValidMetadataValues Table                                                                                                                ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# ValidMetadataValues found from the search string: fileType
#
#
#   Property Name   Map Property Name   Type Name   Preferred Value
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   fileType        None                None        Encryption keys File
#   fileType        None                None        README File
#   fileType        None                None        Java Cryptography Extension (JCE) Keystore File
#   fileType        None                None        Microsoft Word Document
#   fileType        None                None        Docker Container Build Script
#   fileType        None                None        Javascript Program File
#   fileType        None                None        Application Report File
#   fileType        None                None        GeoTIFF File
#   fileType        None                None        JPEG File
#   fileType        None                None        Open Metadata Audit Log Folder
#   fileType        None                None        Properties File
#   fileType        None                None        Window Media Audio File
#   fileType        None                None        Open Metadata Archive File
#   fileType        None                None        Extended Cascading Style Sheet File
#   fileType        None                None        Java Program Source File
#   fileType        None                None        Stderr Log File
#   fileType        None                None        Korn Shell Script File
#   fileType        None                None        Portable Document Format (PDF) File
#   fileType        None                None        Text File
#   fileType        None                None        Gradle Properties File
#   fileType        None                None        Microsoft PowerPoint Presentation File (Old Format)
#   fileType        None                None        Logback Configuration File
#   fileType        None                None        Avro File
#   fileType        None                None        Free Lossless Audio Codec (FLAC) File
#   fileType        None                None        Binary Format File
#   fileType        None                None        Enterprise Archive File
#   fileType        None                None        OMAG Server Cohort Registry
#   fileType        None                None        Tarball Archive File
#   fileType        None                None        Zipped Archive File
#   fileType        None                None        HTML Web Document
#   fileType        None                None        Open Metadata Secrets Store File
#   fileType        None                None        Compressed Archive File
#   fileType        None                None        YAML File
#   fileType        None                None        Variant Call Format (VCF) File
#   fileType        None                None        Apple Pages Document
#   fileType        None                None        Notice File
#   fileType        None                None        Optimized Row Columnar (ORC) File
#   fileType        None                None        Waveform Audio File
#   fileType        None                None        License File
#   fileType        None                None        Java Keystore File
#   fileType        None                None        Computer Icons File
#   fileType        None                None        Java Program Object File
#   fileType        None                None        Java Package Description
#   fileType        None                None        OBJ Material Template Library File
#   fileType        None                None        SQL Program File
#   fileType        None                None        Code Owners File
#   fileType        None                None        OMAG Server Configuration Document
#   fileType        None                None        Adobe Illustrator Image File
#   fileType        None                None        Microsoft Project File
#   fileType        None                None        Microsoft Word Document (Old Format)
#   fileType        None                None        Apache Maven Build File
#   fileType        None                None        Tag Image File Format (TIFF)
#   fileType        None                None        Log Message File
#   fileType        None                None        Windows AVI Video File
#   fileType        None                None        Microsoft Excel Spreadsheet File (Old Format)
#   fileType        None                None        Graphics Interchange Format (GIF) File
#   fileType        None                None        Microsoft PowerPoint Presentation Template File
#   fileType        None                None        Windows Media Video File
#   fileType        None                None        Java Archive Manifest File
#   fileType        None                None        Portable Network Graphics (PNG) File
#   fileType        None                None        High-Efficiency Image Codec (HEIC) File
#   fileType        None                None        Git Ignore File
#   fileType        None                None        Draw.io Document
#   fileType        None                None        Parquet File
#   fileType        None                None        Microsoft Windows Script File
#   fileType        None                None        Windows Disk Image File
#   fileType        None                None        Spring application.properties File
#   fileType        None                None        Rich-text File
#   fileType        None                None        Microsoft Excel Spreadsheet File
#   fileType        None                None        Open Lineage Event File
#   fileType        None                None        Bash Shell Script File
#   fileType        None                None        Open Metadata Audit Log Record File
#   fileType        None                None        Encapsulated Postscript File
#   fileType        None                None        Stdout Log File
#   fileType        None                None        Microsoft DOS Batch File
#   fileType        None                None        Windows Executable File
#   fileType        None                None        Cascading Style Sheet File
#   fileType        None                None        Application Data File
#   fileType        None                None        Microsoft DOS Command File
#   fileType        None                None        Postscript File
#   fileType        None                None        Microsoft PowerPoint Presentation File
#   fileType        None                None        MacOS Application Bundle File
#   fileType        None                None        Java Archive File
#   fileType        None                None        Audio Interchange File Format (AIFF) File
#   fileType        None                None        Scalar Vector Graphics File
#   fileType        None                None        Apple Disk Image File
#   fileType        None                None        Personal Information Exchange File
#   fileType        None                None        JSON File
#   fileType        None                None        Configuration File
#   fileType        None                None        XML File
#   fileType        None                None        Web Archive File
#   fileType        None                None        Video Transport System File
#   fileType        None                None        Log File
#   fileType        None                None        Apple M4V Video File
#   fileType        None                None        Windows Bitmap File
#   fileType        None                None        Apple Numbers Spreadsheet File
#   fileType        None                None        Typescript Program File
#   fileType        None                None        Mermaid Markdown Document
#   fileType        None                None        Microsoft PowerPoint Presentation Template File (Old Format)
#   fileType        None                None        OpenDocument File
#   fileType        None                None        Gradle Build File
#   fileType        None                None        Python Program File
#   fileType        None                None        MP3 Audio File
#   fileType        None                None        Apple Keynote Presentation File
#   fileType        None                None        CSV File
#   fileType        None                None        Markdown File
#   fileType        None                None        MP4 Video File
#   fileType        None                None        Apple MOV Video File
#   fileType        None                None        Wavefront 3D Object File
#   fileType        None                None        Mobile Video File

# %%
result = client.get_consistent_metadata_values(property_name = 'fileType',
                                               type_name = 'CSVFile',
                                               map_name = None,
                                               preferred_value = "CSV File")
print(json.dumps(result, indent=4))

# %% [markdown]
# # Retrieving open metadata types

# %%
# Retrieve a TypeDef - Project
result = client.get_typedef_by_name(entity_type = 'Project')
print(json.dumps(result, indent=4))

# %%
# Retrieve subtypes of a TypeDef - Collection
result = client.get_sub_types(type_name="Collection")
# print(json.dumps(result, indent=4))
mermaid_graph = client.get_sub_types(type_name = 'Collection', 
                                     output_format = 'MERMAID', 
                                     report_spec = "Common-Mermaid")
render_mermaid(mermaid_graph[0])
print(mermaid_graph)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-347005ba-2b35-4670-b5a7-12c9ebed0cf7-9ddd-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     Subtypes for - Collection
#                 </h3>
#                 <p id="mermaid-graph-347005ba-2b35-4670-b5a7-12c9ebed0cf7-9ddd-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 347005ba-2b35-4670-b5a7-12c9ebed0cf7
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart RL
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **Collection**&quot;}
# 2@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **ReferenceList**&quot;}
# 3@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **CollectionFolder**&quot;}
# 4@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **DigitalProductFamily**&quot;}
# 5@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **Glossary**&quot;}
# 6@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **SolutionBlueprint**&quot;}
# 7@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **BusinessCapability**&quot;}
# 8@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **DigitalProductCatalog**&quot;}
# 9@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **WorkItemList**&quot;}
# 10@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **ResultsSet**&quot;}
# 11@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **DesignModel**&quot;}
# 12@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **ConceptModel**&quot;}
# 13@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **DataDictionary**&quot;}
# 14@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **RecentAccess**&quot;}
# 15@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **DigitalSubscription**&quot;}
# 16@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **DataSpec**&quot;}
# 17@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **SoftwareArchive**&quot;}
# 18@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **InformationSupplyChain**&quot;}
# 19@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **Agreement**&quot;}
# 20@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **EventSet**&quot;}
# 21@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **DigitalProduct**&quot;}
# 22@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **RootCollection**&quot;}
# 23@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **ContextEventCollection**&quot;}
# 24@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **HomeCollection**&quot;}
# 25@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **Namespace**&quot;}
# 26@{ shape: rounded, label: &quot;*Open  Metadata  Type*
# **NamingStandardRuleSet**&quot;}
# 2==&gt;1
# 3==&gt;1
# 4==&gt;21
# 5==&gt;1
# 6==&gt;11
# 7==&gt;1
# 8==&gt;1
# 9==&gt;1
# 10==&gt;1
# 11==&gt;1
# 12==&gt;11
# 13==&gt;1
# 14==&gt;1
# 15==&gt;19
# 16==&gt;1
# 17==&gt;1
# 18==&gt;1
# 19==&gt;1
# 20==&gt;1
# 21==&gt;1
# 22==&gt;1
# 23==&gt;1
# 24==&gt;1
# 25==&gt;1
# 26==&gt;1
# style 22 color:#492673, fill:#af8cd9, stroke:#492673
# style 23 color:#492673, fill:#af8cd9, stroke:#492673
# style 24 color:#492673, fill:#af8cd9, stroke:#492673
# style 25 color:#492673, fill:#af8cd9, stroke:#492673
# style 26 color:#492673, fill:#af8cd9, stroke:#492673
# style 10 color:#492673, fill:#af8cd9, stroke:#492673
# style 11 color:#492673, fill:#af8cd9, stroke:#492673
# style 12 color:#492673, fill:#af8cd9, stroke:#492673
# style 13 color:#492673, fill:#af8cd9, stroke:#492673
# style 14 color:#492673, fill:#af8cd9, stroke:#492673
# style 15 color:#492673, fill:#af8cd9, stroke:#492673
# style 16 color:#492673, fill:#af8cd9, stroke:#492673
# style 17 color:#492673, fill:#af8cd9, stroke:#492673
# style 18 color:#492673, fill:#af8cd9, stroke:#492673
# style 19 color:#492673, fill:#af8cd9, stroke:#492673
# style 1 color:#e4d9f2, fill:#7940bf, stroke:#e4d9f2
# style 2 color:#492673, fill:#af8cd9, stroke:#492673
# style 3 color:#492673, fill:#af8cd9, stroke:#492673
# style 4 color:#492673, fill:#af8cd9, stroke:#492673
# style 5 color:#492673, fill:#af8cd9, stroke:#492673
# style 6 color:#492673, fill:#af8cd9, stroke:#492673
# style 7 color:#492673, fill:#af8cd9, stroke:#492673
# style 8 color:#492673, fill:#af8cd9, stroke:#492673
# style 9 color:#492673, fill:#af8cd9, stroke:#492673
# style 20 color:#492673, fill:#af8cd9, stroke:#492673
# style 21 color:#492673, fill:#af8cd9, stroke:#492673
# click 22 &quot;https://egeria-project.org/types/0/0021-Collections/&quot; &quot;Click for more documentation&quot; _blank
# click 23 &quot;https://egeria-project.org/types/4/0475-Context-Events/&quot; &quot;Click for more documentation&quot; _blank
# click 24 &quot;https://egeria-project.org/types/0/0021-Collections/&quot; &quot;Click for more documentation&quot; _blank
# click 25 &quot;https://egeria-project.org/types/0/0021-Collections/&quot; &quot;Click for more documentation&quot; _blank
# click 26 &quot;https://egeria-project.org/types/4/0438-Naming-Standards/&quot; &quot;Click for more documentation&quot; _blank
# click 10 &quot;https://egeria-project.org/types/0/0021-Collections/&quot; &quot;Click for more documentation&quot; _blank
# click 11 &quot;https://egeria-project.org/types/5/0565-Design-Models/&quot; &quot;Click for more documentation&quot; _blank
# click 12 &quot;https://egeria-project.org/types/5/0571-Concept-Models/&quot; &quot;Click for more documentation&quot; _blank
# click 13 &quot;https://egeria-project.org/types/5/0580-Data-Dictionaries/&quot; &quot;Click for more documentation&quot; _blank
# click 14 &quot;https://egeria-project.org/types/0/0021-Collections/&quot; &quot;Click for more documentation&quot; _blank
# click 15 &quot;https://egeria-project.org/types/7/0712-Digital-Subscription/&quot; &quot;Click for more documentation&quot; _blank
# click 16 &quot;https://egeria-project.org/types/5/0580-Data-Dictionaries/&quot; &quot;Click for more documentation&quot; _blank
# click 17 &quot;https://egeria-project.org/types/0/0030-Hosts-and-Platforms/&quot; &quot;Click for more documentation&quot; _blank
# click 18 &quot;https://egeria-project.org/types/7/0720-Information-Supply-Chains/&quot; &quot;Click for more documentation&quot; _blank
# click 19 &quot;https://egeria-project.org/types/7/0711-Agreements/&quot; &quot;Click for more documentation&quot; _blank
# click 1 &quot;https://egeria-project.org/types/0/0021-Collections/&quot; &quot;Click for more documentation&quot; _blank
# click 2 &quot;https://egeria-project.org/types/0/0021-Collections/&quot; &quot;Click for more documentation&quot; _blank
# click 3 &quot;https://egeria-project.org/types/0/0021-Collections/&quot; &quot;Click for more documentation&quot; _blank
# click 4 &quot;https://egeria-project.org/types/7/0710-Digital-Products/&quot; &quot;Click for more documentation&quot; _blank
# click 5 &quot;https://egeria-project.org/types/3/0310-Glossary/&quot; &quot;Click for more documentation&quot; _blank
# click 6 &quot;https://egeria-project.org/types/7/0740-Solution-Blueprints/&quot; &quot;Click for more documentation&quot; _blank
# click 7 &quot;https://egeria-project.org/types/7/0715-Digital-Business/&quot; &quot;Click for more documentation&quot; _blank
# click 8 &quot;https://egeria-project.org/types/7/0710-Digital-Products/&quot; &quot;Click for more documentation&quot; _blank
# click 9 &quot;https://egeria-project.org/types/0/0021-Collections/&quot; &quot;Click for more documentation&quot; _blank
# click 20 &quot;https://egeria-project.org/types/5/0535-Event-Schemas/&quot; &quot;Click for more documentation&quot; _blank
# click 21 &quot;https://egeria-project.org/types/7/0710-Digital-Products/&quot; &quot;Click for more documentation&quot; _blank
#
# ```
#     </div>
#     <script type="text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>
# [
#     '\n\n```mermaid\n---\ntitle: Subtypes for - Collection [347005ba-2b35-4670-b5a7-12c9ebed0cf7]\n---\nflowchart
# RL\n%%{init: {"flowchart": {"htmlLabels": false}} }%%\n\n1@{ shape: rounded, label: "*Open  Metadata
# Type*\n**Collection**"}\n2@{ shape: rounded, label: "*Open  Metadata  Type*\n**ReferenceList**"}\n3@{ shape:
# rounded, label: "*Open  Metadata  Type*\n**CollectionFolder**"}\n4@{ shape: rounded, label: "*Open  Metadata
# Type*\n**DigitalProductFamily**"}\n5@{ shape: rounded, label: "*Open  Metadata  Type*\n**Glossary**"}\n6@{ shape:
# rounded, label: "*Open  Metadata  Type*\n**SolutionBlueprint**"}\n7@{ shape: rounded, label: "*Open  Metadata
# Type*\n**BusinessCapability**"}\n8@{ shape: rounded, label: "*Open  Metadata
# Type*\n**DigitalProductCatalog**"}\n9@{ shape: rounded, label: "*Open  Metadata  Type*\n**WorkItemList**"}\n10@{
# shape: rounded, label: "*Open  Metadata  Type*\n**ResultsSet**"}\n11@{ shape: rounded, label: "*Open  Metadata
# Type*\n**DesignModel**"}\n12@{ shape: rounded, label: "*Open  Metadata  Type*\n**ConceptModel**"}\n13@{ shape:
# rounded, label: "*Open  Metadata  Type*\n**DataDictionary**"}\n14@{ shape: rounded, label: "*Open  Metadata
# Type*\n**RecentAccess**"}\n15@{ shape: rounded, label: "*Open  Metadata  Type*\n**DigitalSubscription**"}\n16@{
# shape: rounded, label: "*Open  Metadata  Type*\n**DataSpec**"}\n17@{ shape: rounded, label: "*Open  Metadata
# Type*\n**SoftwareArchive**"}\n18@{ shape: rounded, label: "*Open  Metadata
# Type*\n**InformationSupplyChain**"}\n19@{ shape: rounded, label: "*Open  Metadata  Type*\n**Agreement**"}\n20@{
# shape: rounded, label: "*Open  Metadata  Type*\n**EventSet**"}\n21@{ shape: rounded, label: "*Open  Metadata
# Type*\n**DigitalProduct**"}\n22@{ shape: rounded, label: "*Open  Metadata  Type*\n**RootCollection**"}\n23@{ shape:
# rounded, label: "*Open  Metadata  Type*\n**ContextEventCollection**"}\n24@{ shape: rounded, label: "*Open  Metadata
# Type*\n**HomeCollection**"}\n25@{ shape: rounded, label: "*Open  Metadata  Type*\n**Namespace**"}\n26@{ shape:
# rounded, label: "*Open  Metadata
# Type*\n**NamingStandardRuleSet**"}\n2==>1\n3==>1\n4==>21\n5==>1\n6==>11\n7==>1\n8==>1\n9==>1\n10==>1\n11==>1\n12==>
# 11\n13==>1\n14==>1\n15==>19\n16==>1\n17==>1\n18==>1\n19==>1\n20==>1\n21==>1\n22==>1\n23==>1\n24==>1\n25==>1\n26==>1
# \nstyle 22 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 23 color:#492673, fill:#af8cd9, stroke:#492673\nstyle
# 24 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 25 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 26
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 10 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 11
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 12 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 13
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 14 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 15
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 16 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 17
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 18 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 19
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 1 color:#e4d9f2, fill:#7940bf, stroke:#e4d9f2\nstyle 2
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 3 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 4
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 5 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 6
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 7 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 8
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 9 color:#492673, fill:#af8cd9, stroke:#492673\nstyle 20
# color:#492673, fill:#af8cd9, stroke:#492673\nstyle 21 color:#492673, fill:#af8cd9, stroke:#492673\nclick 22
# "https://egeria-project.org/types/0/0021-Collections/" "Click for more documentation" _blank\nclick 23
# "https://egeria-project.org/types/4/0475-Context-Events/" "Click for more documentation" _blank\nclick 24
# "https://egeria-project.org/types/0/0021-Collections/" "Click for more documentation" _blank\nclick 25
# "https://egeria-project.org/types/0/0021-Collections/" "Click for more documentation" _blank\nclick 26
# "https://egeria-project.org/types/4/0438-Naming-Standards/" "Click for more documentation" _blank\nclick 10
# "https://egeria-project.org/types/0/0021-Collections/" "Click for more documentation" _blank\nclick 11
# "https://egeria-project.org/types/5/0565-Design-Models/" "Click for more documentation" _blank\nclick 12
# "https://egeria-project.org/types/5/0571-Concept-Models/" "Click for more documentation" _blank\nclick 13
# "https://egeria-project.org/types/5/0580-Data-Dictionaries/" "Click for more documentation" _blank\nclick 14
# "https://egeria-project.org/types/0/0021-Collections/" "Click for more documentation" _blank\nclick 15
# "https://egeria-project.org/types/7/0712-Digital-Subscription/" "Click for more documentation" _blank\nclick 16
# "https://egeria-project.org/types/5/0580-Data-Dictionaries/" "Click for more documentation" _blank\nclick 17
# "https://egeria-project.org/types/0/0030-Hosts-and-Platforms/" "Click for more documentation" _blank\nclick 18
# "https://egeria-project.org/types/7/0720-Information-Supply-Chains/" "Click for more documentation" _blank\nclick
# 19 "https://egeria-project.org/types/7/0711-Agreements/" "Click for more documentation" _blank\nclick 1
# "https://egeria-project.org/types/0/0021-Collections/" "Click for more documentation" _blank\nclick 2
# "https://egeria-project.org/types/0/0021-Collections/" "Click for more documentation" _blank\nclick 3
# "https://egeria-project.org/types/0/0021-Collections/" "Click for more documentation" _blank\nclick 4
# "https://egeria-project.org/types/7/0710-Digital-Products/" "Click for more documentation" _blank\nclick 5
# "https://egeria-project.org/types/3/0310-Glossary/" "Click for more documentation" _blank\nclick 6
# "https://egeria-project.org/types/7/0740-Solution-Blueprints/" "Click for more documentation" _blank\nclick 7
# "https://egeria-project.org/types/7/0715-Digital-Business/" "Click for more documentation" _blank\nclick 8
# "https://egeria-project.org/types/7/0710-Digital-Products/" "Click for more documentation" _blank\nclick 9
# "https://egeria-project.org/types/0/0021-Collections/" "Click for more documentation" _blank\nclick 20
# "https://egeria-project.org/types/5/0535-Event-Schemas/" "Click for more documentation" _blank\nclick 21
# "https://egeria-project.org/types/7/0710-Digital-Products/" "Click for more documentation" _blank\n\n```'
# ]

# %%
# getSpecificationPropertyTypes - return the list of specification property types
result = client.get_specification_property_types()
print(json.dumps(result, indent=4))
