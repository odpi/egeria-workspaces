# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Egeria Workbook
#
# # Auditing users

# %% [markdown]
# ----
#
# # Setting up the clients

# %%
import json
import time
import os
from rich import print, print_json
from rich.console import Console
from rich.markdown import Markdown

from pyegeria import (
    AssetMaker,
    print_basic_exception, PyegeriaException,
    settings, load_app_config,
    render_mermaid
)

env = settings.Environment
EGERIA_USER = os.environ.get("EGERIA_USER", "erinoverview")
EGERIA_USER_PASSWORD = os.environ.get("EGERIA_USER_PASSWORD", "secret")
console = Console(width = 250)

# %%
garyAssetMakerClient = AssetMaker(view_server=env.egeria_view_server, 
                              platform_url = env.egeria_view_server_url,
                              user_id = "gargeeke", 
                              user_pwd = EGERIA_USER_PASSWORD)
garyToken = garyAssetMakerClient.create_egeria_bearer_token()

# %% [markdown]
# -----
# ## Where are an OMAG Server Platform Secrets?
#
# This mermaid graph comes from a query of the software server platform element cataloged mostly by the **OMAGServerPlatformCataloguer**. This connector is scavenging informaiton from its server's configuration to located the platform and extract as much knowledge as it can find to build an open metadata representation of our platform.
#
# It also does some validation on the set up of the user directory in use by the platform (note exceptions).
#
# ----

# %%
mermaidGraph= "---\ntitle: SoftwareServerPlatform - OMAG Server Platform [b30044fb-0f62-4f5e-b2bf-c434f6a387c4]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Software Server Platform*\n**OMAG Server Platform**\"}\n2@{ shape: card, label: \"*Software Server Platform [Template]*\n**~ {platformName} ~**\"}\n1==>|\"Sourced From\"|2\n3@{ shape: rounded, label: \"*Endpoint*\n**Local OMAG Server Platform endpoint**\"}\n1==>|\"Server Endpoint\"|3\n4@{ shape: hex, label: \"*Software Server*\n**qs-metadata-store from Coco Pharmaceuticals on https:/ /localhost:9443**\"}\n4==>|\"Deployed On\"|1\n5@{ shape: hex, label: \"*Software Server*\n**qs-integration-daemon from Coco Pharmaceuticals on https:/ /localhost:9443**\"}\n5==>|\"Deployed On\"|1\n6@{ shape: hex, label: \"*Software Server*\n**qs-engine-host from Coco Pharmaceuticals on https:/ /localhost:9443**\"}\n6==>|\"Deployed On\"|1\n7@{ shape: rounded, label: \"*Authorization Manager*\n**User Access Manager**\"}\n1==>|\"Supported Software Capability\"|7\n8@{ shape: rounded, label: \"*User Authentication Manager*\n**User Token Manager**\"}\n1==>|\"Supported Software Capability\"|8\n9@{ shape: rounded, label: \"*Virtual Connection*\n**Local OMAG Server Platform connection**\"}\n1==>|\"Asset Connection\"|9\n10@{ shape: rounded, label: \"*Connection*\n**Local OMAG Server Platform secrets store connection**\"}\n9==>|\"restAPIBearerToken [Embedded Connection]\"|10\n11@{ shape: rounded, label: \"*Connector Type*\n**YAML File Secrets Store Connector**\"}\n10==>|\"Connection Connector Type\"|11\n12@{ shape: rounded, label: \"*Endpoint*\n**Local OMAG Server Platform secret store endpoint**\"}\n10==>|\"Connect To Endpoint\"|12\n13@{ shape: rounded, label: \"*Connector Type*\n**OMAG Server Platform Connector**\"}\n9==>|\"Connection Connector Type\"|13\n9==>|\"Connect To Endpoint\"|3\n14@{ shape: doc, label: \"*Exception Type*\n**Clear Text Password Exception**\"}\n1==>|\"peterprofile [Exception]\"|14\n1==>|\"bobnitter [Exception]\"|14\n15@{ shape: doc, label: \"*Exception Type*\n**Missing User Identity Exception**\"}\n1==>|\"qsenginenpa [Exception]\"|15\n1==>|\"daemonnpa [Exception]\"|15\n1==>|\"qsstorenpa [Exception]\"|15\n1==>|\"faithbroker [Exception]\"|14\n16@{ shape: stadium, label: \"*Exception*\n**... plus 49 Items**\"}\n1-.->16\n17@{ shape: stadium, label: \"*Integration Connector*\n**OMAGServerPlatformIntegrationConnector**\"}\n17==>|\"Local OMAG Server Platform(b30044fb-0f62-4f5e-b2bf-c434f6a387c4) [Catalog Target]\"|1\n18@{ shape: rect, label: \"*Solution Component*\n**OMAG Server Platform**\"}\n18==>|\"running instance [Implemented By]\"|1\nstyle 11 color:#000000, fill:#39add1, stroke:#004563\nstyle 12 color:#000000, fill:#39add1, stroke:#004563\nstyle 13 color:#000000, fill:#39add1, stroke:#004563\nstyle 14 color:#FFFFFF, fill:#006400, stroke:#000000\nstyle 15 color:#FFFFFF, fill:#006400, stroke:#000000\nstyle 16 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 17 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 18 color:#000000, fill:#DDA0DD, stroke:#000000\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#004563, fill:#b0e0e6, stroke:#004563\nstyle 3 color:#000000, fill:#39add1, stroke:#004563\nstyle 4 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 5 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 6 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 7 color:#000000, fill:#39add1, stroke:#004563\nstyle 8 color:#000000, fill:#39add1, stroke:#004563\nstyle 9 color:#000000, fill:#39add1, stroke:#004563\nstyle 10 color:#000000, fill:#39add1, stroke:#004563\nclick 11 \"https://github.com/odpi/egeria/tree/main/open-metadata-implementation/adapters/open-connectors/secrets-store-connectors/yaml-secrets-store-connector\" \"Click for more documentation\" _blank\nclick 1 \"https://egeria-project.org/concepts/omag-server-platform/\" \"Click for more documentation\" _blank\nclick 13 \"https://github.com/odpi/egeria/tree/main/open-metadata-implementation/adapters/open-connectors/system-connectors/egeria-system-connectors\" \"Click for more documentation\" _blank\nclick 4 \"https://egeria-project.org/concepts/metadata-access-store/\" \"Click for more documentation\" _blank\nclick 5 \"https://egeria-project.org/concepts/integration-daemon/\" \"Click for more documentation\" _blank\nclick 6 \"https://egeria-project.org/concepts/engine-host/\" \"Click for more documentation\" _blank\nclick 7 \"https://egeria-project.org/concepts/platform-metadata-security-connector/\" \"Click for more documentation\" _blank\nclick 18 \"https://egeria-project.org/concepts/omag-server-platform/\" \"Click for more documentation\" _blank\n"
render_mermaid(mermaidGraph)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-b30044fb-0f62-4f5e-b2bf-c434f6a387c4-1d48-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     SoftwareServerPlatform - OMAG Server Platform
#                 </h3>
#                 <p id="mermaid-graph-b30044fb-0f62-4f5e-b2bf-c434f6a387c4-1d48-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: b30044fb-0f62-4f5e-b2bf-c434f6a387c4
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Software Server Platform*
# **OMAG Server Platform**&quot;}
# 2@{ shape: card, label: &quot;*Software Server Platform [Template]*
# **~ {platformName} ~**&quot;}
# 1==&gt;|&quot;Sourced From&quot;|2
# 3@{ shape: rounded, label: &quot;*Endpoint*
# ...

# %% [markdown]
# ----
#
# The User Authentication Manager and Authorization Manager are connected to the secrets collection in use by the platform
#
#
# ----

# %%
mermaidGraph= "---\ntitle: AuthorizationManager - User Access Manager [aa4bf9b6-0d34-470c-8da0-aaf4ef217f44]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Authorization Manager*\n**User Access Manager**\"}\n2@{ shape: cyl, label: \"*Secrets Collection*\n**cocoUserDirectory**\"}\n1==>|\"Capability Asset Use\"|2\n3@{ shape: hex, label: \"*Software Server Platform*\n**OMAG Server Platform**\"}\n3==>|\"Supported Software Capability\"|1\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 3 color:#000000, fill:#BDB76B, stroke:#004563\nclick 1 \"https://egeria-project.org/concepts/platform-metadata-security-connector/\" \"Click for more documentation\" _blank\nclick 3 \"https://egeria-project.org/concepts/omag-server-platform/\" \"Click for more documentation\" _blank\n"

render_mermaid(mermaidGraph)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-aa4bf9b6-0d34-470c-8da0-aaf4ef217f44-0223-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     AuthorizationManager - User Access Manager
#                 </h3>
#                 <p id="mermaid-graph-aa4bf9b6-0d34-470c-8da0-aaf4ef217f44-0223-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: aa4bf9b6-0d34-470c-8da0-aaf4ef217f44
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Authorization Manager*
# **User Access Manager**&quot;}
# 2@{ shape: cyl, label: &quot;*Secrets Collection*
# **cocoUserDirectory**&quot;}
# 1==&gt;|&quot;Capability Asset Use&quot;|2
# 3@{ shape: hex, label: &quot;*Software Server Platform*
# **OMAG Server Platform**&quot;}
# ...

# %% [markdown]
# -----
# # Working with secrets stores
#
# The Secrets Collection *cocoUserDirectory* is stored in a secrets store.  File-based secrets stores are catalog by the **OMSecretsStoreCataloguer**.  This connector catalogs both the secrets stores it finds as well as the secrets collections it finds inside.  It is carefoul not to store the secrets themselves.  However, it does capture the strictural information, such as information about user accounts, security lists and security controls.
#
# Because this information is sensitive, only people working in security have access to this catalogued information

# %%
# find cocoUserDirectory using gary's token

response = {
  "class": "OpenMetadataRootElementsResponse",
  "requestId": "3d140c75-8cef-41d2-a24c-c6fdb970daf4",
  "relatedHTTPCode": 500,
  "exceptionClassName": "org.odpi.openmetadata.frameworks.openmetadata.ffdc.PropertyServerException",
  "exceptionSubclassName": "org.odpi.openmetadata.frameworks.openmetadata.ffdc.PropertyServerException",
  "exceptionCausedBy": "org.odpi.openmetadata.frameworks.openmetadata.ffdc.UserNotAuthorizedException",
  "actionDescription": "findAssets",
  "exceptionErrorMessage": "OPEN-METADATA-500-025 The Open Metadata Store has received an unexpected org.odpi.openmetadata.frameworks.openmetadata.ffdc.UserNotAuthorizedException exception while formatting a response during method findAssets for service Asset Maker OMVS.  The message was: OMAG-SERVER-SECURITY-403-020 User garygeeke is not authorized to issue an operation Read on SecurityRole element bd1f2fee-f9a2-4fb1-962b-3c42aa539c64",
  "exceptionErrorMessageId": "OPEN-METADATA-500-025",
  "exceptionErrorMessageParameters": [
    "org.odpi.openmetadata.frameworks.openmetadata.ffdc.UserNotAuthorizedException",
    "findAssets",
    "Asset Maker OMVS",
    "OMAG-SERVER-SECURITY-403-020 User garygeeke is not authorized to issue an operation Read on SecurityRole element bd1f2fee-f9a2-4fb1-962b-3c42aa539c64"
  ],
  "exceptionSystemAction": "The request returns with this exception to indicate there has been an internal server error. The server also created a detailed error message and stack trace in the audit log.",
  "exceptionUserAction": "Review the stack trace to identify where the error occurred and work to resolve the cause."
}

# %% [markdown]
# ----
#
# # find cocoUserDirectory using ivor's token
#
# Egeria and connectors, such as OMSecretsStoreCataloguer, accesses secrets, such as certificates, user details, passwords and their access priviledges, through [secrets store connectors](https://egeria-project.org/concepts/secrets-store-connector/).  These connectors have an API that enables a caller to extract details of the secrets found in the secrets store.
#
# Ivor has permission to access details of the secrets collection.   Below is what he sees:
#
# ----

# %%
mermaidGraph="---\ntitle: SecretsCollection - cocoUserDirectory [ee10ba35-e02a-4c29-b9e7-58cee892335e]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Secrets Collection*\n**cocoUserDirectory**\"}\n2@{ shape: rounded, label: \"*User Authentication Manager*\n**User Token Manager**\"}\n2==>|\"Capability Asset Use\"|1\n3@{ shape: rounded, label: \"*Authorization Manager*\n**User Access Manager**\"}\n3==>|\"Capability Asset Use\"|1\n4@{ shape: tag-doc, label: \"*Key Store File*\n**coco-user-directory.omsecrets**\"}\n1==>|\"Data Set Content\"|4\n5@{ shape: bow-rect, label: \"*User Identity*\n**sallycounter**\"}\n1==>|\"User Account\"|5\n6@{ shape: bow-rect, label: \"*User Identity*\n**contentpackcatnpa**\"}\n1==>|\"User Account\"|6\n7@{ shape: bow-rect, label: \"*User Identity*\n**datafoldercatnpa**\"}\n1==>|\"User Account\"|7\n8@{ shape: bow-rect, label: \"*User Identity*\n**tomtally**\"}\n1==>|\"User Account\"|8\n9@{ shape: bow-rect, label: \"*User Identity*\n**sidneyseeker**\"}\n1==>|\"User Account\"|9\n10@{ shape: bow-rect, label: \"*User Identity*\n**olgapubnpa**\"}\n1==>|\"User Account\"|10\n11@{ shape: stadium, label: \"*User Account*\n**... plus 52 Items**\"}\n1-.->11\n12@{ shape: doc, label: \"*Service Access Control*\n**simple-metadata-store**\"}\n1==>|\"Resource Permissions\"|12\n13@{ shape: rect, label: \"*Security Role*\n**openMetadataMember**\"}\n12==>|\"Associated Security List\"|13\n14@{ shape: doc, label: \"*Governance Zone*\n**research**\"}\n1==>|\"Resource Permissions\"|14\n15@{ shape: rect, label: \"*Security Role*\n**dataManagementProcess**\"}\n14==>|\"Associated Security List\"|15\n16@{ shape: rect, label: \"*Security Role*\n**omagServer**\"}\n14==>|\"Associated Security List\"|16\n17@{ shape: rect, label: \"*Security Role*\n**researchStaff**\"}\n14==>|\"Associated Security List\"|17\n14==>|\"Associated Security List\"|17\n18@{ shape: doc, label: \"*Governance Zone*\n**human-resources**\"}\n1==>|\"Resource Permissions\"|18\n19@{ shape: rect, label: \"*Security Role*\n**hrStaff**\"}\n18==>|\"Associated Security List\"|19\n18==>|\"Associated Security List\"|15\n18==>|\"Associated Security List\"|16\n18==>|\"Associated Security List\"|19\n20@{ shape: doc, label: \"*Governance Zone*\n**data-lake**\"}\n1==>|\"Resource Permissions\"|20\n21@{ shape: rect, label: \"*Security Group*\n**instanceOwner**\"}\n20==>|\"Associated Security List\"|21\n20==>|\"Associated Security List\"|15\n20==>|\"Associated Security List\"|13\n22@{ shape: rect, label: \"*Security Role*\n**metadataArchitect**\"}\n20==>|\"Associated Security List\"|22\n23@{ shape: doc, label: \"*Service Access Control*\n**engine-host**\"}\n1==>|\"Resource Permissions\"|23\n24@{ shape: rect, label: \"*Security Role*\n**serverOperator**\"}\n23==>|\"Associated Security List\"|24\n25@{ shape: doc, label: \"*Service Access Control*\n**server-operations**\"}\n1==>|\"Resource Permissions\"|25\n25==>|\"Associated Security List\"|13\n26@{ shape: rect, label: \"*Security Role*\n**serverInvestigator**\"}\n25==>|\"Associated Security List\"|26\n27@{ shape: stadium, label: \"*Resource Permissions*\n**... plus 24 Items**\"}\n1-.->27\n1==>|\"Secrets Collection Security List\"|16\n28@{ shape: rect, label: \"*Security Role*\n**salesLeader**\"}\n1==>|\"Secrets Collection Security List\"|28\n29@{ shape: rect, label: \"*Security Group*\n**salesTeam**\"}\n1==>|\"Secrets Collection Security List\"|29\n30@{ shape: rect, label: \"*Security Role*\n**itStaff**\"}\n1==>|\"Secrets Collection Security List\"|30\n31@{ shape: rect, label: \"*Security Role*\n**clinicalTrialsProcess**\"}\n1==>|\"Secrets Collection Security List\"|31\n32@{ shape: rect, label: \"*Security Role*\n**marketingLeader**\"}\n1==>|\"Secrets Collection Security List\"|32\n33@{ shape: stadium, label: \"*Secrets Collection Security List*\n**... plus 82 Items**\"}\n1-.->33\nstyle 22 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 23 color:#FFFFFF, fill:#006400, stroke:#000000\nstyle 24 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 25 color:#FFFFFF, fill:#006400, stroke:#000000\nstyle 26 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 27 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 28 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 29 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 30 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 31 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 10 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 32 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 11 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 33 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 12 color:#FFFFFF, fill:#006400, stroke:#000000\nstyle 13 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 14 color:#FFFFFF, fill:#006400, stroke:#000000\nstyle 15 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 16 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 17 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 18 color:#FFFFFF, fill:#006400, stroke:#000000\nstyle 19 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#39add1, stroke:#004563\nstyle 3 color:#000000, fill:#39add1, stroke:#004563\nstyle 4 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 5 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 6 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 7 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 8 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 9 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 20 color:#FFFFFF, fill:#006400, stroke:#000000\nstyle 21 color:#000000, fill:#f5fffa, stroke:#000000\nclick 3 \"https://egeria-project.org/concepts/platform-metadata-security-connector/\" \"Click for more documentation\" _blank\n"
render_mermaid(mermaidGraph)

userAccountTypeProfileMermaidPieChart= "pie\ntitle Account Types in cocoUserDirectory\n\"Digital Users\" : 51\n\"Contractors\" : 2\n\"Employees\" : 22\n\"External Users\" : 5\n"
render_mermaid(userAccountTypeProfileMermaidPieChart)
print(userAccountTypeProfileMermaidPieChart)

userAccountStatusProfileMermaidPieChart= "pie\ntitle Account Statuses in cocoUserDirectory\n\"Locked\" : 0\n\"Active\" : 80\n\"Expired\" : 0\n\"Disabled\" : 0\n"
render_mermaid(userAccountStatusProfileMermaidPieChart)
print(userAccountStatusProfileMermaidPieChart)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-ee10ba35-e02a-4c29-b9e7-58cee892335e-7a4e-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     SecretsCollection - cocoUserDirectory
#                 </h3>
#                 <p id="mermaid-graph-ee10ba35-e02a-4c29-b9e7-58cee892335e-7a4e-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: ee10ba35-e02a-4c29-b9e7-58cee892335e
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Secrets Collection*
# **cocoUserDirectory**&quot;}
# 2@{ shape: rounded, label: &quot;*User Authentication Manager*
# **User Token Manager**&quot;}
# 2==&gt;|&quot;Capability Asset Use&quot;|1
# 3@{ shape: rounded, label: &quot;*Authorization Manager*
# ...

# %% [markdown]
# ----
#
# ## UserIdentities
#
# User identities represent a user account.  They are in 2 zones:
#
# ```
#         "classificationProperties": {
#           "class": "ZoneMembershipProperties",
#           "typeName": "ZoneMembership",
#           "zoneMembership": [
#             "security",
#             "garygeeke"
#           ]
#         }
# ```
#
#
# ### findUserIdentities (gary)
#
# Gary is able to see his own User Identity information.
#
# ----

# %%
mermaidGraph= "---\ntitle: UserIdentity - garygeeke [58a64a19-abd5-465c-a8a7-b2451345249e]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*User Identity*\n**garygeeke**\"}\n2@{ shape: trap-t, label: \"*Person*\n**Gary Geeke**\"}\n2==>|\"Profile Identity\"|1\n3@{ shape: cyl, label: \"*Secrets Collection*\n**cocoUserDirectory**\"}\n3==>|\"User Account\"|1\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#FFE599, stroke:#000000\nstyle 3 color:#000000, fill:#BDB76B, stroke:#004563\n"
render_mermaid(mermaidGraph)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-58a64a19-abd5-465c-a8a7-b2451345249e-2027-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     UserIdentity - garygeeke
#                 </h3>
#                 <p id="mermaid-graph-58a64a19-abd5-465c-a8a7-b2451345249e-2027-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 58a64a19-abd5-465c-a8a7-b2451345249e
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*User Identity*
# **garygeeke**&quot;}
# 2@{ shape: trap-t, label: &quot;*Person*
# **Gary Geeke**&quot;}
# 2==&gt;|&quot;Profile Identity&quot;|1
# 3@{ shape: cyl, label: &quot;*Secrets Collection*
# **cocoUserDirectory**&quot;}
# 3==&gt;|&quot;User Account&quot;|1
# ...

# %% [markdown]
# -----
#
# # get Gary's UserIdentities (ivor)
#
# Ivor is able to see it too because of his security membership.
#
# -----

# %%
mermaidGraph= "---\ntitle: UserIdentity - garygeeke [58a64a19-abd5-465c-a8a7-b2451345249e]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*User Identity*\n**garygeeke**\"}\n2@{ shape: trap-t, label: \"*Person*\n**Gary Geeke**\"}\n2==>|\"Profile Identity\"|1\n3@{ shape: cyl, label: \"*Secrets Collection*\n**cocoUserDirectory**\"}\n3==>|\"User Account\"|1\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#FFE599, stroke:#000000\nstyle 3 color:#000000, fill:#BDB76B, stroke:#004563\n"

render_mermaid(mermaidGraph)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-58a64a19-abd5-465c-a8a7-b2451345249e-7620-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     UserIdentity - garygeeke
#                 </h3>
#                 <p id="mermaid-graph-58a64a19-abd5-465c-a8a7-b2451345249e-7620-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 58a64a19-abd5-465c-a8a7-b2451345249e
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*User Identity*
# **garygeeke**&quot;}
# 2@{ shape: trap-t, label: &quot;*Person*
# **Gary Geeke**&quot;}
# 2==&gt;|&quot;Profile Identity&quot;|1
# 3@{ shape: cyl, label: &quot;*Secrets Collection*
# **cocoUserDirectory**&quot;}
# 3==&gt;|&quot;User Account&quot;|1
# ...

# %% [markdown]
# ----
#
# ## Exception Types
#
#
# **OMAGServerPlatformCataloger** creates exceptions if there are potential issues with the user information it finds in the user directory.
#
# ### Missing user accounts
#
# This identifies accounts defined to Egeria but missing from the user directory.
#
# ----

# %%
mermaidGraph= "---\ntitle: ExceptionType - Missing User Account Exception [40b941d8-fcba-49e8-9e9d-85090e6e817c]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Exception Type*\n**Missing User Account Exception**\"}\n2@{ shape: bow-rect, label: \"*User Identity*\n**ANON 000190**\"}\n2==>|\"ANON 000190 [Exception]\"|1\n3@{ shape: bow-rect, label: \"*User Identity*\n**ANON 000098**\"}\n3==>|\"ANON 000098 [Exception]\"|1\n4@{ shape: bow-rect, label: \"*User Identity*\n**ANON 000034**\"}\n4==>|\"ANON 000034 [Exception]\"|1\n5@{ shape: bow-rect, label: \"*User Identity*\n**ANON 000087**\"}\n5==>|\"ANON 000087 [Exception]\"|1\n6@{ shape: bow-rect, label: \"*User Identity*\n**ANON 000128**\"}\n6==>|\"ANON 000128 [Exception]\"|1\n7@{ shape: bow-rect, label: \"*User Identity*\n**ANON 000031**\"}\n7==>|\"ANON 000031 [Exception]\"|1\n8@{ shape: stadium, label: \"*Exception*\n**... plus 209 Items**\"}\n8-.->1\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 3 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 4 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 5 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 6 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 7 color:#000000, fill:#FF8C00, stroke:#000000\nstyle 8 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\n"
render_mermaid(mermaidGraph)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-40b941d8-fcba-49e8-9e9d-85090e6e817c-5bf1-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     ExceptionType - Missing User Account Exception
#                 </h3>
#                 <p id="mermaid-graph-40b941d8-fcba-49e8-9e9d-85090e6e817c-5bf1-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 40b941d8-fcba-49e8-9e9d-85090e6e817c
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Exception Type*
# **Missing User Account Exception**&quot;}
# 2@{ shape: bow-rect, label: &quot;*User Identity*
# **ANON 000190**&quot;}
# 2==&gt;|&quot;ANON 000190 [Exception]&quot;|1
# 3@{ shape: bow-rect, label: &quot;*User Identity*
# **ANON 000098**&quot;}
# ...

# %% [markdown]
# ----
#
# ### Clear text password
#
# This identifies users that have clear text passwords - they need to change their passwords to ensure they are encrypted.
#
# ----

# %%
mermaidGraph= "---\ntitle: ExceptionType - Clear Text Password Exception [769e2f89-a940-4f32-abbc-a427c78c14ca]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Exception Type*\n**Clear Text Password Exception**\"}\n2@{ shape: hex, label: \"*Software Server Platform*\n**OMAG Server Platform**\"}\n2==>|\"stewfaster [Exception]\"|1\n2==>|\"robbierecords [Exception]\"|1\n2==>|\"egerianpa [Exception]\"|1\n2==>|\"bobnitter [Exception]\"|1\n2==>|\"callie-marketing [Exception]\"|1\n2==>|\"harryhopeful [Exception]\"|1\n3@{ shape: stadium, label: \"*Exception*\n**... plus 27 Items**\"}\n3-.->1\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nclick 2 \"https://egeria-project.org/concepts/omag-server-platform/\" \"Click for more documentation\" _blank\n"
render_mermaid(mermaidGraph)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-769e2f89-a940-4f32-abbc-a427c78c14ca-0ca2-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     ExceptionType - Clear Text Password Exception
#                 </h3>
#                 <p id="mermaid-graph-769e2f89-a940-4f32-abbc-a427c78c14ca-0ca2-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 769e2f89-a940-4f32-abbc-a427c78c14ca
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Exception Type*
# **Clear Text Password Exception**&quot;}
# 2@{ shape: hex, label: &quot;*Software Server Platform*
# **OMAG Server Platform**&quot;}
# 2==&gt;|&quot;stewfaster [Exception]&quot;|1
# 2==&gt;|&quot;robbierecords [Exception]&quot;|1
# ...

# %% [markdown]
# ----
#
# ### Missing UserIdentity exception
#
# This is for an account in the user directory that is missing from open metadata.
#
# ----

# %%
mermaidGraph= "---\ntitle: ExceptionType - Missing User Identity Exception [7998ac6d-b9db-4005-8d7c-9724484931c5]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Exception Type*\n**Missing User Identity Exception**\"}\n2@{ shape: hex, label: \"*Software Server Platform*\n**OMAG Server Platform**\"}\n2==>|\"qsviewnpa [Exception]\"|1\n2==>|\"activenpa [Exception]\"|1\n2==>|\"reddyleft [Exception]\"|1\n2==>|\"callie-marketing [Exception]\"|1\n2==>|\"egerianpa [Exception]\"|1\n2==>|\"enginenpa [Exception]\"|1\n3@{ shape: stadium, label: \"*Exception*\n**... plus 16 Items**\"}\n3-.->1\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 3 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nclick 2 \"https://egeria-project.org/concepts/omag-server-platform/\" \"Click for more documentation\" _blank\n"
render_mermaid(mermaidGraph)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-7998ac6d-b9db-4005-8d7c-9724484931c5-a1bc-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     ExceptionType - Missing User Identity Exception
#                 </h3>
#                 <p id="mermaid-graph-7998ac6d-b9db-4005-8d7c-9724484931c5-a1bc-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 7998ac6d-b9db-4005-8d7c-9724484931c5
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Exception Type*
# **Missing User Identity Exception**&quot;}
# 2@{ shape: hex, label: &quot;*Software Server Platform*
# **OMAG Server Platform**&quot;}
# 2==&gt;|&quot;qsviewnpa [Exception]&quot;|1
# 2==&gt;|&quot;activenpa [Exception]&quot;|1
# ...

# %% [markdown]
# -----
#
# # Governance zones - digital-products
#
# ## Retrieved by Ivor
#
# -----

# %%
mermaidGraph= "---\ntitle: GovernanceZone - Digital Products Zone [f1fbad4c-b4cb-4d78-aaf3-072ca5043390]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Governance Zone*\n**Digital Products Zone**\"}\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\n"
render_mermaid(mermaidGraph)
print(mermaidGraph)
    
zoneProfileMermaidPieChart= "pie\ntitle Membership of Digital Products Zone\n\"SolutionActorRole\" : 3\n\"DigitalProductCatalog\" : 1\n\"BusinessImperative\" : 1\n\"DigitalProductFamily\" : 8\n\"GovernancePolicy\" : 1\n\"PersonRole\" : 3\n\"LicenseType\" : 3\n\"SolutionComponent\" : 10\n\"SolutionBlueprint\" : 8\n\"ServiceLevelObjective\" : 13\n\"EngineAction\" : 1\n\"Community\" : 3\n\"GovernanceApproach\" : 1\n\"DigitalProduct\" : 92\n"
render_mermaid(zoneProfileMermaidPieChart)
print(zoneProfileMermaidPieChart)

zoneProfileAnchoredMermaidPieChart= "pie\ntitle Anchored Elements of Digital Products Zone\n\"GovernanceActionProcess\" : 368\n\"DigitalProductFamily\" : 9\n\"GovernancePolicy\" : 1\n\"LicenseType\" : 3\n\"PersonRole\" : 103\n\"SolutionComponent\" : 10\n\"Endpoint\" : 72\n\"EngineAction\" : 1\n\"DataSpec\" : 92\n\"SolutionActorRole\" : 3\n\"DigitalProductCatalog\" : 1\n\"BusinessImperative\" : 1\n\"DataStructure\" : 92\n\"DataDictionary\" : 1\n\"ReferenceCodeTable\" : 91\n\"NoteLog\" : 3\n\"SolutionBlueprint\" : 8\n\"ServiceLevelObjective\" : 13\n\"VirtualConnection\" : 72\n\"Glossary\" : 1\n\"NotificationType\" : 368\n\"TabularDataSet\" : 1\n\"Community\" : 3\n\"GovernanceApproach\" : 1\n\"DigitalProduct\" : 92\n"
render_mermaid(zoneProfileAnchoredMermaidPieChart)
print(zoneProfileAnchoredMermaidPieChart)
     
zoneProfileAllMermaidPieChart= "pie\ntitle All Elements of Digital Products Zone\n\"GovernanceActionProcess\" : 368\n\"DigitalProductFamily\" : 17\n\"GovernancePolicy\" : 2\n\"PersonRole\" : 106\n\"LicenseType\" : 6\n\"SolutionComponent\" : 20\n\"Endpoint\" : 72\n\"EngineAction\" : 2\n\"DataSpec\" : 92\n\"SolutionActorRole\" : 6\n\"DigitalProductCatalog\" : 2\n\"BusinessImperative\" : 2\n\"DataStructure\" : 92\n\"DataDictionary\" : 1\n\"ReferenceCodeTable\" : 91\n\"NoteLog\" : 3\n\"SolutionBlueprint\" : 16\n\"VirtualConnection\" : 72\n\"ServiceLevelObjective\" : 26\n\"Glossary\" : 1\n\"NotificationType\" : 368\n\"TabularDataSet\" : 1\n\"Community\" : 6\n\"GovernanceApproach\" : 2\n\"DigitalProduct\" : 184\n"
render_mermaid(zoneProfileAllMermaidPieChart)
print(zoneProfileAllMermaidPieChart)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-f1fbad4c-b4cb-4d78-aaf3-072ca5043390-d8ba-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     GovernanceZone - Digital Products Zone
#                 </h3>
#                 <p id="mermaid-graph-f1fbad4c-b4cb-4d78-aaf3-072ca5043390-d8ba-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: f1fbad4c-b4cb-4d78-aaf3-072ca5043390
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Governance Zone*
# **Digital Products Zone**&quot;}
# style 1 color:#000000, fill:#e0ab18, stroke:#004563
#     </div>
#     <script type_name = "text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
# ...

# %%
mermaidGraph= "---\ntitle: GovernanceZone - Digital Products Zone [fd27d6b2-ccf7-4a47-8f6a-5f3a3fbeb80c]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Governance Zone*\n**Digital Products Zone**\"}\n2@{ shape: cyl, label: \"*Secrets Collection*\n**cocoUserDirectory**\"}\n2==>|\"Resource Permissions\"|1\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#BDB76B, stroke:#004563\n"
render_mermaid(mermaidGraph)
    
zoneProfileMermaidPieChart="pie\ntitle Membership of Digital Products Zone\n\"DigitalProduct\" : 103\n\"SolutionBlueprint\" : 8\n\"DigitalProductFamily\" : 8\n\"SolutionActorRole\" : 4\n\"ServiceLevelObjective\" : 4\n\"Community\" : 4\n\"LicenseType\" : 3\n\"PersonRole\" : 2\n\"DigitalProductCatalog\" : 1\n\"BusinessImperative\" : 1\n\"GovernancePolicy\" : 1\n\"GovernanceApproach\" : 1\n"
render_mermaid(zoneProfileMermaidPieChart)
print(zoneProfileMermaidPieChart)

zoneProfileAnchoredMermaidPieChart= "pie\ntitle Anchored Elements of Digital Products Zone\n\"GovernanceActionProcess\" : 288\n\"NotificationType\" : 288\n\"PersonRole\" : 113\n\"DataStructure\" : 103\n\"DataSpec\" : 103\n\"DigitalProduct\" : 103\n\"ReferenceCodeTable\" : 72\n\"Endpoint\" : 72\n\"VirtualConnection\" : 72\n\"DigitalProductFamily\" : 9\n\"SolutionBlueprint\" : 8\n\"SolutionActorRole\" : 4\n\"NoteLog\" : 4\n\"ServiceLevelObjective\" : 4\n\"Community\" : 4\n\"LicenseType\" : 3\n\"Others\" : 3\n"
render_mermaid(zoneProfileAnchoredMermaidPieChart)
print(zoneProfileAnchoredMermaidPieChart)
     
zoneProfileAllMermaidPieChart= "pie\ntitle All Elements of Digital Products Zone\n\"GovernanceActionProcess\" : 288\n\"NotificationType\" : 288\n\"DigitalProduct\" : 206\n\"PersonRole\" : 115\n\"DataStructure\" : 103\n\"DataSpec\" : 103\n\"ReferenceCodeTable\" : 72\n\"Endpoint\" : 72\n\"VirtualConnection\" : 72\n\"DigitalProductFamily\" : 17\n\"SolutionBlueprint\" : 16\n\"SolutionActorRole\" : 8\n\"ServiceLevelObjective\" : 8\n\"Community\" : 8\n\"LicenseType\" : 6\n\"NoteLog\" : 4\n\"Others\" : 4\n"
render_mermaid(zoneProfileAllMermaidPieChart)
print(zoneProfileAllMermaidPieChart)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-fd27d6b2-ccf7-4a47-8f6a-5f3a3fbeb80c-d99b-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     GovernanceZone - Digital Products Zone
#                 </h3>
#                 <p id="mermaid-graph-fd27d6b2-ccf7-4a47-8f6a-5f3a3fbeb80c-d99b-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: fd27d6b2-ccf7-4a47-8f6a-5f3a3fbeb80c
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Governance Zone*
# **Digital Products Zone**&quot;}
# 2@{ shape: cyl, label: &quot;*Secrets Collection*
# **cocoUserDirectory**&quot;}
# 2==&gt;|&quot;Resource Permissions&quot;|1
# style 1 color:#000000, fill:#e0ab18, stroke:#004563
# ...

# %% [markdown]
# ----
# ## Retrieved by Gary
#
# ----

# %%
mermaidGraph= "---\ntitle: GovernanceZone - Digital Products Zone [fd27d6b2-ccf7-4a47-8f6a-5f3a3fbeb80c]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Governance Zone*\n**Digital Products Zone**\"}\n2@{ shape: cyl, label: \"*Secrets Collection*\n**cocoUserDirectory**\"}\n2==>|\"Resource Permissions\"|1\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#BDB76B, stroke:#004563\n"
render_mermaid(mermaidGraph)

zoneProfileMermaidPieChart= "pie\ntitle Membership of Digital Products Zone\n\"DigitalProduct\" : 103\n\"SolutionBlueprint\" : 8\n\"DigitalProductFamily\" : 8\n\"SolutionActorRole\" : 4\n\"ServiceLevelObjective\" : 4\n\"Community\" : 4\n\"LicenseType\" : 3\n\"PersonRole\" : 2\n\"DigitalProductCatalog\" : 1\n\"BusinessImperative\" : 1\n\"GovernancePolicy\" : 1\n\"GovernanceApproach\" : 1\n"
render_mermaid(zoneProfileMermaidPieChart)
print(zoneProfileMermaidPieChart)

zoneProfileAnchoredMermaidPieChart=  "pie\ntitle Anchored Elements of Digital Products Zone\n\"GovernanceActionProcess\" : 288\n\"NotificationType\" : 288\n\"PersonRole\" : 113\n\"DataStructure\" : 103\n\"DataSpec\" : 103\n\"DigitalProduct\" : 103\n\"ReferenceCodeTable\" : 72\n\"Endpoint\" : 72\n\"VirtualConnection\" : 72\n\"DigitalProductFamily\" : 9\n\"SolutionBlueprint\" : 8\n\"SolutionActorRole\" : 4\n\"NoteLog\" : 4\n\"ServiceLevelObjective\" : 4\n\"Community\" : 4\n\"LicenseType\" : 3\n\"Others\" : 3\n"
render_mermaid(zoneProfileAnchoredMermaidPieChart)

zoneProfileAllMermaidPieChart="pie\ntitle All Elements of Digital Products Zone\n\"GovernanceActionProcess\" : 288\n\"NotificationType\" : 288\n\"DigitalProduct\" : 206\n\"PersonRole\" : 115\n\"DataStructure\" : 103\n\"DataSpec\" : 103\n\"ReferenceCodeTable\" : 72\n\"Endpoint\" : 72\n\"VirtualConnection\" : 72\n\"DigitalProductFamily\" : 17\n\"SolutionBlueprint\" : 16\n\"SolutionActorRole\" : 8\n\"ServiceLevelObjective\" : 8\n\"Community\" : 8\n\"LicenseType\" : 6\n\"NoteLog\" : 4\n\"Others\" : 4\n"
render_mermaid(zoneProfileAllMermaidPieChart)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-fd27d6b2-ccf7-4a47-8f6a-5f3a3fbeb80c-6684-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     GovernanceZone - Digital Products Zone
#                 </h3>
#                 <p id="mermaid-graph-fd27d6b2-ccf7-4a47-8f6a-5f3a3fbeb80c-6684-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: fd27d6b2-ccf7-4a47-8f6a-5f3a3fbeb80c
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Governance Zone*
# **Digital Products Zone**&quot;}
# 2@{ shape: cyl, label: &quot;*Secrets Collection*
# **cocoUserDirectory**&quot;}
# 2==&gt;|&quot;Resource Permissions&quot;|1
# style 1 color:#000000, fill:#e0ab18, stroke:#004563
# ...

# %%
collectionMermaidMindMap="mindmap\n**DigitalProductCatalog** Open Metadata Digital Product Catalog\n    **Glossary** Open Metadata Digital Product Glossary\n        **CollectionFolder** Digital Product Basics\n        **CollectionFolder** Digital Subscriptions\n        **CollectionFolder** Data Item Semantics\n    **DigitalProductFamily** Open Metadata Digital Products\n        **DigitalProductFamily** Organization Observability\n        **DigitalProductFamily** Survey Reports\n        **DigitalProductFamily** IT Operations Observability\n        **DigitalProductFamily** Governance Observability\n        **DigitalProductFamily** Open Metadata Types\n        **DigitalProductFamily** Actor, Places and Product Master Data\n        **DigitalProductFamily** Valid Metadata Value Sets\n        **DigitalProductFamily** Reference Data Sets\n    **DataDictionary** Open Metadata Digital Product Data Dictionary\n"
render_mermaid(collectionMermaidMindMap)

mermaidGraph="---\ntitle: DigitalProductCatalog - Open Metadata Digital Product Catalog [9a9275fa-6f5f-4cb6-9492-55ab52840f7a]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Digital Product Catalog*\n**Open Metadata Digital Product Catalog**\"}\n2@{ shape: trap-t, label: \"*Engine Action*\n**baudot-subscription-manager (EgeriaWatchdog)**\"}\n1==>|\"Actions\"|2\n3@{ shape: doc, label: \"*Governance Approach*\n**Digital Products**\"}\n1==>|\"More Information\"|3\n4@{ shape: rect, label: \"*Root Collection*\n**Digital Product Catalogs Root**\"}\n4==>|\"Collection Membership\"|1\n5@{ shape: rect, label: \"*Glossary*\n**Open Metadata Digital Product Glossary**\"}\n1==>|\"Collection Membership\"|5\n6@{ shape: rect, label: \"*Collection Folder*\n**Digital Product Basics**\"}\n5==>|\"Collection Membership\"|6\n7@{ shape: rect, label: \"*Glossary Term*\n**Digital Product**\"}\n6==>|\"Collection Membership\"|7\n8@{ shape: rect, label: \"*Collection Folder*\n**Digital Subscriptions**\"}\n5==>|\"Collection Membership\"|8\n9@{ shape: rect, label: \"*Glossary Term*\n**Evaluation Subscription**\"}\n8==>|\"Collection Membership\"|9\n10@{ shape: rect, label: \"*Glossary Term*\n**Ongoing Update Subscription**\"}\n8==>|\"Collection Membership\"|10\n11@{ shape: rect, label: \"*Collection Folder*\n**Data Item Semantics**\"}\n5==>|\"Collection Membership\"|11\n12@{ shape: rect, label: \"*Glossary Term*\n**Open Metadata Type Name**\"}\n11==>|\"Collection Membership\"|12\n13@{ shape: rect, label: \"*Glossary Term*\n**Unique Identifier**\"}\n11==>|\"Collection Membership\"|13\n14@{ shape: rect, label: \"*Digital Product Family*\n**Open Metadata Digital Products**\"}\n1==>|\"Collection Membership\"|14\n15@{ shape: rect, label: \"*Digital Product Family*\n**Organization Observability**\"}\n14==>|\"Collection Membership\"|15\n16@{ shape: rect, label: \"*Digital Product Family*\n**Survey Reports**\"}\n14==>|\"Collection Membership\"|16\n17@{ shape: rect, label: \"*Digital Product*\n**Resource measurement annotations for surveyed Relational Tables**\"}\n16==>|\"includes product [Collection Membership]\"|17\n18@{ shape: rect, label: \"*Digital Product*\n**Resource measurement annotations for surveyed Relational Data Managers**\"}\n16==>|\"includes product [Collection Membership]\"|18\n19@{ shape: rect, label: \"*Digital Product*\n**List of Request For Action Annotations from all Survey Reports**\"}\n16==>|\"includes product [Collection Membership]\"|19\n20@{ shape: rect, label: \"*Digital Product*\n**Resource measurement annotations for surveyed resources**\"}\n16==>|\"includes product [Collection Membership]\"|20\n21@{ shape: rect, label: \"*Digital Product*\n**List of Survey Reports**\"}\n16==>|\"includes product [Collection Membership]\"|21\n22@{ shape: rect, label: \"*Digital Product*\n**Missing File Classifiers**\"}\n16==>|\"includes product [Collection Membership]\"|22\n23@{ shape: stadium, label: \"*Collection Membership*\n**... plus 7 Items**\"}\n16-.->23\n24@{ shape: rect, label: \"*Digital Product Family*\n**IT Operations Observability**\"}\n14==>|\"Collection Membership\"|24\n25@{ shape: rect, label: \"*Digital Product*\n**Servers**\"}\n24==>|\"includes product [Collection Membership]\"|25\n26@{ shape: rect, label: \"*Digital Product Family*\n**Governance Observability**\"}\n14==>|\"Collection Membership\"|26\n27@{ shape: rect, label: \"*Digital Product*\n**Certifications**\"}\n26==>|\"includes product [Collection Membership]\"|27\n28@{ shape: rect, label: \"*Digital Product*\n**Licenses**\"}\n26==>|\"includes product [Collection Membership]\"|28\n29@{ shape: rect, label: \"*Digital Product*\n**Exceptions**\"}\n26==>|\"includes product [Collection Membership]\"|29\n30@{ shape: rect, label: \"*Digital Product*\n**Governance Controls**\"}\n26==>|\"includes product [Collection Membership]\"|30\n31@{ shape: rect, label: \"*Digital Product Family*\n**Open Metadata Types**\"}\n14==>|\"Collection Membership\"|31\n32@{ shape: rect, label: \"*Digital Product*\n**Open Metadata Attributes For Types List**\"}\n31==>|\"includes product [Collection Membership]\"|32\n33@{ shape: rect, label: \"*Digital Product*\n**Open Metadata Data Types List**\"}\n31==>|\"includes product [Collection Membership]\"|33\n34@{ shape: rect, label: \"*Digital Product*\n**Open Metadata Types List**\"}\n31==>|\"includes product [Collection Membership]\"|34\n35@{ shape: cyl, label: \"*Reference Code Table*\n**Data set for Open Metadata Types List**\"}\n34==>|\"product data set [Collection Membership]\"|35\n36@{ shape: rect, label: \"*Digital Product*\n**Open Metadata Attributes List**\"}\n31==>|\"includes product [Collection Membership]\"|36\n37@{ shape: rect, label: \"*Digital Product Family*\n**Actor, Places and Product Master Data**\"}\n14==>|\"Collection Membership\"|37\n38@{ shape: rect, label: \"*Digital Product*\n**Digital Product List**\"}\n37==>|\"includes product [Collection Membership]\"|38\n39@{ shape: rect, label: \"*Digital Product*\n**People List**\"}\n37==>|\"includes product [Collection Membership]\"|39\n40@{ shape: rect, label: \"*Digital Product*\n**Organization List**\"}\n37==>|\"includes product [Collection Membership]\"|40\n41@{ shape: rect, label: \"*Digital Product*\n**List of Locations**\"}\n37==>|\"includes product [Collection Membership]\"|41\n42@{ shape: stadium, label: \"*Collection Membership*\n**... plus 2 Items**\"}\n14-.->42\n43@{ shape: rect, label: \"*Data Dictionary*\n**Open Metadata Digital Product Data Dictionary**\"}\n1==>|\"Collection Membership\"|43\n44@{ shape: rect, label: \"*Data Field*\n**File Creation Time**\"}\n43==>|\"Collection Membership\"|44\n45@{ shape: rect, label: \"*Data Field*\n**Element Last Update Time**\"}\n43==>|\"Collection Membership\"|45\n46@{ shape: rect, label: \"*Data Field*\n**Summary**\"}\n43==>|\"Collection Membership\"|46\n47@{ shape: rect, label: \"*Data Field*\n**Open Metadata Type Name**\"}\n43==>|\"Collection Membership\"|47\n48@{ shape: rect, label: \"*Data Field*\n**Distinguished Name**\"}\n43==>|\"Collection Membership\"|48\n49@{ shape: rect, label: \"*Data Field*\n**Recipient**\"}\n43==>|\"Collection Membership\"|49\n50@{ shape: stadium, label: \"*Collection Membership*\n**... plus 218 Items**\"}\n43-.->50\n51@{ shape: rect, label: \"*Solution Blueprint*\n**Open Metadata Digital Product Catalog Solution**\"}\n1==>|\"Solution Design\"|51\nstyle 44 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 45 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 46 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 47 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 48 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 49 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 50 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 51 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 10 color:#000000, fill:#66CDAA, stroke:#008080\nstyle 11 color:#000000, fill:#8fbc8f, stroke:#000000\nstyle 12 color:#000000, fill:#66CDAA, stroke:#008080\nstyle 13 color:#000000, fill:#66CDAA, stroke:#008080\nstyle 14 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 15 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 16 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 17 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 18 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 19 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#7fffd4, stroke:#000000\nstyle 3 color:#FFFFFF, fill:#006400, stroke:#000000\nstyle 4 color:#000000, fill:#2e8b57, stroke:#000000\nstyle 5 color:#FFFFFF, fill:#008080, stroke:#000000\nstyle 6 color:#000000, fill:#8fbc8f, stroke:#000000\nstyle 7 color:#000000, fill:#66CDAA, stroke:#008080\nstyle 8 color:#000000, fill:#8fbc8f, stroke:#000000\nstyle 9 color:#000000, fill:#66CDAA, stroke:#008080\nstyle 20 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 21 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 22 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 23 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 24 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 25 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 26 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 27 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 28 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 29 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 30 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 31 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 32 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 33 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 34 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 35 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 36 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 37 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 38 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 39 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 40 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 41 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 42 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 43 color:#000000, fill:#d2691e, stroke:#000000\n"
render_mermaid(mermaidGraph)
# Out:
#     <div></div>
#     <div class="mermaid">
#         mindmap
# **DigitalProductCatalog** Open Metadata Digital Product Catalog
#     **Glossary** Open Metadata Digital Product Glossary
#         **CollectionFolder** Digital Product Basics
#         **CollectionFolder** Digital Subscriptions
#         **CollectionFolder** Data Item Semantics
#     **DigitalProductFamily** Open Metadata Digital Products
#         **DigitalProductFamily** Organization Observability
#         **DigitalProductFamily** Survey Reports
#         **DigitalProductFamily** IT Operations Observability
#         **DigitalProductFamily** Governance Observability
#         **DigitalProductFamily** Open Metadata Types
#         **DigitalProductFamily** Actor, Places and Product Master Data
#         **DigitalProductFamily** Valid Metadata Value Sets
#         **DigitalProductFamily** Reference Data Sets
#     **DataDictionary** Open Metadata Digital Product Data Dictionary
#
#     </div>
# ...

# %%
collectionMermaidMindMap="mindmap\n**DigitalProductCatalog** Open Metadata Digital Product Catalog\n    **Glossary** Open Metadata Digital Product Glossary\n        **CollectionFolder** Digital Product Basics\n        **CollectionFolder** Digital Subscriptions\n        **CollectionFolder** Data Item Semantics\n    **DigitalProductFamily** Open Metadata Digital Products\n        **DigitalProductFamily** Organization Observability\n        **DigitalProductFamily** Survey Reports\n        **DigitalProductFamily** IT Operations Observability\n        **DigitalProductFamily** Security Observability\n            **DigitalProductFamily** Secrets Observability\n            **DigitalProductFamily** Governance Zone Observability\n            **DigitalProductFamily** User Observability\n            **DigitalProductFamily** Security Observability\n        **DigitalProductFamily** Governance Observability\n        **DigitalProductFamily** Open Metadata Types\n        **DigitalProductFamily** Actor, Places and Product Master Data\n        **DigitalProductFamily** Valid Metadata Value Sets\n        **DigitalProductFamily** Reference Data Sets\n    **DataDictionary** Open Metadata Digital Product Data Dictionary\n"
render_mermaid(collectionMermaidMindMap)

mermaidGraph="---\ntitle: DigitalProductCatalog - Open Metadata Digital Product Catalog [9a9275fa-6f5f-4cb6-9492-55ab52840f7a]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Digital Product Catalog*\n**Open Metadata Digital Product Catalog**\"}\n2@{ shape: trap-t, label: \"*Engine Action*\n**baudot-subscription-manager (EgeriaWatchdog)**\"}\n1==>|\"Actions\"|2\n3@{ shape: doc, label: \"*Governance Approach*\n**Digital Products**\"}\n1==>|\"More Information\"|3\n4@{ shape: rect, label: \"*Root Collection*\n**Digital Product Catalogs Root**\"}\n4==>|\"Collection Membership\"|1\n5@{ shape: rect, label: \"*Glossary*\n**Open Metadata Digital Product Glossary**\"}\n1==>|\"Collection Membership\"|5\n6@{ shape: rect, label: \"*Collection Folder*\n**Digital Product Basics**\"}\n5==>|\"Collection Membership\"|6\n7@{ shape: rect, label: \"*Glossary Term*\n**Digital Product**\"}\n6==>|\"Collection Membership\"|7\n8@{ shape: rect, label: \"*Collection Folder*\n**Digital Subscriptions**\"}\n5==>|\"Collection Membership\"|8\n9@{ shape: rect, label: \"*Glossary Term*\n**Evaluation Subscription**\"}\n8==>|\"Collection Membership\"|9\n10@{ shape: rect, label: \"*Glossary Term*\n**Ongoing Update Subscription**\"}\n8==>|\"Collection Membership\"|10\n11@{ shape: rect, label: \"*Collection Folder*\n**Data Item Semantics**\"}\n5==>|\"Collection Membership\"|11\n12@{ shape: rect, label: \"*Glossary Term*\n**Open Metadata Type Name**\"}\n11==>|\"Collection Membership\"|12\n13@{ shape: rect, label: \"*Glossary Term*\n**Unique Identifier**\"}\n11==>|\"Collection Membership\"|13\n14@{ shape: rect, label: \"*Digital Product Family*\n**Open Metadata Digital Products**\"}\n1==>|\"Collection Membership\"|14\n15@{ shape: rect, label: \"*Digital Product Family*\n**Organization Observability**\"}\n14==>|\"Collection Membership\"|15\n16@{ shape: rect, label: \"*Digital Product Family*\n**Survey Reports**\"}\n14==>|\"Collection Membership\"|16\n17@{ shape: rect, label: \"*Digital Product*\n**Resource measurement annotations for surveyed Relational Tables**\"}\n16==>|\"includes product [Collection Membership]\"|17\n18@{ shape: rect, label: \"*Digital Product*\n**Resource measurement annotations for surveyed Relational Data Managers**\"}\n16==>|\"includes product [Collection Membership]\"|18\n19@{ shape: rect, label: \"*Digital Product*\n**List of Request For Action Annotations from all Survey Reports**\"}\n16==>|\"includes product [Collection Membership]\"|19\n20@{ shape: rect, label: \"*Digital Product*\n**Resource measurement annotations for surveyed resources**\"}\n16==>|\"includes product [Collection Membership]\"|20\n21@{ shape: rect, label: \"*Digital Product*\n**List of Survey Reports**\"}\n16==>|\"includes product [Collection Membership]\"|21\n22@{ shape: rect, label: \"*Digital Product*\n**Missing File Classifiers**\"}\n16==>|\"includes product [Collection Membership]\"|22\n23@{ shape: stadium, label: \"*Collection Membership*\n**... plus 7 Items**\"}\n16-.->23\n24@{ shape: rect, label: \"*Digital Product Family*\n**IT Operations Observability**\"}\n14==>|\"Collection Membership\"|24\n25@{ shape: rect, label: \"*Digital Product*\n**Servers**\"}\n24==>|\"includes product [Collection Membership]\"|25\n26@{ shape: rect, label: \"*Digital Product Family*\n**Security Observability**\"}\n14==>|\"Collection Membership\"|26\n27@{ shape: rect, label: \"*Digital Product Family*\n**Secrets Observability**\"}\n26==>|\"includes product [Collection Membership]\"|27\n28@{ shape: rect, label: \"*Digital Product*\n**Open Metadata Secrets Collections**\"}\n27==>|\"includes product [Collection Membership]\"|28\n29@{ shape: rect, label: \"*Digital Product*\n**Open Metadata Secrets Stores**\"}\n27==>|\"includes product [Collection Membership]\"|29\n30@{ shape: rect, label: \"*Digital Product Family*\n**Governance Zone Observability**\"}\n26==>|\"includes product [Collection Membership]\"|30\n31@{ shape: rect, label: \"*Digital Product*\n**Zone Membership Profile**\"}\n26==>|\"includes product [Collection Membership]\"|31\n32@{ shape: rect, label: \"*Digital Product Family*\n**User Observability**\"}\n26==>|\"includes product [Collection Membership]\"|32\n33@{ shape: rect, label: \"*Digital Product*\n**Open Metadata User Identities**\"}\n32==>|\"includes product [Collection Membership]\"|33\n34@{ shape: rect, label: \"*Digital Product*\n**Open Metadata User Accounts**\"}\n32==>|\"includes product [Collection Membership]\"|34\n35@{ shape: rect, label: \"*Digital Product Family*\n**Security Observability**\"}\n26==>|\"includes product [Collection Membership]\"|35\n36@{ shape: rect, label: \"*Digital Product*\n**Zone Membership Totals**\"}\n26==>|\"includes product [Collection Membership]\"|36\n37@{ shape: rect, label: \"*Digital Product Family*\n**Governance Observability**\"}\n14==>|\"Collection Membership\"|37\n38@{ shape: rect, label: \"*Digital Product*\n**Certifications**\"}\n37==>|\"includes product [Collection Membership]\"|38\n39@{ shape: rect, label: \"*Digital Product*\n**Licenses**\"}\n37==>|\"includes product [Collection Membership]\"|39\n40@{ shape: rect, label: \"*Digital Product*\n**Exceptions**\"}\n37==>|\"includes product [Collection Membership]\"|40\n41@{ shape: rect, label: \"*Digital Product*\n**Governance Controls**\"}\n37==>|\"includes product [Collection Membership]\"|41\n42@{ shape: rect, label: \"*Digital Product Family*\n**Open Metadata Types**\"}\n14==>|\"Collection Membership\"|42\n43@{ shape: rect, label: \"*Digital Product*\n**Open Metadata Attributes For Types List**\"}\n42==>|\"includes product [Collection Membership]\"|43\n44@{ shape: rect, label: \"*Digital Product*\n**Open Metadata Data Types List**\"}\n42==>|\"includes product [Collection Membership]\"|44\n45@{ shape: rect, label: \"*Digital Product*\n**Open Metadata Types List**\"}\n42==>|\"includes product [Collection Membership]\"|45\n46@{ shape: cyl, label: \"*Reference Code Table*\n**Data set for Open Metadata Types List**\"}\n45==>|\"product data set [Collection Membership]\"|46\n47@{ shape: rect, label: \"*Digital Product*\n**Open Metadata Attributes List**\"}\n42==>|\"includes product [Collection Membership]\"|47\n48@{ shape: stadium, label: \"*Collection Membership*\n**... plus 3 Items**\"}\n14-.->48\n49@{ shape: rect, label: \"*Data Dictionary*\n**Open Metadata Digital Product Data Dictionary**\"}\n1==>|\"Collection Membership\"|49\n50@{ shape: rect, label: \"*Data Field*\n**File Creation Time**\"}\n49==>|\"Collection Membership\"|50\n51@{ shape: rect, label: \"*Data Field*\n**Element Last Update Time**\"}\n49==>|\"Collection Membership\"|51\n52@{ shape: rect, label: \"*Data Field*\n**Summary**\"}\n49==>|\"Collection Membership\"|52\n53@{ shape: rect, label: \"*Data Field*\n**Open Metadata Type Name**\"}\n49==>|\"Collection Membership\"|53\n54@{ shape: rect, label: \"*Data Field*\n**Distinguished Name**\"}\n49==>|\"Collection Membership\"|54\n55@{ shape: rect, label: \"*Data Field*\n**Recipient**\"}\n49==>|\"Collection Membership\"|55\n56@{ shape: stadium, label: \"*Collection Membership*\n**... plus 218 Items**\"}\n49-.->56\n57@{ shape: rect, label: \"*Solution Blueprint*\n**Open Metadata Digital Product Catalog Solution**\"}\n1==>|\"Solution Design\"|57\nstyle 44 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 45 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 46 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 47 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 48 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 49 color:#000000, fill:#d2691e, stroke:#000000\nstyle 50 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 51 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 52 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 53 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 10 color:#000000, fill:#66CDAA, stroke:#008080\nstyle 54 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 11 color:#000000, fill:#8fbc8f, stroke:#000000\nstyle 55 color:#000000, fill:#ffe3cc, stroke:#FFA500\nstyle 12 color:#000000, fill:#66CDAA, stroke:#008080\nstyle 56 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 13 color:#000000, fill:#66CDAA, stroke:#008080\nstyle 57 color:#000000, fill:#f5fffa, stroke:#000000\nstyle 14 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 15 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 16 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 17 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 18 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 19 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#7fffd4, stroke:#000000\nstyle 3 color:#FFFFFF, fill:#006400, stroke:#000000\nstyle 4 color:#000000, fill:#2e8b57, stroke:#000000\nstyle 5 color:#FFFFFF, fill:#008080, stroke:#000000\nstyle 6 color:#000000, fill:#8fbc8f, stroke:#000000\nstyle 7 color:#000000, fill:#66CDAA, stroke:#008080\nstyle 8 color:#000000, fill:#8fbc8f, stroke:#000000\nstyle 9 color:#000000, fill:#66CDAA, stroke:#008080\nstyle 20 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 21 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 22 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 23 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 24 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 25 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 26 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 27 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 28 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 29 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 30 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 31 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 32 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 33 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 34 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 35 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 36 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 37 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 38 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 39 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 40 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 41 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 42 color:#000000, fill:#838cc7, stroke:#3079ab\nstyle 43 color:#000000, fill:#838cc7, stroke:#3079ab\n"

render_mermaid(mermaidGraph)
# Out:
#     <div></div>
#     <div class="mermaid">
#         mindmap
# **DigitalProductCatalog** Open Metadata Digital Product Catalog
#     **Glossary** Open Metadata Digital Product Glossary
#         **CollectionFolder** Digital Product Basics
#         **CollectionFolder** Digital Subscriptions
#         **CollectionFolder** Data Item Semantics
#     **DigitalProductFamily** Open Metadata Digital Products
#         **DigitalProductFamily** Organization Observability
#         **DigitalProductFamily** Survey Reports
#         **DigitalProductFamily** IT Operations Observability
#         **DigitalProductFamily** Security Observability
#             **DigitalProductFamily** Secrets Observability
#             **DigitalProductFamily** Governance Zone Observability
#             **DigitalProductFamily** User Observability
#             **DigitalProductFamily** Security Observability
#         **DigitalProductFamily** Governance Observability
# ...
