# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Egeria Workbook
#
# # Load Martyn's Law
#
# This notebook contains the commands to load the markdown files containing the Dr.Egeria commands to create the open metadata definitions for describing the requirements for a new UK regulation called the **Terrorism (Protection of Premises) Act 2025** known as **Martyn's Law**.  This new law is of relevance to Coco Pharmaceuticals because they hold an annual conference in their London Offices.  More information on the sceanario is found on Egeria's document Website:
#
# * [Ivor Padlock prepares for Martyn's Law](https://egeria-project.org/practices/coco-pharmaceuticals/scenarios/preparing-for-martyns-law/overview/) scenario description
# * [Assessing a new regulation](https://egeria-project.org/egeria-solutions/assessing-new-regulation/overview/) solution
#
# Run the cells below to create the definitions Ivor Padlock defines in his initial assessment of the Martyn's Law requirements.  The processing of each cell may take a minute so look for message
#
# **v2: Processing complete for 'file name'**
#
#
# ----

# %%
# Initialize the python environment

import os
from md_processing.dr_egeria import process_md_file
from pyegeria.core.config import load_app_config, settings, pretty_print_config

load_app_config()                              # reads config.json via env vars / .env
env = settings.Environment

print("Connecting to server: " + env.egeria_view_server + " at " + env.egeria_view_server_url)  # e.g. "Connecting to server qs-view-server at https://localhost:9443"
# Out:
# Connecting to server: qs-view-server at https://host.docker.internal:9443

# %%
# Process external-references.md

process_md_file(
    input_file="./external-references.md",
    output_folder="./receipts",
    directive="process",
    server=env.egeria_view_server,
    url=env.egeria_view_server_url,
    userid=os.environ.get("EGERIA_USER", "ivorpadlock"),
    user_pass=os.environ.get("EGERIA_USER_PASSWORD", "secret"),
    summary_only=True,
)
# Out:
# v2: Processing Markdown File: /home/jovyan/coco-workbooks/4. keeping-safe/martyns-law/external-references.md
# *** INFO: PROCESS MODE ***
# Dr. Egeria will EXECUTE these commands and make PERMANENT CHANGES to Egeria.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
#                                                                                     Dr. Egeria v2 Processing Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Markdown Command          ┃ Canonical Command         ┃ Status  ┃ Found ┃ Display Name / End 1                    ┃ Qualified Name / End2                  ┃ Message                                 ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Update Collection Folder  │ Update Collection Folder  │ SUCCESS │ Yes   │ External Sources for Martyn's Law       │ CollectionFolder::MartynsLawUK::Extern │ Executed Update Collection Folder       │
# │                           │                           │         │       │                                         │ alSources                              │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ be99ac6a-1100-4552-9616-63a6f6649ef8) | │
# │                           │                           │         │       │                                         │                                        │ Related: Journal Entry (GUID:           │
# │                           │                           │         │       │                                         │                                        │ f779a06c-f7eb-456a-8a12-2798ded9125e)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update Cited Document     │ Update Cited Document     │ SUCCESS │ Yes   │ Terrorism (Protection of Premises) Act  │ CitedDocument::MartynsLawUK::TheAct    │ Executed Update Cited Document (GUID:   │
# │                           │                           │         │       │ 2025                                    │                                        │ 2a6f8969-9f90-43d4-aec2-b713e8b706cf) | │
# │                           │                           │         │       │                                         │                                        │ Related: Journal Entry (GUID:           │
# │                           │                           │         │       │                                         │                                        │ 1f0e9f1f-76a9-4003-b892-06614a3e5960)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ CitedDocument::MartynsLawUK::TheAct     │                                        │ Executed Add Member to Collection       │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update Cited Document     │ Update Cited Document     │ SUCCESS │ Yes   │ Martyn's Law Statutory Guidance from    │ CitedDocument::MartynsLawUK::Statutory │ Executed Update Cited Document (GUID:   │
# │                           │                           │         │       │ the UK Government (Home Office)         │ Guidance                               │ 37cf7e00-fe5f-4038-bcf0-c4d3e11a5689)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ CitedDocument::MartynsLawUK::StatutoryG │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ uidance                                 │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ Premises affected by Martyn's Law       │ ExternalReference::MartynsLawUK::Scope │ Executed Update External Reference      │
# │                           │                           │         │       │                                         │ ::Premises                             │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ 234b49e5-523a-41bc-9796-5350e78ff5be)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::Scope: │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ :Premises                               │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ Events affected by Martyn's Law         │ ExternalReference::MartynsLawUK::Scope │ Executed Update External Reference      │
# │                           │                           │         │       │                                         │ ::Events                               │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ 8c912a74-3a02-4aee-877a-1e09fc2b86d8)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::Scope: │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ :Events                                 │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ Capacity estimation                     │ ExternalReference::MartynsLawUK::Capac │ Executed Update External Reference      │
# │                           │                           │         │       │                                         │ ityEstimates                           │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ 4b39c5e5-9d41-4393-9378-88ff7ae78aa9)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::Capaci │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ tyEstimates                             │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ Responsible person factsheet            │ ExternalReference::MartynsLawUK::Respo │ Executed Update External Reference      │
# │                           │                           │         │       │                                         │ nsiblePerson                           │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ 4cd9c210-42ef-43d8-a1e8-72be101045a9)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::Respon │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ siblePerson                             │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ Standard duty requirements factsheet    │ ExternalReference::MartynsLawUK::Stand │ Executed Update External Reference      │
# │                           │                           │         │       │                                         │ ardDutyRequirements                    │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ d22bcf4c-de47-4540-a118-fa429d1a1e79)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::Standa │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ rdDutyRequirements                      │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ Enhanced duty requirements factsheet    │ ExternalReference::MartynsLawUK::Enhan │ Executed Update External Reference      │
# │                           │                           │         │       │                                         │ cedDutyRequirements                    │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ 2f3d3dc5-3595-4c69-ba4e-2d49fd5c576e)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::Enhanc │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ edDutyRequirements                      │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ The regulator, sanctions and            │ ExternalReference::MartynsLawUK::TheRe │ Executed Update External Reference      │
# │                           │                           │         │       │ enforcement factsheet                   │ gulator                                │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ a5f637a6-be98-497b-9271-64237b4664a6)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::TheReg │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ ulator                                  │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update Related Media      │ Update Related Media      │ SUCCESS │ Yes   │ One-Page Leaflet for Martyn's Law       │ ExternalReference::MartynsLawUK::OnePa │ Executed Update Related Media (GUID:    │
# │                           │                           │         │       │                                         │ geLeaflet                              │ 837b3d46-613e-4add-98e9-65dccc5bf21c)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::OnePag │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ eLeaflet                                │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update Related Media      │ Update Related Media      │ SUCCESS │ Yes   │ Which premises are in scope Infographic │ RelatedMedia::MartynsLawUK::Scope::Pre │ Executed Update Related Media (GUID:    │
# │                           │                           │         │       │                                         │ mises::Infographic                     │ 403e74f0-e212-400b-b696-9a802a60136d)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ RelatedMedia::MartynsLawUK::Scope::Prem │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ ises::Infographic                       │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update Related Media      │ Update Related Media      │ SUCCESS │ Yes   │ Which events are in scope Infographic   │ RelatedMedia::MartynsLawUK::Scope::Eve │ Executed Update Related Media (GUID:    │
# │                           │                           │         │       │                                         │ nts::Infographic                       │ 7fb478fd-5e40-4ea4-b561-4e1dd58003da)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ RelatedMedia::MartynsLawUK::Scope::Even │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ ts::Infographic                         │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ Martyn's Law Myth Buster                │ ExternalReference::MartynsLawUK::MythB │ Executed Update External Reference      │
# │                           │                           │         │       │                                         │ uster                                  │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ bfb1260b-e41b-44d0-b223-1e6a1c79862e)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::MythBu │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ ster                                    │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ Top Tips on getting ready for Martyn's  │ ExternalReference::MartynsLawUK::TopTi │ Executed Update External Reference      │
# │                           │                           │         │       │ Law                                     │ ps                                     │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ 5162e261-25cb-4be1-a997-f2b083aa966a)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::TopTip │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ s                                       │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update Related Media      │ Update Related Media      │ SUCCESS │ Yes   │ Responsible Person Infographic          │ ExternalReference::MartynsLawUK::Respo │ Executed Update Related Media (GUID:    │
# │                           │                           │         │       │                                         │ nsiblePerson::Infographic              │ bc65ece0-3b95-4d76-ade2-dd66876f4a56)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::Respon │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ siblePerson::Infographic                │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ Protect UK Martyn's Law Home Page       │ ExternalReference::MartynsLawUK::Prote │ Executed Update External Reference      │
# │                           │                           │         │       │                                         │ ctUKMartynsLaw::HomePage               │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ 43c18c78-1e98-494d-ab04-c32a595bdf2d)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::MartynsLawUK::Protec │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ tUKMartynsLaw::HomePage                 │                                        │                                         │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Update External Reference │ Update External Reference │ SUCCESS │ Yes   │ National Protective Security Authority  │ ExternalReference::NationalProtectiveS │ Executed Update External Reference      │
# │                           │                           │         │       │ (NPSA) Home Page                        │ ecurityAuthority::HomePage             │ (GUID:                                  │
# │                           │                           │         │       │                                         │                                        │ 0c8bcce3-848f-44ce-b74a-20f7ec72fc45)   │
# ├···························┼···························┼·········┼·······┼·········································┼········································┼·········································┤
# │ Add Member to Collection  │ Add Member to Collection  │ SUCCESS │ No    │ ExternalReference::NationalProtectiveSe │                                        │ Executed Add Member to Collection       │
# │                           │                           │         │       │ curityAuthority::HomePage               │                                        │                                         │
# └───────────────────────────┴───────────────────────────┴─────────┴───────┴─────────────────────────────────────────┴────────────────────────────────────────┴─────────────────────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ==> SUCCESS: Output written to /home/jovyan/distribution-hub/dr-egeria-outbox/receipts/processed-2026-07-24 13:56-external-references.md
# v2: Processing complete for './external-references.md'

# %%
# Process glossary.md

process_md_file(
    input_file="./glossary.md",
    output_folder="./receipts",
    directive="process",
    server=env.egeria_view_server,
    url=env.egeria_view_server_url,
    userid=os.environ.get("EGERIA_USER", "ivorpadlock"),
    user_pass=os.environ.get("EGERIA_USER_PASSWORD", "secret"),
    summary_only=True,
)
# Out:
# v2: Processing Markdown File: /home/jovyan/coco-workbooks/4. keeping-safe/martyns-law/glossary.md
# *** INFO: PROCESS MODE ***
# Dr. Egeria will EXECUTE these commands and make PERMANENT CHANGES to Egeria.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
#                                                                                     Dr. Egeria v2 Processing Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Markdown Command        ┃ Canonical Command       ┃ Status  ┃ Found ┃ Display Name / End 1                     ┃ Qualified Name / End2                    ┃ Message                                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Update Glossary         │ Update Glossary         │ SUCCESS │ Yes   │ Glossary for the Terrorism (Protection   │ Glossary::MartynsLawUK                   │ Executed Update Glossary (GUID:          │
# │                         │                         │         │       │ of Premises) Act 2025 (UK)               │                                          │ 39a01298-2ee5-44ad-bfba-8654479d6f45)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Appropriate                              │ GlossaryTerm::MartynsLawUK::Appropriate  │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ 04fc08b7-f934-4a50-9f10-c3c7e46d7fc0)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Appropriate  │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Appropriate  │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ At the same time                         │ GlossaryTerm::MartynsLawUK::AtTheSameTim │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ e                                        │ 48a09a0a-b881-4968-9907-df49cc247bfd)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::AtTheSameTim │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ e                                        │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Communication                            │ GlossaryTerm::MartynsLawUK::Communicatio │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ n                                        │ 2988f16f-9fcb-4ede-a6de-3757638bcca3)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Communicatio │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ n                                        │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Communicatio │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ n                                        │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Compliance notice                        │ GlossaryTerm::MartynsLawUK::ComplianceNo │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ tice                                     │ 08898f0e-d778-4c05-83e8-78d435920425)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::ComplianceNo │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ tice                                     │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::ComplianceNo │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ tice                                     │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Co-operation                             │ GlossaryTerm::MartynsLawUK::Co-operation │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ a69504e5-b70e-4021-83d8-9eba909dbef3)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Co-operation │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Co-operation │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Co-ordination                            │ GlossaryTerm::MartynsLawUK::Co-ordinatio │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ n                                        │ a8d86e84-3a76-4f8a-9c9c-34c2b24906da)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Co-ordinatio │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ n                                        │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Co-ordinatio │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ n                                        │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Enhanced tier                            │ GlossaryTerm::MartynsLawUK::EnhancedTier │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ 11df76ca-8b81-4f2e-a170-9d5176ff7446)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::EnhancedTier │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::EnhancedTier │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link External Reference │ Link External Reference │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::EnhancedTier │                                          │ Executed Link External Reference         │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Evacuation                               │ GlossaryTerm::MartynsLawUK::Evacuation   │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ 9d23694d-9e6f-4750-8a9c-84160f307e8d)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Evacuation   │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Evacuation   │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ From time to time                        │ GlossaryTerm::MartynsLawUK::FromTimeToTi │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ me                                       │ b4c464d8-ef77-435a-aac8-33a94c3863d5)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::FromTimeToTi │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ me                                       │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::FromTimeToTi │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ me                                       │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Immediate vicinity                       │ GlossaryTerm::MartynsLawUK::ImmediateVic │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ inity                                    │ ae02c3b2-4413-4428-a368-89eebcd8283c)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::ImmediateVic │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ inity                                    │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::ImmediateVic │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ inity                                    │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Invacuation                              │ GlossaryTerm::MartynsLawUK::Invacuation  │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ 0f2164d2-6333-44ac-a2a2-5688e8d4a4e5)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Invacuation  │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Invacuation  │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Lockdown                                 │ GlossaryTerm::MartynsLawUK::Lockdown     │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ 7fcaa00f-f3f7-488e-b9fa-31b87f611b08)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Lockdown     │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Lockdown     │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ The National Counter-Terrorism Security  │ GlossaryTerm::MartynsLawUK::NationalCoun │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │ Office                                   │ terTerrorismSecurityOffice               │ c20f710a-3ba4-4478-817d-476a373ace25)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link External Reference │ Link External Reference │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::NationalCoun │                                          │ Executed Link External Reference         │
# │                         │                         │         │       │ terTerrorismSecurityOffice               │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ The National Protective Security         │ GlossaryTerm::MartynsLawUK::NationalProt │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │ Authority                                │ ectiveSecurityAuthority                  │ 4aaea786-c619-4c26-aa35-c642083e992e)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link External Reference │ Link External Reference │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::NationalProt │                                          │ Executed Link External Reference         │
# │                         │                         │         │       │ ectiveSecurityAuthority                  │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Penalty notice                           │ GlossaryTerm::MartynsLawUK::PenaltyNotic │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ e                                        │ 761166de-59bd-460e-8ef2-b690af64d679)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::PenaltyNotic │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ e                                        │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::PenaltyNotic │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ e                                        │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Principal use                            │ GlossaryTerm::MartynsLawUK::PrincipalUse │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ d5335634-febf-4d42-a806-c10f01b6e8d2)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::PrincipalUse │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::PrincipalUse │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Public protection measures               │ GlossaryTerm::MartynsLawUK::PublicProtec │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ tionMeasures                             │ fd2b115a-6516-483a-9b36-7f70d4530a87)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::PublicProtec │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ tionMeasures                             │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::PublicProtec │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ tionMeasures                             │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Public protection procedures             │ GlossaryTerm::MartynsLawUK::PublicProtec │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ tionProcedures                           │ f7fb3161-11b7-4558-b45e-35d2efbb0e4f)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::PublicProtec │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ tionProcedures                           │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::PublicProtec │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ tionProcedures                           │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Qualifying event                         │ GlossaryTerm::MartynsLawUK::QualifyingEv │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ ent                                      │ ecaca12f-8a92-4a8c-b549-5af9c4412ec3)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::QualifyingEv │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ ent                                      │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::QualifyingEv │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ ent                                      │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link External Reference │ Link External Reference │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::QualifyingEv │                                          │ Executed Link External Reference         │
# │                         │                         │         │       │ ent                                      │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link External Reference │ Link External Reference │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::QualifyingEv │                                          │ Executed Link External Reference         │
# │                         │                         │         │       │ ent                                      │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Qualifying premises                      │ GlossaryTerm::MartynsLawUK::QualifyingPr │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ emises                                   │ 6ee8cce2-e413-415e-b9cb-9364b126b4b0)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::QualifyingPr │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ emises                                   │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::QualifyingEv │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ ent                                      │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link External Reference │ Link External Reference │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::QualifyingPr │                                          │ Executed Link External Reference         │
# │                         │                         │         │       │ emises                                   │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link External Reference │ Link External Reference │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::QualifyingPr │                                          │ Executed Link External Reference         │
# │                         │                         │         │       │ emises                                   │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Reasonably practicable                   │ GlossaryTerm::MartynsLawUK::ReasonablyPr │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ acticable                                │ 56e06279-dca4-4299-91d5-908b1fadaa86)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::ReasonablyPr │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ acticable                                │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Responsible person or responsible        │ GlossaryTerm::MartynsLawUK::ResponsibleP │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │ persons                                  │ erson                                    │ 0e2d8653-87fd-4b5f-9005-a701bd13b3fe)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::ResponsibleP │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ erson                                    │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::ResponsibleP │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ erson                                    │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link External Reference │ Link External Reference │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::ResponsibleP │                                          │ Executed Link External Reference         │
# │                         │                         │         │       │ erson                                    │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Restriction notice                       │ GlossaryTerm::MartynsLawUK::RestrictionN │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ otice                                    │ 8e780e7a-43e0-4036-abf9-4f2f14d9eb77)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::RestrictionN │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ otice                                    │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::RestrictionN │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ otice                                    │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Schedule 1 use                           │ GlossaryTerm::MartynsLawUK::Schedule1Use │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ a596d6f9-d81d-4176-b803-745a8a9a5153)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Schedule1Use │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Schedule1Use │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Scope                                    │ GlossaryTerm::MartynsLawUK::Scope        │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ 081aa287-2cef-4f56-be36-d7e36e360e7c)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Security Industry Authority              │ GlossaryTerm::MartynsLawUK::SecurityIndu │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ stryAuthority                            │ 5e754d6f-0ad9-4927-998e-630139492509)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Senior individual                        │ GlossaryTerm::MartynsLawUK::SeniorIndivi │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ dual                                     │ ba4ff62d-2501-4d23-9dce-83c80e8743e1)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::SeniorIndivi │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ dual                                     │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::SeniorIndivi │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ dual                                     │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Staff                                    │ GlossaryTerm::MartynsLawUK::Staff        │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ 2fdad51b-1ee7-4ea2-9cdf-8dc98676f5db)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Standard tier                            │ GlossaryTerm::MartynsLawUK::StandardTier │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │                                          │ ab217bb0-7ee4-421c-995e-f8b504150449)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::StandardTier │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::StandardTier │                                          │ Executed Link Cited Document             │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link External Reference │ Link External Reference │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::StandardTier │                                          │ Executed Link External Reference         │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Vulnerability                            │ GlossaryTerm::MartynsLawUK::Vulnerabilit │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ y                                        │ 0f8b23b3-4c59-4533-9b8e-18b1c9db5f35)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::Vulnerabilit │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ y                                        │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Update Glossary Term    │ Update Glossary Term    │ SUCCESS │ Yes   │ Wholly or mainly                         │ GlossaryTerm::MartynsLawUK::WhollyOrMain │ Executed Update Glossary Term (GUID:     │
# │                         │                         │         │       │                                          │ ly                                       │ 5ae90e64-014e-4f00-9c76-336bfcdd53cd)    │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::WhollyOrMain │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ ly                                       │                                          │                                          │
# ├·························┼·························┼·········┼·······┼··········································┼··········································┼··········································┤
# │ Link Cited Document     │ Link Cited Document     │ SUCCESS │ No    │ GlossaryTerm::MartynsLawUK::WhollyOrMain │                                          │ Executed Link Cited Document             │
# │                         │                         │         │       │ ly                                       │                                          │                                          │
# └─────────────────────────┴─────────────────────────┴─────────┴───────┴──────────────────────────────────────────┴──────────────────────────────────────────┴──────────────────────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ==> SUCCESS: Output written to /home/jovyan/distribution-hub/dr-egeria-outbox/receipts/processed-2026-07-24 13:57-glossary.md
# v2: Processing complete for './glossary.md'

# %%
# Process regulation.md

process_md_file(
    input_file="./regulation.md",
    output_folder="./receipts",
    directive="process",
    server=env.egeria_view_server,
    url=env.egeria_view_server_url,
    userid=os.environ.get("EGERIA_USER", "ivorpadlock"),
    user_pass=os.environ.get("EGERIA_USER_PASSWORD", "secret"),
    summary_only=True,
)
# Out:
# v2: Processing Markdown File: /home/jovyan/coco-workbooks/4. keeping-safe/martyns-law/regulation.md
# *** INFO: PROCESS MODE ***
# Dr. Egeria will EXECUTE these commands and make PERMANENT CHANGES to Egeria.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
#                                                                                     Dr. Egeria v2 Processing Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Markdown Command              ┃ Canonical Command             ┃ Status  ┃ Found ┃ Display Name / End 1                       ┃ Qualified Name / End2    ┃ Message                                    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Update Regulation             │ Update Regulation             │ SUCCESS │ Yes   │ Terrorism (Protection of Premises) Act     │ Regulation::MartynsLawUK │ Executed Update Regulation (GUID:          │
# │                               │                               │         │       │ 2025 (UK)                                  │                          │ 71c5325d-61e3-4143-9678-d9aae6396614)      │
# ├·······························┼·······························┼·········┼·······┼············································┼··························┼············································┤
# │ Attach Collection to Resource │ Attach Collection to Resource │ SUCCESS │ No    │ Regulation::MartynsLawUK                   │                          │ Executed Attach Collection to Resource     │
# ├·······························┼·······························┼·········┼·······┼············································┼··························┼············································┤
# │ Attach Collection to Resource │ Attach Collection to Resource │ SUCCESS │ No    │ Regulation::MartynsLawUK                   │                          │ Executed Attach Collection to Resource     │
# └───────────────────────────────┴───────────────────────────────┴─────────┴───────┴────────────────────────────────────────────┴──────────────────────────┴────────────────────────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ==> SUCCESS: Output written to /home/jovyan/distribution-hub/dr-egeria-outbox/receipts/processed-2026-07-24 14:02-regulation.md
# v2: Processing complete for './regulation.md'

# %%
# Process collections.md

process_md_file(
    input_file="./collections.md",
    output_folder="./receipts",
    directive="process",
    server=env.egeria_view_server,
    url=env.egeria_view_server_url,
    userid=os.environ.get("EGERIA_USER", "ivorpadlock"),
    user_pass=os.environ.get("EGERIA_USER_PASSWORD", "secret"),
    summary_only=True,
)
# Out:
# v2: Processing Markdown File: /home/jovyan/coco-workbooks/4. keeping-safe/martyns-law/collections.md
# *** INFO: PROCESS MODE ***
# Dr. Egeria will EXECUTE these commands and make PERMANENT CHANGES to Egeria.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
#                                                                                     Dr. Egeria v2 Processing Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Markdown Command         ┃ Canonical Command        ┃ Status  ┃ Found ┃ Display Name / End 1                         ┃ Qualified Name / End2          ┃ Message                                      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Update Collection Folder │ Update Collection Folder │ SUCCESS │ Yes   │ Martyn's Law (UK)                            │ CollectionFolder::MartynsLawUK │ Executed Update Collection Folder (GUID:     │
# │                          │                          │         │       │                                              │                                │ 6d08f21a-7227-4081-b9b8-697a8f9603cf)        │
# ├··························┼··························┼·········┼·······┼··············································┼································┼··············································┤
# │ Add Member to Collection │ Add Member to Collection │ SUCCESS │ No    │ CollectionFolder::MartynsLawUK               │                                │ Executed Add Member to Collection            │
# ├··························┼··························┼·········┼·······┼··············································┼································┼··············································┤
# │ Add Member to Collection │ Add Member to Collection │ SUCCESS │ No    │ Regulation::MartynsLawUK                     │                                │ Executed Add Member to Collection            │
# ├··························┼··························┼·········┼·······┼··············································┼································┼··············································┤
# │ Add Member to Collection │ Add Member to Collection │ SUCCESS │ No    │ Glossary::MartynsLawUK                       │                                │ Executed Add Member to Collection            │
# ├··························┼··························┼·········┼·······┼··············································┼································┼··············································┤
# │ Add Member to Collection │ Add Member to Collection │ SUCCESS │ No    │ CollectionFolder::MartynsLawUK::ExternalSour │                                │ Executed Add Member to Collection            │
# │                          │                          │         │       │ ces                                          │                                │                                              │
# └──────────────────────────┴──────────────────────────┴─────────┴───────┴──────────────────────────────────────────────┴────────────────────────────────┴──────────────────────────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ==> SUCCESS: Output written to /home/jovyan/distribution-hub/dr-egeria-outbox/receipts/processed-2026-07-24 14:02-collections.md
# v2: Processing complete for './collections.md'
