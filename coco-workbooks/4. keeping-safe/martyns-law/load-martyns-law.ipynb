# %% [markdown]
# <!-- SPDX-License-Identifier: CC-BY-4.0 -->
# <!-- Copyright Contributors to the ODPi Egeria project 2024. -->
#
# ![Egeria Logo](https://raw.githubusercontent.com/odpi/egeria/main/assets/img/ODPi_Egeria_Logo_color.png)
#
# ### Egeria Workbook
#
# # Load Martyn's Law
#
# This notebook contains the commands to load the markdown files containing the Dr.Egeria commands to create the open metadata definitions for describing the requirements for a new UK regulation called the **Terrorism (Protection of Premises) Act 2025** known as **Martyn's Law**.  This new law is of relevance to Coco Pharmaceuticals because they hold an annual conference in their London Offices.  More information on the sceanario is found on Egeria's document Website:
#
# * [Ivor Padlock prepares for Martyn's Law](https://egeria-project.org/practices/coco-pharmaceuticals/scenarios/preparing-for-martyns-law/overview/) scenario description
# * [Assessing a new regulation](https://egeria-project.org/egeria-solutions/assessing-new-regulation/overview/) solution
#
# Run the cells below to create the definitions Ivor Padlock defines in his initial assessment of the Martyn's Law requirements.  The processing of each cell may take a minute so look for message
#
# **v2: Processing complete for 'file name'**
#
#
# ----

# %%
# Initialize the python environment

import os
from md_processing.dr_egeria import process_md_file
from pyegeria.core.config import load_app_config, settings, pretty_print_config

load_app_config()                              # reads config.json via env vars / .env
env = settings.Environment

print("Connecting to server: " + env.egeria_view_server + " at " + env.egeria_view_server_url)  # e.g. "Connecting to server qs-view-server at https://localhost:9443"
# Out:
# Connecting to server: qs-view-server at https://host.docker.internal:9443

# %%
# Process external-references.md

process_md_file(
    input_file="./external-references.md",
    output_folder="./receipts",
    directive="process",
    server=env.egeria_view_server,
    url=env.egeria_view_server_url,
    userid=os.environ.get("EGERIA_USER", "ivorpadlock"),
    user_pass=os.environ.get("EGERIA_USER_PASSWORD", "secret"),
    summary_only=True,
)
# Out:
# v2: Processing Markdown File: /home/jovyan/coco-workbooks/keeping-safe/martyns-law/external-references.md
# *** INFO: PROCESS MODE ***
# Dr. Egeria will EXECUTE these commands and make PERMANENT CHANGES to Egeria.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
#                                                                                                                   Dr. Egeria v2 Processing Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ...

# %%
# Process glossary.md

process_md_file(
    input_file="./glossary.md",
    output_folder="./receipts",
    directive="process",
    server=env.egeria_view_server,
    url=env.egeria_view_server_url,
    userid=os.environ.get("EGERIA_USER", "ivorpadlock"),
    user_pass=os.environ.get("EGERIA_USER_PASSWORD", "secret"),
    summary_only=True,
)
# Out:
# v2: Processing Markdown File: /home/jovyan/coco-workbooks/keeping-safe/martyns-law/glossary.md
# *** INFO: PROCESS MODE ***
# Dr. Egeria will EXECUTE these commands and make PERMANENT CHANGES to Egeria.
# Processing Warnings:
# -- Create Glossary Term (GlossaryTerm::MartynsLawUK::Scope) --
#    - Warning: An element with Display Name 'Scope' already exists in Egeria (QN or Display Name match) but could not be fetched.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
#                                                                                                                   Dr. Egeria v2 Processing Summary
# ...

# %%
# Process regulation.md

process_md_file(
    input_file="./regulation.md",
    output_folder="./receipts",
    directive="process",
    server=env.egeria_view_server,
    url=env.egeria_view_server_url,
    userid=os.environ.get("EGERIA_USER", "ivorpadlock"),
    user_pass=os.environ.get("EGERIA_USER_PASSWORD", "secret"),
    summary_only=True,
)
# Out:
# v2: Processing Markdown File: /home/jovyan/coco-workbooks/keeping-safe/martyns-law/regulation.md
# *** INFO: PROCESS MODE ***
# Dr. Egeria will EXECUTE these commands and make PERMANENT CHANGES to Egeria.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
#                                                                                                                 Dr. Egeria v2 Processing Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ...

# %%
# Process collections.md

process_md_file(
    input_file="./collections.md",
    output_folder="./receipts",
    directive="process",
    server=env.egeria_view_server,
    url=env.egeria_view_server_url,
    userid=os.environ.get("EGERIA_USER", "ivorpadlock"),
    user_pass=os.environ.get("EGERIA_USER_PASSWORD", "secret"),
    summary_only=True,
)
# Out:
# v2: Processing Markdown File: /home/jovyan/coco-workbooks/keeping-safe/martyns-law/collections.md
# *** INFO: PROCESS MODE ***
# Dr. Egeria will EXECUTE these commands and make PERMANENT CHANGES to Egeria.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
#                                                                                                                   Dr. Egeria v2 Processing Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ...

# %%
from rich import print, print_json
from rich.console import Console
from rich.markdown import Markdown

from pyegeria import (
    print_basic_exception, PyegeriaException,
    render_mermaid
)



collectionMermaidMindMap= "mindmap\n**RootCollection** Corporate Regulation Library\n    **CollectionFolder** Privacy Regulations\n    **CollectionFolder** Pharmaceutical Industry Regulations\n        **CollectionFolder** Clinical Trial Regulations\n    **CollectionFolder** Financial Regulations\n    **CollectionFolder** Security Regulations\n"
render_mermaid(collectionMermaidMindMap)
# Out:
#     <div></div>
#     <div class="mermaid">
#         mindmap
# **RootCollection** Corporate Regulation Library
#     **CollectionFolder** Privacy Regulations
#     **CollectionFolder** Pharmaceutical Industry Regulations
#         **CollectionFolder** Clinical Trial Regulations
#     **CollectionFolder** Financial Regulations
#     **CollectionFolder** Security Regulations
#
#     </div>
#     <script type_name = "text/javascript">
#         if (window.mermaid) {
#     mermaid.initialize({startOnLoad: true});
#     mermaid.contentLoaded();
#     }
#     </script>

# %%
mermaidGraph= "---\ntitle: CollectionFolder - Security Regulations [54a95fb3-2147-4bf1-ab1d-9d424647f188]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Collection Folder*\n**Security Regulations**\"}\n2@{ shape: rect, label: \"*Root Collection*\n**Corporate Regulation Library**\"}\n2==>|\"Collection Membership\"|1\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 2 color:#000000, fill:#2e8b57, stroke:#000000\n"
render_mermaid(mermaidGraph)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-54a95fb3-2147-4bf1-ab1d-9d424647f188-71dd-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     CollectionFolder - Security Regulations
#                 </h3>
#                 <p id="mermaid-graph-54a95fb3-2147-4bf1-ab1d-9d424647f188-71dd-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 54a95fb3-2147-4bf1-ab1d-9d424647f188
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Collection Folder*
# **Security Regulations**&quot;}
# 2@{ shape: rect, label: &quot;*Root Collection*
# **Corporate Regulation Library**&quot;}
# 2==&gt;|&quot;Collection Membership&quot;|1
# style 1 color:#000000, fill:#e0ab18, stroke:#004563
# ...

# %%
mermaidGraph= "---\ntitle: CollectionFolder - External Sources for Martyn''s Law [731bd079-aa40-4b7d-8d22-6186f04e9339]\n---\nflowchart TD\n%%{init: {\"flowchart\": {\"htmlLabels\": false}} }%%\n\n1@{ shape: rounded, label: \"*Collection Folder*\n**External Sources for Martyn''s Law**\"}\n2@{ shape: docs, label: \"*External Reference*\n**Standard duty requirements factsheet**\"}\n1==>|\"Collection Membership\"|2\n3@{ shape: docs, label: \"*Cited Document*\n**Terrorism (Protection of Premises) Act 2025**\"}\n1==>|\"Collection Membership\"|3\n4@{ shape: docs, label: \"*External Reference*\n**Capacity estimation**\"}\n1==>|\"Collection Membership\"|4\n5@{ shape: docs, label: \"*External Reference*\n**The regulator, sanctions and enforcement factsheet**\"}\n1==>|\"Collection Membership\"|5\n6@{ shape: docs, label: \"*External Reference*\n**Martyn''s Law Myth Buster**\"}\n1==>|\"Collection Membership\"|6\n7@{ shape: docs, label: \"*Cited Document*\n**Martyn''s Law Statutory Guidance from the UK Government (Home Office)**\"}\n1==>|\"Collection Membership\"|7\n8@{ shape: stadium, label: \"*Collection Membership*\n**... plus 11 Items**\"}\n1-.->8\n9@{ shape: flag, label: \"*Note Log*\n**External Sources for Martyn''s Law-NoteLog**\"}\n1==>|\"Attached Note Log\"|9\n10@{ shape: subproc, label: \"*Notification*\n**CollectionFolder::MartynsLawUK::ExternalSources-Journal-Entry-2026-05-06 14:39**\"}\n9==>|\"Attached Note Log Entry\"|10\n11@{ shape: flag, label: \"*Note Log*\n**External Sources for Martyn''s Law-NoteLog**\"}\n1==>|\"Attached Note Log\"|11\n12@{ shape: subproc, label: \"*Notification*\n**CollectionFolder::MartynsLawUK::ExternalSources-Journal-Entry-2026-05-06 14:45**\"}\n11==>|\"Attached Note Log Entry\"|12\nstyle 11 color:#000000, fill:#9370DB, stroke:#004563\nstyle 1 color:#000000, fill:#e0ab18, stroke:#004563\nstyle 12 color:#000000, fill:#BDB76B, stroke:#004563\nstyle 2 color:#000000, fill:#FFFF00, stroke:#000000\nstyle 3 color:#000000, fill:#FFFF00, stroke:#000000\nstyle 4 color:#000000, fill:#FFFF00, stroke:#000000\nstyle 5 color:#000000, fill:#FFFF00, stroke:#000000\nstyle 6 color:#000000, fill:#FFFF00, stroke:#000000\nstyle 7 color:#000000, fill:#FFFF00, stroke:#000000\nstyle 8 color:#000000, fill:#F9F7ED, stroke:#b7c0c7\nstyle 9 color:#000000, fill:#9370DB, stroke:#004563\nstyle 10 color:#000000, fill:#BDB76B, stroke:#004563\nclick 2 \"https://www.gov.uk/government/publications/terrorism-protection-of-premises-act-2025-factsheets/terrorism-protection-of-premises-act-2025-standard-duty-requirements-factsheet\" \"Click for more documentation\" _blank\nclick 3 \"https://www.legislation.gov.uk/ukpga/2025/10/contents/enacted\" \"Click for more documentation\" _blank\nclick 4 \"https://www.gov.uk/government/publications/terrorism-protection-of-premises-act-2025-factsheets/terrorism-protection-of-premises-act-2025-assessment-of-the-number-of-individuals-expected-to-be-present-formerly-known-as-capacity-calculations\" \"Click for more documentation\" _blank\nclick 5 \"https://www.gov.uk/government/publications/terrorism-protection-of-premises-act-2025-factsheets/terrorism-protection-of-premises-act-2025-the-regulator-sanctions-and-enforcement-factsheet\" \"Click for more documentation\" _blank\nclick 6 \"https://www.protectuk.police.uk/sites/default/files/2026-04/46.39_HO_Martyns%20Law_Myth_buster_Final_WEB.pdf\" \"Click for more documentation\" _blank\nclick 7 \"https://www.gov.uk/government/publications/the-terrorism-protection-of-premises-act-2025\" \"Click for more documentation\" _blank\n"
render_mermaid(mermaidGraph)

collectionMermaidMindMap= "mindmap\n**CollectionFolder** External Sources for Martyn''s Law\n"
render_mermaid(collectionMermaidMindMap)
# Out:
#     <div>
#                 <h3 id="mermaid-graph-731bd079-aa40-4b7d-8d22-6186f04e9339-0f69-heading" style="margin: 20px 0; font-size: 1.5em; text-align: center;">
#                     CollectionFolder - External Sources for Martyn&#x27;&#x27;s Law
#                 </h3>
#                 <p id="mermaid-graph-731bd079-aa40-4b7d-8d22-6186f04e9339-0f69-subheading" style="margin: 0; padding: 5px; font-size: 1em; text-align: center; color: gray; flex: 0 0 auto;">
#                     GUID: 731bd079-aa40-4b7d-8d22-6186f04e9339
#                 </p>
#                 </div>
#     <div class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1@{ shape: rounded, label: &quot;*Collection Folder*
# **External Sources for Martyn&#x27;&#x27;s Law**&quot;}
# 2@{ shape: docs, label: &quot;*External Reference*
# **Standard duty requirements factsheet**&quot;}
# 1==&gt;|&quot;Collection Membership&quot;|2
# ...
