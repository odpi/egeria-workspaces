# %%
out ={
  "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
  "title": "Zone Asset Types \u2014 Digital Products Zone",
   "description": "Zone Asset Types \u2014 Digital Products Zone",
  "data": {
    "values": [
      {
        "assetType": "SolutionActorRole",
        "count": 4
      },
      {
        "assetType": "DigitalProductCatalog",
        "count": 1
      },
      {
        "assetType": "BusinessImperative",
        "count": 1
      },
      {
        "assetType": "DigitalProductFamily",
        "count": 8
      },
      {
        "assetType": "GovernancePolicy",
        "count": 1
      },
      {
        "assetType": "PersonRole",
        "count": 3
      },
      {
        "assetType": "LicenseType",
        "count": 3
      },
      {
        "assetType": "SolutionComponent",
        "count": 10
      },
      {
        "assetType": "SolutionBlueprint",
        "count": 8
      },
      {
        "assetType": "ServiceLevelObjective",
        "count": 28
      },
      {
        "assetType": "EngineAction",
        "count": 1
      },
      {
        "assetType": "Community",
        "count": 4
      },
      {
        "assetType": "GovernanceApproach",
        "count": 1
      },
      {
        "assetType": "DigitalProduct",
        "count": 105
      }
    ]
  },
  "mark": {
    "type": "bar",
    "tooltip": True
  },
  "encoding": {
    "y": {
      "field": "assetType",
      "type": "nominal",
      "sort": "-x",
      "title": "Asset Type"
    },
    "x": {
      "field": "count",
      "type": "quantitative",
      "title": "Count"
    },
    "color": {
      "field": "assetType",
      "type": "nominal",
      "legend": None
    },
    "tooltip": [
      {
        "field": "assetType",
        "type": "nominal",
        "title": "Type"
      },
      {
        "field": "count",
        "type": "quantitative",
        "title": "Count"
      }
    ]
  }
}

# %%
from IPython.display import display

# %%
display({
    "application/vnd.vegalite.v5+json": out
}, raw=True
       )
